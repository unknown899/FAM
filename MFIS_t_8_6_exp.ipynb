# %% [markdown]
# # 本次模擬cmd log資訊
#
# * 2026/05/28（19點）開始模擬
# * 只保留最後一個iteration(38948)的迭代資訊和AMReX finalize(如下)

# %% [markdown]
# MLMG: Initial rhs               = 384747159.2
# MLMG: Initial residual (resid0) = 8519020938
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.0008411514282, 9.873803977e-14
# MLMG: Timers: Solve = 0.902711137 Iter = 0.898757798 Bottom = 0.892557363
# 1 iterations :: err = 1
# MLMG: Initial rhs               = 384747159.2
# MLMG: Initial residual (resid0) = 8519020938
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.001217871846, 1.429591329e-13
# MLMG: Timers: Solve = 0.864943991 Iter = 0.86097892 Bottom = 0.854847907
# 2 iterations :: err = 2.811342005e-11
# Steady state check : (phi(t) - phi(t-1)).norm0() = 9.947508073e-08
# Advanced step 38948 in 1.849642753 seconds
#
# step = 38948, Phi_Bc_hi = -4, num_Vapp = 21, sign = 1
# MLMG: Initial rhs               = 384747160.9
# MLMG: Initial residual (resid0) = 6819820937
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.0002777850377, 4.073201339e-14
# MLMG: Timers: Solve = 0.834851577 Iter = 0.830969547 Bottom = 0.824824636
# 1 iterations :: err = 1
# MLMG: Initial rhs               = 384747160.9
# MLMG: Initial residual (resid0) = 6819820937
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.002210036226, 3.240607409e-13
# MLMG: Timers: Solve = 0.830779927 Iter = 0.826818836 Bottom = 0.820689569
# 2 iterations :: err = 7.167582684e-05
# MLMG: Initial rhs               = 384747160.9
# MLMG: Initial residual (resid0) = 6819820937
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.0009729102815, 1.426592121e-13
# MLMG: Timers: Solve = 0.854315155 Iter = 0.850340585 Bottom = 0.844211878
# 3 iterations :: err = 5.878133965e-08
# voltage_sweep == 1 && num_Vapp == num_Vapp_max!
# High-water FAB megabyte spread across MPI nodes: [44 ... 44]
# Current     FAB megabyte spread across MPI nodes: [34 ... 34]
# Total run time 82954.84235 seconds
#
#
# TinyProfiler total time across processes [min...avg...max]: 8.295e+04 ... 8.295e+04 ... 8.295e+04
#
# ----------------------------------------------------------------------------------------------
# Name                                           NCalls  Excl. Min  Excl. Avg  Excl. Max   Max %
# ----------------------------------------------------------------------------------------------
# amrex::Dot()                                 51460646  1.707e+04  1.728e+04  1.747e+04  21.06%
# MLABecLaplacian::normalize()                 25964594  1.027e+04  1.029e+04  1.031e+04  12.43%
# MLABecLaplacian::Fapply()                    26042686  1.016e+04  1.018e+04  1.022e+04  12.32%
# MLCGSolver::ParallelAllReduce                64633419       8033       8814       9598  11.57%
# FabArray::norminf()                          26432945       9098       9109       9125  11.00%
# FillBoundary_finish()                        26354494       8265       8274       8291   9.99%
# FillBoundary_nowait()                        26354494       6424       6582       6776   8.17%
# FabArray::Saxpy_Saxpy()                      12938502       2359       2720       3131   3.77%
# FabArray::Saypy_Saxpy()                      12791821       2389       2641       2904   3.50%
# FabArray::Saxpy_Xpay()                       12704231       2188       2418       2532   3.05%
# ComputePhi_Rho()                                38969      723.2      810.9      888.4   1.07%
# amrex::Copy()                                 1288741      561.1      620.7      667.4   0.80%
# FabArray::setVal()                            1444424      588.6      593.5      603.7   0.73%
# Calculate_Landau()                              38948      532.9      545.3      559.3   0.67%
# MLCGSolver::bicgstab                           234271      328.3        329      329.8   0.40%
# Calculate_Grad()                                38948      272.8      282.2      292.9   0.35%
# MLCellLinOp::applyBC()                       26042686      224.5      226.7      229.8   0.28%
# ComputeEfromPhi()                               77896      164.1      187.9        222   0.27%
# FabArray::LinComb()                            194936      158.7      176.4      212.6   0.26%
# Calculate_Elec()                                38948      80.55      124.4      163.2   0.20%
# FabArray::FillBoundary()                     26354494      114.3        115      116.8   0.14%
# MLCellLinOp::apply()                         26042686      114.1      114.6      115.6   0.14%
# main()                                              1      56.64      71.89      79.11   0.10%
# MLMG::solve()                                   78092      14.04      15.87      19.31   0.02%
# MLMG::actualBottomSolve()                      234271      3.128      3.145      3.166   0.00%
# MLCellLinOp::solutionResidual()                312363      1.733      1.737      1.739   0.00%
# MLMG::oneIter()                                234271       1.54      1.558      1.567   0.00%
# MLMG::computeResidual()                        234271     0.8667     0.8684     0.8705   0.00%
# MLMG::mgVcycle_bottom                          234271     0.6792      0.681     0.6847   0.00%
# MLMG::mgVcycle()                               234271     0.6501     0.6514      0.655   0.00%
# MLMG::computeMLResidual()                       78092     0.2552     0.2562     0.2571   0.00%
# Other                                        28190183      401.3      419.8      441.2   0.53%
# ----------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------
# Name                                           NCalls  Incl. Min  Incl. Avg  Incl. Max   Max %
# ----------------------------------------------------------------------------------------------
# main()                                              1  8.295e+04  8.295e+04  8.295e+04 100.00%
# ComputePhi_Rho()                                38969  8.142e+04  8.142e+04  8.142e+04  98.16%
# MLMG::solve()                                   78092  7.976e+04  7.976e+04  7.976e+04  96.15%
# MLMG::oneIter()                                234271  7.902e+04  7.902e+04  7.903e+04  95.27%
# MLMG::mgVcycle()                               234271  7.898e+04  7.898e+04  7.898e+04  95.21%
# MLMG::mgVcycle_bottom                          234271  7.898e+04  7.898e+04  7.898e+04  95.21%
# MLMG::actualBottomSolve()                      234271  7.898e+04  7.898e+04  7.898e+04  95.20%
# MLCGSolver::bicgstab                           234271  7.892e+04  7.893e+04  7.894e+04  95.16%
# MLCellLinOp::apply()                         26042686  2.517e+04  2.535e+04  2.551e+04  30.75%
# amrex::Dot()                                 51460646  1.707e+04  1.728e+04  1.747e+04  21.06%
# MLCGSolver::ParallelAllReduce                64633419  1.606e+04  1.671e+04   1.73e+04  20.85%
# MLCellLinOp::applyBC()                       26042686  1.489e+04  1.505e+04  1.524e+04  18.37%
# FabArray::FillBoundary()                     26354494  1.484e+04  1.501e+04  1.519e+04  18.32%
# MLABecLaplacian::normalize()                 25964594  1.027e+04  1.029e+04  1.031e+04  12.43%
# MLABecLaplacian::Fapply()                    26042686  1.016e+04  1.018e+04  1.022e+04  12.32%
# FabArray::norminf()                          26432945       9098       9109       9125  11.00%
# FillBoundary_finish()                        26354494       8265       8274       8291   9.99%
# FillBoundary_nowait()                        26354494       6462       6620       6814   8.21%
# FabArray::Saxpy_Saxpy()                      12938502       2359       2720       3131   3.77%
# FabArray::Saypy_Saxpy()                      12791821       2389       2641       2904   3.50%
# FabArray::Saxpy_Xpay()                       12704231       2188       2418       2532   3.05%
# amrex::Copy()                                 1288741      561.1      620.7      667.4   0.80%
# FabArray::setVal()                            1444424      588.6      593.5      603.7   0.73%
# Calculate_Landau()                              38948      532.9      545.3      559.3   0.67%
# MLCellLinOp::solutionResidual()                312363      469.5      469.6      469.7   0.57%
# MLMG::computeResidual()                        234271      322.5      322.6      322.7   0.39%
# Calculate_Grad()                                38948      272.8      282.2      292.9   0.35%
# ComputeEfromPhi()                               77896      164.1      187.9        222   0.27%
# FabArray::LinComb()                            194936      158.7      176.4      212.6   0.26%
# Calculate_Elec()                                38948      80.55      124.4      163.2   0.20%
# MLMG::computeMLResidual()                       78092        148      148.2      148.3   0.18%
# Other                                        28190183      680.6      698.6      718.5   0.87%
# ----------------------------------------------------------------------------------------------
#
# Device Memory Usage:
# ------------------------------------------------------------------------------------------------------------------------------
# Name                                            Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ------------------------------------------------------------------------------------------------------------------------------
# The_Arena::Initialize()                              4       0   B       0   B       0   B     731 MiB     731 MiB     731 MiB
# main()                                             976      29 MiB      29 MiB      29 MiB      30 MiB      30 MiB      30 MiB
# WritePlotfile()                                    352      96   B      97   B     101   B    8496 KiB    8496 KiB    8496 KiB
# ResizeRandomSeed                                     8    4607 KiB    4607 KiB    4607 KiB    4608 KiB    4608 KiB    4608 KiB
# MLCGSolver::bicgstab                          18741680    2518 KiB    2518 KiB    2518 KiB    2652 KiB    2652 KiB    2652 KiB
# MLMG::prepareForSolve()                             64    2033 KiB    2033 KiB    2033 KiB    2034 KiB    2034 KiB    2034 KiB
# MLABecLaplacian::define()                           64    1955 KiB    1955 KiB    1955 KiB    1956 KiB    1956 KiB    1956 KiB
# ComputePhi_Rho()                               8748768      15 KiB      15 KiB      16 KiB    1888 KiB    1888 KiB    1888 KiB
# MultiFab::OverlapMask()                        1564920     717   B     727   B     737   B     472 KiB     472 KiB     472 KiB
# BndryData::define()                                192     433 KiB     433 KiB     433 KiB     434 KiB     434 KiB     434 KiB
# MLCellLinOp::defineAuxData()                       192     203 KiB     203 KiB     203 KiB     204 KiB     204 KiB     204 KiB
# VisMF::Write(FabArray)                            6336       0   B       0   B       0   B      48 KiB      48 KiB      48 KiB
# FillBoundary_nowait()                          4373144      43 KiB      43 KiB      43 KiB      44 KiB      44 KiB      44 KiB
# MultiFab::max()                                 155884     513   B     513   B     514   B      24 KiB      24 KiB      24 KiB
# amrex::Dot()                                 205842584    4990   B    5051   B    5110   B      24 KiB      24 KiB      24 KiB
# FabArray::norminf()                          105731780    2657   B    2661   B    2667   B      24 KiB      24 KiB      24 KiB
# MultiFab::norm1                                 312984       7   B       7   B       7   B      24 KiB      24 KiB      24 KiB
# FabArray::setVal()                             3123784      18 KiB      18 KiB      18 KiB      19 KiB      19 KiB      19 KiB
# FillBoundary_finish()                          2186572      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB
# amrex::Copy()                                  1562584    8170   B    8170   B    8170   B    8192   B    8192   B    8192   B
# MLCellLinOp::applyBC()                       104483140    6911   B    6911   B    6911   B    7168   B    7168   B    7168   B
# MLCellLinOp::prepareForSolve()                       4       0   B       0   B       0   B    4096   B    4096   B    4096   B
# FabArray::setVal(val, thecmd, scomp, ncomp)         56       0   B       0   B       0   B    1024   B    1024   B    1024   B
# FabArray::LinComb()                             312372     512   B     512   B     513   B    1024   B    1024   B    1024   B
# MLABecLaplacian::Fapply()                      1874168     956   B     956   B     956   B    1024   B    1024   B    1024   B
# MultiFab::Divide()                              312984       0   B       0   B       0   B     512   B     512   B     512   B
# MLCellLinOp::defineBC()                              4     511   B     511   B     511   B     512   B     512   B     512   B
# ------------------------------------------------------------------------------------------------------------------------------
#
# Managed Memory Usage:
# ---------------------------------------------------------------------------------------------------------------
# Name                             Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ---------------------------------------------------------------------------------------------------------------
# The_Managed_Arena::Initialize()       4       0   B       0   B       0   B    8192 KiB    8192 KiB    8192 KiB
# main()                                4       0   B       0   B       0   B      31 KiB      31 KiB      31 KiB
# ---------------------------------------------------------------------------------------------------------------
#
# Pinned Memory Usage:
# ------------------------------------------------------------------------------------------------------------------------------
# Name                                            Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ------------------------------------------------------------------------------------------------------------------------------
# The_Pinned_Arena::Initialize()                       4       0   B       0   B       0   B    8192 KiB    8192 KiB    8192 KiB
# VisMF::Write(FabArray)                            6688       6   B       6   B       6   B    2124 KiB    2124 KiB    2124 KiB
# FillBoundary_nowait()                        215209096      54 KiB      54 KiB      54 KiB     104 KiB     104 KiB     104 KiB
# FabArray::setVal()                             3123784      18 KiB      18 KiB      18 KiB      19 KiB      19 KiB      19 KiB
# FillBoundary_finish()                          2186572      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB
# amrex::Copy()                                  1562584    8170   B    8170   B    8170   B    8192   B    8192   B    8192   B
# MLCellLinOp::applyBC()                          312396    6911   B    6911   B    6911   B    6912   B    6912   B    6912   B
# MLCellLinOp::prepareForSolve()                       4       0   B       0   B       0   B    4096   B    4096   B    4096   B
# FabArray::LinComb()                             312372     512   B     512   B     513   B    1024   B    1024   B    1024   B
# FabArray::setVal(val, thecmd, scomp, ncomp)         56       0   B       0   B       0   B    1024   B    1024   B    1024   B
# MLABecLaplacian::Fapply()                      1874168     956   B     956   B     956   B    1024   B    1024   B    1024   B
# MultiFab::OverlapMask()                         312984       0   B       0   B       0   B     768   B     768   B     768   B
# MultiFab::max()                                 155884     512   B     512   B     512   B     768   B     768   B     768   B
# MLCellLinOp::setLevelBC()                           88       0   B       0   B       0   B     512   B     512   B     512   B
# MultiFab::Divide()                              312984       0   B       0   B       0   B     512   B     512   B     512   B
# amrex::Dot()                                 205842584      51   B      52   B      53   B     256   B     256   B     256   B
# Unprofiled                                          60       0   B       0   B       0   B     256   B     256   B     256   B
# MultiFab::norm1                                 312984       0   B       0   B       0   B     256   B     256   B     256   B
# FabArray::norminf()                          105731780      27   B      27   B      27   B     256   B     256   B     256   B
# ------------------------------------------------------------------------------------------------------------------------------
#
# Total GPU global memory (MB) spread across MPI: [3901 ... 3901]
# Free  GPU global memory (MB) spread across MPI: [547 ... 547]
# [The         Arena] max space (MB) allocated spread across MPI: [731 ... 731]
# [The         Arena] max space (MB) used      spread across MPI: [47 ... 47]
# [The Managed Arena] max space (MB) allocated spread across MPI: [8 ... 8]
# [The Managed Arena] max space (MB) used      spread across MPI: [0 ... 0]
# [The  Pinned Arena] max space (MB) allocated spread across MPI: [8 ... 8]
# [The  Pinned Arena] max space (MB) used      spread across MPI: [2 ... 2]
# AMReX (26.05-39-gbe2cc437644f) finalized

# %% [markdown]
# # 使用者設定

# %%
import re
from pathlib import Path

import yt
import numpy as np
import pandas as pd


# =========================
# User settings
# =========================
PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt")          # plotfile 所在資料夾
PLOT_PREFIX = "plt"
PLOT_INTERVAL = 10000000           # 你的 plot_int，例如 100

# 如果你的 field 名稱不是 ("boxlib", "Phi")，後面會自動列出 field_list 方便你改
PHI_FIELD_CANDIDATES = [
    ("boxlib", "Phi"),
    ("boxlib", "phi"),
    ("boxlib", "PoissonPhi"),
    "Phi",
    "phi",
    "PoissonPhi",
]

# FE layer range, unit: nm
FE_Z_LO_NM = 21.5
FE_Z_HI_NM = 29.5

# 如果你想只畫 FE 的 x 範圍，也可以打開這兩行
# 若是 MFIS 全幅 FE，通常用整個 x 範圍即可

FE_X_LO_NM = -16.0
FE_X_HI_NM = 16.0

FE_Y_LO_NM = -16.0
FE_Y_HI_NM = 16.0

ALPHA = -5.0e9
BETA = 6.0e10
SMALL_GAMMA = 1.5e11
G11 = 1.0e-9
G44 = 1.0e-9


# 3D sweep plot要畫的電壓欄位：-5, -4, ..., 5
VOLTAGES = np.arange(-5, 6, 1)
# 3D contour 要畫的plotfile
PLOTFILE_NAME = "plt00020080"

# %% [markdown]
# ## Utils

# %%
def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v

def read_full_field_from_grids(ds, field):
    """
    Read a cell-centered AMReX field from all yt grids
    and stitch them into one full-domain numpy array.

    Return:
        full: numpy array with shape ds.domain_dimensions
    """
    dims = np.array(ds.domain_dimensions, dtype=int)
    full = np.empty(tuple(dims), dtype=float)

    domain_lo = ds.domain_left_edge.to_value()
    domain_hi = ds.domain_right_edge.to_value()
    dx = (domain_hi - domain_lo) / dims

    for grid in ds.index.grids:
        arr = to_numpy(grid[field])

        left = grid.LeftEdge.to_value()

        # grid start index in global domain
        start = np.rint((left - domain_lo) / dx).astype(int)

        nx, ny, nz = arr.shape
        i0, j0, k0 = start
        i1, j1, k1 = i0 + nx, j0 + ny, k0 + nz

        full[i0:i1, j0:j1, k0:k1] = arr

    return full

# %% [markdown]
# # plot

# %% [markdown]
# ## 看有哪些 plotfile

# %%
from pathlib import Path
import yt


plot_paths = sorted([p for p in PLOT_DIR.glob(f"{PLOT_PREFIX}*") if p.is_dir()])

# 只要名稱 (plt000100, ...)
plot_names = [p.name for p in plot_paths]

print("Available plotfiles:")
for name in plot_names:
    print("  ", name)
# Out:
# Available plotfiles:
#    plt00000000
#    plt00000098
#    plt00000164
#    plt00000239
#    plt00000327
#    plt00000435
#    plt00000577
#    plt00000801
#    plt00008361
#    plt00011960
#    plt00016913
#    plt00020080
#    plt00027130
#    plt00027629
#    plt00031118
#    plt00035225
#    plt00035614
#    plt00036085
#    plt00036912
#    plt00037416
#    plt00037931
#    plt00038948

# %% [markdown]
# ## 探索yt資料結構

# %% [markdown]
# ### dir(ds) # 列出 ds 所有(variable和property和method)

# %% [markdown]
# * Note: variable和property和method統稱attribute

# %%
ds = yt.load(PLOT_DIR/plot_names[0])  # 載入指定的 plotfile
dir(ds) # 列出 ds 所有變數和屬性和方法
#[a for a in dir(ds) if not a.startswith("_")]
# Out:
# yt : [INFO     ] 2026-05-29 18:13:48,890 Parameters: current_time              = 0.0
# yt : [INFO     ] 2026-05-29 18:13:48,890 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:48,891 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:48,891 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_object_class',
#  '_arr',
#  '_assign_unit_system',
#  '_create_unit_registry',
#  '_default_cparam_filename',
#  '_determined_fields',
#  '_field_info',
#  '_field_info_class',
#  '_field_list',
#  '_find_extremum',
#  '_force_periodicity',
#  '_get_field_info',
#  '_get_field_info_helper',
#  '_guess_candidates',
#  '_hash',
#  '_header_mesh_start',
#  '_index_class',
#  '_input_filename',
#  '_instantiated',
#  '_instantiated_index',
#  '_ionization_label_format',
#  '_is_valid',
#  '_is_within_domain',
#  '_load_requirements',
#  '_localize_check',
#  '_lookup_cparam_filepath',
#  '_max_level',
#  '_min_level',
#  '_missing_load_requirements',
#  '_mrep',
#  '_output_prefix',
#  '_override_code_units',
#  '_parse_cparams',
#  '_parse_fparams',
#  '_parse_header_file',
#  '_parse_parameter_file',
#  '_particle_type_counts',
#  '_periodicity',
#  '_proj_type',
#  '_quan',
#  '_sanitize_units_override',
#  '_set_code_unit_attributes',
#  '_set_derived_attrs',
#  '_setup_classes',
#  '_setup_coordinate_handler',
#  '_setup_filtered_type',
#  '_setup_particle_type',
#  '_setup_particle_types',
#  '_skip_cache',
#  '_unit_system_id',
#  '_unit_system_name',
#  '_units',
#  '_uses_code_length_unit',
#  '_uses_code_time_unit',
#  '_validate_units_override_keys',
#  'add_deposited_particle_field',
#  'add_field',
#  'add_gradient_fields',
#  'add_mesh_sampling_particle_field',
#  'add_particle_filter',
#  'add_particle_union',
#  'all_data',
#  'arbitrary_grid',
#  'arr',
#  'backup_filename',
#  'basename',
#  'bool',
#  'box',
#  'checksum',
#  'close',
#  'conversion_factors',
#  'coordinates',
#  'covering_grid',
#  'cparam_filename',
#  'create_field_info',
#  'current_time',
#  'cut_region',
#  'cutting',
#  'data_collection',
#  'dataset_type',
#  'default_field',
#  'default_fluid_type',
#  'default_species_fields',
#  'default_units',
#  'define_unit',
#  'derived_field_list',
#  'dimensionality',
#  'directory',
#  'disk',
#  'domain_center',
#  'domain_dimensions',
#  'domain_left_edge',
#  'domain_offset',
#  'domain_right_edge',
#  'domain_width',
#  'ellipsoid',
#  'field_info',
#  'field_list',
#  'field_units',
#  'fields',
#  'fields_detected',
#  'filename',
#  'find_field_values_at_point',
#  'find_field_values_at_points',
#  'find_max',
#  'find_min',
#  'fluid_types',
#  'force_periodicity',
#  'fparam_filename',
#  'fullpath',
#  'geometry',
#  'get_smallest_appropriate_unit',
#  'get_unit_from_registry',
#  'has_key',
#  'index',
#  'intersection',
#  'ires_factor',
#  'known_filters',
#  'length_unit',
#  'level_offsets',
#  'mass_unit',
#  'max_level',
#  'min_level',
#  'minimal_sphere',
#  'no_cgs_equiv_length',
#  'object_types',
#  'objects',
#  'octree',
#  'orion_version',
#  'ortho_ray',
#  'output_dir',
#  'parameter_filename',
#  'parameters',
#  'particle_fields_by_type',
#  'particle_type_counts',
#  'particle_types',
#  'particle_types_raw',
#  'particle_unions',
#  'particles_exist',
#  'periodicity',
#  'plots',
#  'point',
#  'print_key_parameters',
#  'print_stats',
#  'proj',
#  'quan',
#  'r',
#  'ray',
#  'ref_factors',
#  'refine_by',
#  'region',
#  'region_expression',
#  'relative_refinement',
#  'set_code_units',
#  'set_field_label_format',
#  'set_units',
#  'setup_cosmology',
#  'setup_deprecated_fields',
#  'slice',
#  'smoothed_covering_grid',
#  'sphere',
#  'storage_filename',
#  'streamline',
#  'surface',
#  'time_unit',
#  'union',
#  'unique_identifier',
#  'unit_registry',
#  'unit_system',
#  'units',
#  'units_override',
#  'velocity_unit']

# %% [markdown]
# ### 用key word查看dir(ds)中可能會用到的attribute

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "domain"
    if "domain" in a.lower():
        print(a)
# Out:
# _is_within_domain
# domain_center
# domain_dimensions
# domain_left_edge
# domain_offset
# domain_right_edge
# domain_width

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "field"
    if "field" in a.lower():
        print(a)
# Out:
# _determined_fields
# _field_info
# _field_info_class
# _field_list
# _get_field_info
# _get_field_info_helper
# add_deposited_particle_field
# add_field
# add_gradient_fields
# add_mesh_sampling_particle_field
# create_field_info
# default_field
# default_species_fields
# derived_field_list
# field_info
# field_list
# field_units
# fields
# fields_detected
# find_field_values_at_point
# find_field_values_at_points
# particle_fields_by_type
# set_field_label_format
# setup_deprecated_fields

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "index"
    if "index" in a.lower():
        print(a)
# Out:
# _index_class
# _instantiated_index
# index

# %% [markdown]
# * **grid相關attribute在index內**

# %%
for a in dir(ds.index): # 列出 ds.index 裡有哪些屬性和方法，特別是包含 "index"
    if "grid" in a.lower():
        print(a)
# Out:
# _count_grids
# _get_grid_objs
# _get_grid_tree
# _get_grids
# _grid_chunksize
# _grids
# _initialize_grid_arrays
# _populate_grid_objects
# grid
# grid_corners
# grid_dimensions
# grid_left_edge
# grid_levels
# grid_particle_count
# grid_right_edge
# grid_start_index
# grids
# lock_grids_to_parents
# num_grids
# select_grids

# %%
for a in dir(ds.index.grids[0]): # 列出 ds.index.grids[0] 裡有哪些屬性和方法，特別是包含 "index"
    
        print(a)
# Out:
# ActiveDimensions
# Children
# LeftEdge
# Level
# NumberOfParticles
# OverlappingSiblings
# Parent
# RightEdge
# __abstractmethods__
# __add__
# __and__
# __annotations__
# __class__
# __delattr__
# __delitem__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __int__
# __invert__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __or__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __setitem__
# __sizeof__
# __slots__
# __str__
# __sub__
# __subclasshook__
# __weakref__
# __xor__
# _abc_impl
# _activate_cache
# _base_offset
# _cache_mask
# _child_index_mask
# _child_indices
# _child_mask
# _children_ids
# _chunk_info
# _chunked_read
# _compute_extrema
# _con_args
# _container_fields
# _count_particles
# _current_chunk
# _current_fluid_type
# _current_particle_type
# _data_source
# _debug
# _default_field_parameters
# _derived_quantity_chunking
# _determine_fields
# _distributed
# _ds_hold
# _extrema_cache
# _field_cache
# _field_lock
# _field_parameter_state
# _field_type_state
# _fill_child_mask
# _finalize_parallel
# _first_matching_field
# _generate_container_field
# _generate_field
# _generate_fields
# _generate_fluid_field
# _generate_particle_field
# _generate_spatial_fluid
# _get_grid_objs
# _get_grids
# _get_objs
# _get_offset
# _get_selector_mask
# _grids
# _hash
# _id_offset
# _identify_dependencies
# _index
# _initialize_cache
# _initialize_parallel
# _ipython_key_completions_
# _is_default_field_parameter
# _last_count
# _last_mask
# _last_selector_id
# _locked
# _max_level
# _min_level
# _num_ghost_zones
# _offset
# _parameter_iterate
# _parent_id
# _pdata
# _prepare_grid
# _reshape_vals
# _selector
# _set_center
# _set_default_field_parameters
# _setup_dx
# _skip_add
# _sort_by
# _spatial
# _tds_attrs
# _tds_fields
# _tree
# _type_name
# apply_units
# argmax
# argmin
# blocks
# child_index_mask
# child_indices
# child_mask
# chunks
# clear_data
# clone
# comm
# convert
# count
# count_particles
# create_firefly_object
# dds
# deposit
# ds
# fcoords
# fcoords_vertex
# field_data
# field_parameters
# filename
# fwidth
# get_data
# get_dependencies
# get_field_parameter
# get_global_startindex
# get_position
# get_vertex_centered_data
# has_field_parameter
# has_key
# icoords
# id
# index
# integrate
# ires
# keys
# max
# max_level
# mean
# min
# min_level
# particle_operation
# partition_index_2d
# partition_index_3d
# partition_index_3d_bisection_list
# partition_region_3d
# pf
# profile
# ptp
# quantities
# retrieve_ghost_zones
# save_as_dataset
# select
# select_blocks
# select_fcoords
# select_fwidth
# select_icoords
# select_ires
# select_particles
# select_tcoords
# selector
# set_field_parameter
# shape
# smooth
# start_index
# std
# sum
# tiles
# to_astropy_table
# to_dataframe
# to_glue
# write_out

# %% [markdown]
# ## yt dataset

# %% [markdown]
# * 可以從上一個部份"探索yt資料結構"找想用的attribute

# %%
print("========== Dataset ==========")
print("type:", type(ds))
print("用SI單位")
print("current_time(s):", ds.current_time)
print("domain_left_edge(m) :", ds.domain_left_edge)
print("domain_right_edge(m):", ds.domain_right_edge)
print("domain_center:", ds.domain_center)
print("domain_width(domain邊長):", ds.domain_width)
print("domain_offset:", ds.domain_offset)
print("domain_dimensions(xyz方向各切成幾格):", ds.domain_dimensions)
print("dimensionality:", ds.dimensionality)
print("geometry:", ds.geometry)
#print("periodicity:", ds.periodicity)

print("\n========== Fields ==========")
for f in ds.field_list:
    print(" ", f)
# Out:
# ========== Dataset ==========
# type: <class 'yt.frontends.amrex.data_structures.BoxlibDataset'>
# 用SI單位
# current_time(s): 0.0 code_time
# domain_left_edge(m) : [-1.6e-08 -1.6e-08  0.0e+00] code_length
# domain_right_edge(m): [1.60e-08 1.60e-08 2.95e-08] code_length
# domain_center: [0.000e+00 0.000e+00 1.475e-08] code_length
# domain_width(domain邊長): [3.20e-08 3.20e-08 2.95e-08] code_length
# domain_offset: [0 0 0]
# domain_dimensions(xyz方向各切成幾格): [64 64 59]
# dimensionality: 3
# geometry: cartesian
#
# ========== Fields ==========
#   ('boxlib', 'Ex')
#   ('boxlib', 'Ey')
#   ('boxlib', 'Ez')
#   ('boxlib', 'Phi')
#   ('boxlib', 'PhiDiff')
#   ('boxlib', 'PoissonRHS')
#   ('boxlib', 'Px')
#   ('boxlib', 'Py')
#   ('boxlib', 'Pz')
#   ('boxlib', 'alpha')
#   ('boxlib', 'beta')
#   ('boxlib', 'charge')
#   ('boxlib', 'electrons')
#   ('boxlib', 'epsilon')
#   ('boxlib', 'holes')
#   ('boxlib', 'mask')
#   ('boxlib', 'theta')
#   ('boxlib', 'tphase')

# %% [markdown]
# * domain切成多個grid分配給mpi rank平行運算，**資料分散在每個grid**

# %%
print("\n========== Grids ==========")
print("number of grids:", len(ds.index.grids))
for i, g in enumerate(ds.index.grids):
    print(f"grid {i}:")
    print("  LeftEdge:", g.LeftEdge)
    print("  RightEdge:", g.RightEdge)
    print("  ActiveDimensions:", g.ActiveDimensions)
    print("  Level:", g.Level)
print(ds.index.grid_start_index)
# Out:
# ========== Grids ==========
# number of grids: 16
# grid 0:
#   LeftEdge: [-1.6e-08 -1.6e-08  0.0e+00] code_length
#   RightEdge: [-8.00e-09 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 1:
#   LeftEdge: [-8.0e-09 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 0.00e+00 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 2:
#   LeftEdge: [ 0.0e+00 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 8.00e-09 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 3:
#   LeftEdge: [ 8.0e-09 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 1.60e-08 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 4:
#   LeftEdge: [-1.6e-08 -8.0e-09  0.0e+00] code_length
#   RightEdge: [-8.00e-09  0.00e+00  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 5:
#   LeftEdge: [-8.e-09 -8.e-09  0.e+00] code_length
#   RightEdge: [0.00e+00 0.00e+00 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 6:
#   LeftEdge: [ 0.e+00 -8.e-09  0.e+00] code_length
#   RightEdge: [8.00e-09 0.00e+00 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 7:
#   LeftEdge: [ 8.e-09 -8.e-09  0.e+00] code_length
#   RightEdge: [1.60e-08 0.00e+00 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 8:
#   LeftEdge: [-1.6e-08  0.0e+00  0.0e+00] code_length
#   RightEdge: [-8.00e-09  8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 9:
#   LeftEdge: [-8.e-09  0.e+00  0.e+00] code_length
#   RightEdge: [0.00e+00 8.00e-09 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 10:
#   LeftEdge: [0. 0. 0.] code_length
#   RightEdge: [8.00e-09 8.00e-09 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 11:
#   LeftEdge: [8.e-09 0.e+00 0.e+00] code_length
#   RightEdge: [1.60e-08 8.00e-09 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 12:
#   LeftEdge: [-1.6e-08  8.0e-09  0.0e+00] code_length
#   RightEdge: [-8.00e-09  1.60e-08  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 13:
#   LeftEdge: [-8.e-09  8.e-09  0.e+00] code_length
#   RightEdge: [0.00e+00 1.60e-08 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 14:
#   LeftEdge: [0.e+00 8.e-09 0.e+00] code_length
#   RightEdge: [8.00e-09 1.60e-08 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 15:
#   LeftEdge: [8.e-09 8.e-09 0.e+00] code_length
#   RightEdge: [1.60e-08 1.60e-08 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# [[ 0  0  0]
#  [16  0  0]
#  [32  0  0]
#  [48  0  0]
#  [ 0 16  0]
#  [16 16  0]
#  [32 16  0]
#  [48 16  0]
#  [ 0 32  0]
#  [16 32  0]
#  [32 32  0]
#  [48 32  0]
#  [ 0 48  0]
#  [16 48  0]
#  [32 48  0]
#  [48 48  0]]

# %% [markdown]
# ## **2Dfield繪製**

# %% [markdown]
# * g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
# * x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置

# %%
import yt
import numpy as np
import matplotlib.pyplot as plt
for i in range(len(plot_names)):
    plotfile = PLOT_DIR/plot_names[i] 
    field = ("boxlib", "Phi")

    ds = yt.load(plotfile)

    #g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
    Phi_array = read_full_field_from_grids(ds, field) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid

    print("Phi_array shape =", Phi_array.shape)

    Nx, Ny, Nz = Phi_array.shape #用index存資料

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dims = np.array([Nx, Ny, Nz])

    dx = (hi - lo) / dims

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    y0 = Ny // 2
    slice2d = Phi_array[:, y0, :]

    plt.figure(figsize=(6, 5))
    im = plt.pcolormesh(
        x_nm,
        z_nm,
        slice2d.T,
        shading="auto",
        cmap="RdBu"
    )

    plt.colorbar(im, label="Ex")
    plt.xlabel("x (nm)")
    plt.ylabel("z (nm)")
    plt.title(f"Phi x-z slice at y index = {y0}")
    plt.tight_layout()
    plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 18:13:49,051 Parameters: current_time              = 0.0
# yt : [INFO     ] 2026-05-29 18:13:49,053 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:49,054 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:49,054 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:49,338 Parameters: current_time              = 1.96e-11
# yt : [INFO     ] 2026-05-29 18:13:49,339 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:49,340 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:49,340 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:49,885 Parameters: current_time              = 3.280000000000006e-11
# yt : [INFO     ] 2026-05-29 18:13:49,886 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:49,886 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:49,887 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:50,126 Parameters: current_time              = 4.7800000000000296e-11
# yt : [INFO     ] 2026-05-29 18:13:50,126 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:50,127 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:50,128 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:50,364 Parameters: current_time              = 6.540000000000035e-11
# yt : [INFO     ] 2026-05-29 18:13:50,365 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:50,366 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:50,366 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:50,606 Parameters: current_time              = 8.7e-11
# yt : [INFO     ] 2026-05-29 18:13:50,607 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:50,607 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:50,608 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:50,868 Parameters: current_time              = 1.1539999999999953e-10
# yt : [INFO     ] 2026-05-29 18:13:50,869 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:50,870 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:50,871 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:51,155 Parameters: current_time              = 1.6020000000000163e-10
# yt : [INFO     ] 2026-05-29 18:13:51,155 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:51,156 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:51,157 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:51,435 Parameters: current_time              = 1.6722000000001457e-09
# yt : [INFO     ] 2026-05-29 18:13:51,435 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:51,436 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:51,436 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:51,684 Parameters: current_time              = 2.3920000000003665e-09
# yt : [INFO     ] 2026-05-29 18:13:51,685 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:51,685 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:51,686 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:52,264 Parameters: current_time              = 3.3826000000006703e-09
# yt : [INFO     ] 2026-05-29 18:13:52,265 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:52,266 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:52,266 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:52,500 Parameters: current_time              = 4.016000000000865e-09
# yt : [INFO     ] 2026-05-29 18:13:52,501 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:52,502 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:52,502 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:52,738 Parameters: current_time              = 5.426000000001297e-09
# yt : [INFO     ] 2026-05-29 18:13:52,739 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:52,740 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:52,740 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:52,969 Parameters: current_time              = 5.525800000001328e-09
# yt : [INFO     ] 2026-05-29 18:13:52,970 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:52,970 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:52,971 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:53,211 Parameters: current_time              = 6.223600000001542e-09
# yt : [INFO     ] 2026-05-29 18:13:53,212 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:53,213 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:53,213 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:53,448 Parameters: current_time              = 7.045000000001794e-09
# yt : [INFO     ] 2026-05-29 18:13:53,449 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:53,449 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:53,450 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:53,680 Parameters: current_time              = 7.1228000000018176e-09
# yt : [INFO     ] 2026-05-29 18:13:53,681 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:53,682 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:53,682 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:54,224 Parameters: current_time              = 7.2170000000018465e-09
# yt : [INFO     ] 2026-05-29 18:13:54,225 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:54,225 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:54,226 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:54,478 Parameters: current_time              = 7.382400000001897e-09
# yt : [INFO     ] 2026-05-29 18:13:54,478 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:54,479 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:54,479 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:54,718 Parameters: current_time              = 7.483200000001792e-09
# yt : [INFO     ] 2026-05-29 18:13:54,719 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:54,720 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:54,720 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:54,951 Parameters: current_time              = 7.586200000001398e-09
# yt : [INFO     ] 2026-05-29 18:13:54,951 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:54,952 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:54,953 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 18:13:55,204 Parameters: current_time              = 7.78960000000062e-09
# yt : [INFO     ] 2026-05-29 18:13:55,205 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:55,206 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:55,207 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)

# %%
import yt
import numpy as np
import matplotlib.pyplot as plt

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_plt")  # 改成你 plotfile 所在的資料夾
plotfile = PLOT_DIR/plot_names[2] 
field = ("boxlib", "Ex")

ds = yt.load(plotfile)

#g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
E_array = read_full_field_from_grids(ds, field) # 讀取整個 domain 的 Ex 資料，會自動合併多個 grid

print("E_array shape =", E_array.shape)

Nx, Ny, Nz = E_array.shape #用index存資料

lo = ds.domain_left_edge.to_value()
hi = ds.domain_right_edge.to_value()
dims = np.array([Nx, Ny, Nz])

dx = (hi - lo) / dims

x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置
z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

y0 = Ny // 2
slice2d = E_array[:, y0, :]

plt.figure(figsize=(6, 5))
im = plt.pcolormesh(
    x_nm,
    z_nm,
    slice2d.T,
    shading="auto",
    cmap="RdBu"
)

plt.colorbar(im, label="Ex")
plt.xlabel("x (nm)")
plt.ylabel("z (nm)")
plt.title(f"Ex x-z slice at y index = {y0}")
plt.tight_layout()
plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 18:13:55,489 Parameters: current_time              = 3.280000000000006e-11
# yt : [INFO     ] 2026-05-29 18:13:55,490 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:55,490 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:55,491 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# E_array shape = (64, 64, 59)

# %% [markdown]
# ## 2D Pz slice plot(all voltage in same graph)

# %%
from pathlib import Path
import re

import yt
import numpy as np
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec")          # plotfile 所在資料夾
P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")



USE_FE_X_RANGE = False

# y slice: None 表示取 y 方向正中間
Y_INDEX = None

# 若 plot_names 已經是你前面整理好的 steady-state plot list，就直接用
# plot_names = [...]
# 若沒有，就自動抓目前資料夾內所有 plt########
AUTO_FIND_PLOTS = False

# 跳過 initial plt00000000
SKIP_INITIAL = True

# 色階是否對稱於 0，畫 Pz 通常建議 True
SYMMETRIC_COLOR_SCALE = True

# 輸出圖片名稱
SAVE_FIG = True
OUT_FIG = PLOT_DIR/"Pz_FE_layer_stack.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


def read_one_plot(plotfile, y_index=None):
    ds = yt.load(str(plotfile))
    #g = ds.index.grids[0]

    P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

    if PHI_FIELD in ds.field_list:
        Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
    else:
        Phi = None

    Nx, Ny, Nz = P.shape

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    if y_index is None:
        y_index = Ny // 2

    # FE z range mask
    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    # P slice: shape after selection = (Nx_sel, Nz_sel)
    P_slice = P[np.ix_(x_sel, [y_index], z_sel)][:, 0, :]

    x_plot = x_nm[x_sel]
    z_plot = z_nm[z_sel]

    # 用最上層 cell 的 Phi 平均值當 top potential
    # 注意：這是 top cell center，不是真正 ghost boundary
    if Phi is not None:
        top_phi = Phi[:, :, -1]
        Vtop_mean = float(np.mean(top_phi))
        Vtop_min = float(np.min(top_phi))
        Vtop_max = float(np.max(top_phi))
    else:
        Vtop_mean = np.nan
        Vtop_min = np.nan
        Vtop_max = np.nan

    info = {
        "ds": ds,
        "P_slice": P_slice,
        "x_nm": x_plot,
        "z_nm": z_plot,
        "y_index": y_index,
        "y_nm": float(y_nm[y_index]),
        "Vtop_mean": Vtop_mean,
        "Vtop_min": Vtop_min,
        "Vtop_max": Vtop_max,
        "shape": P.shape,
    }

    return info


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

# sort by step if names are plt########
plot_names_use = sorted(plot_names_use, key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

print("Plotfiles to draw:")
for n in plot_names_use:
    print(" ", n)

records = []
all_values = []

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    info = read_one_plot(plotfile, y_index=Y_INDEX)

    step = get_step_from_name(name)

    records.append({
        "name": name,
        "step": step,
        **info,
    })

    all_values.append(info["P_slice"])

# shared color scale
all_concat = np.concatenate([v.ravel() for v in all_values])
if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(all_concat))
    vmin = -vmax
else:
    vmin = np.nanmin(all_concat)
    vmax = np.nanmax(all_concat)

# determine sweep direction from Vtop sequence
Vseq = np.array([r["Vtop_mean"] for r in records], dtype=float)

directions = []
for idx, V in enumerate(Vseq):
    if idx == 0 or not np.isfinite(Vseq[idx-1]) or not np.isfinite(V):
        directions.append("start")
    else:
        dV = V - Vseq[idx-1]
        if dV > 1e-8:
            directions.append("positive sweep")
        elif dV < -1e-8:
            directions.append("negative sweep")
        else:
            directions.append("same V")

# figure size
n = len(records)
fig_height = max(2.0 * n, 4.0)
fig, axes = plt.subplots(
    nrows=n,
    ncols=1,
    figsize=(7.5, fig_height),
    sharex=True,
    constrained_layout=True
)

if n == 1:
    axes = [axes]

last_im = None

for ax, rec, sweep_dir in zip(axes, records, directions):
    P_slice = rec["P_slice"]
    x_nm = rec["x_nm"]
    z_nm = rec["z_nm"]

    last_im = ax.pcolormesh(
        x_nm,
        z_nm,
        P_slice.T,
        shading="auto",
        cmap="RdBu",
        vmin=vmin,
        vmax=vmax
    )

    Vmean = rec["Vtop_mean"]
    Vmin = rec["Vtop_min"]
    Vmax = rec["Vtop_max"]

    if np.isfinite(Vmean):
        v_label = f"Vg = {Vmean:+.0f} V"
        # 若你想檢查 top x/y variation，也可以顯示 min/max
        # v_label += f" [{Vmin:+.3f}, {Vmax:+.3f}]"
    else:
        v_label = "Vtop unavailable"

    step_label = f"step={rec['step']}" if rec["step"] is not None else rec["name"]

    ax.set_ylabel("z (nm)")

    ax.set_title(
        f"{v_label} | {sweep_dir} | "
        f"y center ≈ {rec['y_nm']:.2f} nm",
        fontsize=9
    )

axes[-1].set_xlabel("x (nm)")

cbar = fig.colorbar(last_im, ax=axes, shrink=0.8)
cbar.set_label(r"Pz (C/m$^2$)")

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=200)
    print(f"Saved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 18:13:55,758 Parameters: current_time              = 1.96e-11
# yt : [INFO     ] 2026-05-29 18:13:55,759 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:55,759 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:55,760 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Plotfiles to draw:
#   plt00000098
#   plt00000164
#   plt00000239
#   plt00000327
#   plt00000435
#   plt00000577
#   plt00000801
#   plt00008361
#   plt00011960
#   plt00016913
#   plt00020080
#   plt00027130
#   plt00027629
#   plt00031118
#   plt00035225
#   plt00035614
#   plt00036085
#   plt00036912
#   plt00037416
#   plt00037931
#   plt00038948
# yt : [INFO     ] 2026-05-29 18:13:55,884 Parameters: current_time              = 3.280000000000006e-11
# yt : [INFO     ] 2026-05-29 18:13:55,885 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:55,885 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:55,886 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:55,998 Parameters: current_time              = 4.7800000000000296e-11
# yt : [INFO     ] 2026-05-29 18:13:55,999 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:56,000 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:56,000 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:56,427 Parameters: current_time              = 6.540000000000035e-11
# yt : [INFO     ] 2026-05-29 18:13:56,428 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:56,429 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:56,429 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:56,541 Parameters: current_time              = 8.7e-11
# yt : [INFO     ] 2026-05-29 18:13:56,543 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:56,543 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:56,544 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:56,654 Parameters: current_time              = 1.1539999999999953e-10
# yt : [INFO     ] 2026-05-29 18:13:56,654 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:56,655 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:56,655 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:56,766 Parameters: current_time              = 1.6020000000000163e-10
# yt : [INFO     ] 2026-05-29 18:13:56,767 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:56,768 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:56,769 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:56,879 Parameters: current_time              = 1.6722000000001457e-09
# yt : [INFO     ] 2026-05-29 18:13:56,880 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:56,880 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:56,881 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:56,996 Parameters: current_time              = 2.3920000000003665e-09
# yt : [INFO     ] 2026-05-29 18:13:56,997 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:56,998 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:56,998 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:57,117 Parameters: current_time              = 3.3826000000006703e-09
# yt : [INFO     ] 2026-05-29 18:13:57,118 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:57,119 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:57,119 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:57,232 Parameters: current_time              = 4.016000000000865e-09
# yt : [INFO     ] 2026-05-29 18:13:57,233 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:57,234 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:57,234 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:57,353 Parameters: current_time              = 5.426000000001297e-09
# yt : [INFO     ] 2026-05-29 18:13:57,353 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:57,354 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:57,355 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:57,467 Parameters: current_time              = 5.525800000001328e-09
# yt : [INFO     ] 2026-05-29 18:13:57,468 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:57,468 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:57,469 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:57,586 Parameters: current_time              = 6.223600000001542e-09
# yt : [INFO     ] 2026-05-29 18:13:57,587 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:57,587 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:57,588 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:57,703 Parameters: current_time              = 7.045000000001794e-09
# yt : [INFO     ] 2026-05-29 18:13:57,704 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:57,704 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:57,705 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:57,821 Parameters: current_time              = 7.1228000000018176e-09
# yt : [INFO     ] 2026-05-29 18:13:57,822 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:57,823 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:57,823 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:57,937 Parameters: current_time              = 7.2170000000018465e-09
# yt : [INFO     ] 2026-05-29 18:13:57,938 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:57,938 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:57,939 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:58,049 Parameters: current_time              = 7.382400000001897e-09
# yt : [INFO     ] 2026-05-29 18:13:58,050 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:58,050 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:58,051 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:58,161 Parameters: current_time              = 7.483200000001792e-09
# yt : [INFO     ] 2026-05-29 18:13:58,162 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:58,163 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:58,163 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:58,545 Parameters: current_time              = 7.586200000001398e-09
# yt : [INFO     ] 2026-05-29 18:13:58,546 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:58,546 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:58,547 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:13:58,660 Parameters: current_time              = 7.78960000000062e-09
# yt : [INFO     ] 2026-05-29 18:13:58,661 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:13:58,661 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:13:58,662 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/Pz_FE_layer_stack.png

# %% [markdown]
# ## 3D Scatter plot (all voltage in same graph)

# %% [markdown]
# * trash

# %%
from pathlib import Path
import re

import yt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec")

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 若 FE 只在部分 x/y 範圍，打開這裡
USE_FE_X_RANGE = False

USE_FE_Y_RANGE = False




# 用 top Phi 平均值四捨五入到整數電壓來分類
V_ROUND_DECIMALS = 0

# 3D 點太多會慢，STRIDE=2 表示 x/y/z 每 2 點取 1 點
# 若想更細可設 1；若很慢可設 3 或 4
STRIDE = 2

# 顏色是否以 0 對稱，畫 Pz 建議 True
SYMMETRIC_COLOR_SCALE = True

# 3D 視角
ELEV = 22
AZIM = -55

# 點大小
POINT_SIZE = 2

# 跳過 initial plt00000000
SKIP_INITIAL = True

# 若你已經有 plot_names，就保留 AUTO_FIND_PLOTS=False
# plot_names = [...]
AUTO_FIND_PLOTS = False

SAVE_FIG = True
OUT_FIG = PLOT_DIR/"Pz_FE_3D_2x11_sweep.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


def read_one_plot_3d(plotfile):
    ds = yt.load(str(plotfile))
    #g = ds.index.grids[0]

    P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

    if PHI_FIELD in ds.field_list:
        Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
    else:
        Phi = None

    Nx, Ny, Nz = P.shape

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    # FE selection
    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    if USE_FE_Y_RANGE:
        y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
    else:
        y_sel = np.ones_like(y_nm, dtype=bool)

    # Apply selection
    P_fe = P[np.ix_(x_sel, y_sel, z_sel)]

    x_fe = x_nm[x_sel]
    y_fe = y_nm[y_sel]
    z_fe = z_nm[z_sel]

    # Downsample for 3D plotting
    P_ds = P_fe[::STRIDE, ::STRIDE, ::STRIDE]
    x_ds = x_fe[::STRIDE]
    y_ds = y_fe[::STRIDE]
    z_ds = z_fe[::STRIDE]

    X, Y, Z = np.meshgrid(x_ds, y_ds, z_ds, indexing="ij")

    # Estimate top voltage from top cell Phi
    if Phi is not None:
        top_phi = Phi[:, :, -1]
        Vtop_mean = float(np.mean(top_phi))
        Vtop_min = float(np.min(top_phi))
        Vtop_max = float(np.max(top_phi))
    else:
        Vtop_mean = np.nan
        Vtop_min = np.nan
        Vtop_max = np.nan

    return {
        "P": P_ds,
        "X": X,
        "Y": Y,
        "Z": Z,
        "x_range": (float(np.min(x_fe)), float(np.max(x_fe))),
        "y_range": (float(np.min(y_fe)), float(np.max(y_fe))),
        "z_range": (float(np.min(z_fe)), float(np.max(z_fe))),
        "Vtop_mean": Vtop_mean,
        "Vtop_min": Vtop_min,
        "Vtop_max": Vtop_max,
        "shape_full": P.shape,
        "shape_fe": P_fe.shape,
        "shape_plot": P_ds.shape,
    }


def classify_sweep(records):
    """
    根據 records 原本的時間順序，用 Vtop 的變化判斷正掃/負掃。
    第一個點歸到 positive，因為通常是正掃起點。
    turning point 會同時加入 positive 與 negative，讓上下排都有 +5。
    """
    pos = []
    neg = []

    V = np.array([r["Vtop_mean"] for r in records], dtype=float)

    if len(records) == 0:
        return pos, neg

    pos.append(records[0])

    for i in range(1, len(records)):
        dV = V[i] - V[i - 1]

        if dV > 1e-8:
            pos.append(records[i])
        elif dV < -1e-8:
            # 如果剛從正掃轉負掃，把上一個 turning point 也放進 neg
            if len(neg) == 0:
                neg.append(records[i - 1])
            neg.append(records[i])
        else:
            # 同電壓重複時，不確定歸類；先放到目前方向
            if len(neg) == 0:
                pos.append(records[i])
            else:
                neg.append(records[i])

    return pos, neg


def pick_record_by_voltage(records, target_v):
    """
    從一組 records 中挑最接近 target_v 的那筆。
    """
    if len(records) == 0:
        return None

    V = np.array([r["Vround"] for r in records], dtype=float)
    idx = int(np.argmin(np.abs(V - target_v)))

    if np.abs(V[idx] - target_v) > 0.25:
        return None

    return records[idx]


def draw_3d_fe(ax, rec, norm, cmap):
    P = rec["P"]
    X = rec["X"]
    Y = rec["Y"]
    Z = rec["Z"]

    ax.scatter(
        X.ravel(),
        Y.ravel(),
        Z.ravel(),
        c=P.ravel(),
        cmap=cmap,
        norm=norm,
        s=POINT_SIZE,
        marker="s",
        linewidths=0,
        alpha=0.95,
    )

    ax.set_xlim(rec["x_range"])
    ax.set_ylim(rec["y_range"])
    ax.set_zlim(rec["z_range"])

    ax.view_init(elev=ELEV, azim=AZIM)

    # 22 張小圖，不要塞太多刻度
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])

    ax.set_box_aspect((
        rec["x_range"][1] - rec["x_range"][0],
        rec["y_range"][1] - rec["y_range"][0],
        rec["z_range"][1] - rec["z_range"][0],
    ))


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

plot_names_use = sorted(
    plot_names_use,
    key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99
)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

print("Plotfiles to read:")
for n in plot_names_use:
    print(" ", n)

records = []

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    info = read_one_plot_3d(plotfile)

    Vround = np.round(info["Vtop_mean"], V_ROUND_DECIMALS)

    rec = {
        "name": name,
        "step": get_step_from_name(name),
        "Vround": float(Vround),
        **info,
    }

    records.append(rec)

print("\nRead records:")
for r in records:
    print(
        f"{r['name']}  step={r['step']}  "
        f"Vtop={r['Vtop_mean']:+.4f} V  Vround={r['Vround']:+.0f}  "
        f"shape_fe={r['shape_fe']}  shape_plot={r['shape_plot']}"
    )

# classify positive / negative sweep from time ordering
pos_records, neg_records = classify_sweep(records)

print("\nPositive sweep records:")
for r in pos_records:
    print(f"  V={r['Vround']:+.0f}  {r['name']}")

print("\nNegative sweep records:")
for r in neg_records:
    print(f"  V={r['Vround']:+.0f}  {r['name']}")

# Arrange columns left-to-right by increasing voltage: -5, -4, ..., 5
pos_grid = [pick_record_by_voltage(pos_records, v) for v in VOLTAGES]
neg_grid = [pick_record_by_voltage(neg_records, v) for v in VOLTAGES]

# shared color scale from all selected records
selected_records = [r for r in pos_grid + neg_grid if r is not None]
if len(selected_records) == 0:
    raise RuntimeError("No records selected. Check plot_names or voltage classification.")

all_p = np.concatenate([r["P"].ravel() for r in selected_records])

if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(all_p))
    vmin = -vmax
else:
    vmin = np.nanmin(all_p)
    vmax = np.nanmax(all_p)

cmap = "RdBu"
norm = Normalize(vmin=vmin, vmax=vmax)

# 2 x 11 figure
fig = plt.figure(figsize=(22, 6.2))

axes = np.empty((2, len(VOLTAGES)), dtype=object)

for row in range(2):
    for col in range(len(VOLTAGES)):
        axes[row, col] = fig.add_subplot(
            2,
            len(VOLTAGES),
            row * len(VOLTAGES) + col + 1,
            projection="3d"
        )

for col, Vtarget in enumerate(VOLTAGES):
    rec = pos_grid[col]
    ax = axes[0, col]

    if rec is not None:
        draw_3d_fe(ax, rec, norm, cmap)
        ax.set_title(f"{Vtarget:+.0f} V\npos sweep", fontsize=9)
    else:
        ax.set_title(f"{Vtarget:+.0f} V\nmissing", fontsize=9)
        ax.axis("off")

for col, Vtarget in enumerate(VOLTAGES):
    rec = neg_grid[col]
    ax = axes[1, col]

    if rec is not None:
        draw_3d_fe(ax, rec, norm, cmap)
        ax.set_title(f"{Vtarget:+.0f} V\nneg sweep", fontsize=9)
    else:
        ax.set_title(f"{Vtarget:+.0f} V\nmissing", fontsize=9)
        ax.axis("off")

# row labels
fig.text(0.01, 0.72, "Positive sweep\n(-5 → +5)", va="center", ha="left", fontsize=12)
fig.text(0.01, 0.28, "Negative sweep\n(+5 → -5)\nshown as -5 → +5", va="center", ha="left", fontsize=12)

# shared colorbar
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])

cbar = fig.colorbar(
    sm,
    ax=axes.ravel().tolist(),
    shrink=0.75,
    pad=0.01,
    location="right"
)
cbar.set_label(r"Pz (C/m$^2$)")

fig.suptitle(
    "3D FE-layer Pz colormap | columns ordered by increasing applied voltage",
    fontsize=14
)

plt.tight_layout(rect=[0.04, 0.03, 0.94, 0.93])

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=200)
    print(f"\nSaved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 18:14:02,593 Parameters: current_time              = 1.96e-11
# yt : [INFO     ] 2026-05-29 18:14:02,593 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:02,594 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:02,594 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:02,706 Parameters: current_time              = 3.280000000000006e-11
# yt : [INFO     ] 2026-05-29 18:14:02,707 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:02,707 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:02,708 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Plotfiles to read:
#   plt00000098
#   plt00000164
#   plt00000239
#   plt00000327
#   plt00000435
#   plt00000577
#   plt00000801
#   plt00008361
#   plt00011960
#   plt00016913
#   plt00020080
#   plt00027130
#   plt00027629
#   plt00031118
#   plt00035225
#   plt00035614
#   plt00036085
#   plt00036912
#   plt00037416
#   plt00037931
#   plt00038948
# yt : [INFO     ] 2026-05-29 18:14:02,822 Parameters: current_time              = 4.7800000000000296e-11
# yt : [INFO     ] 2026-05-29 18:14:02,823 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:02,823 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:02,824 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:02,942 Parameters: current_time              = 6.540000000000035e-11
# yt : [INFO     ] 2026-05-29 18:14:02,943 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:02,944 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:02,944 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:03,519 Parameters: current_time              = 8.7e-11
# yt : [INFO     ] 2026-05-29 18:14:03,520 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:03,521 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:03,521 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:03,636 Parameters: current_time              = 1.1539999999999953e-10
# yt : [INFO     ] 2026-05-29 18:14:03,637 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:03,638 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:03,638 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:03,756 Parameters: current_time              = 1.6020000000000163e-10
# yt : [INFO     ] 2026-05-29 18:14:03,756 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:03,757 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:03,757 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:03,871 Parameters: current_time              = 1.6722000000001457e-09
# yt : [INFO     ] 2026-05-29 18:14:03,872 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:03,872 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:03,873 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:03,986 Parameters: current_time              = 2.3920000000003665e-09
# yt : [INFO     ] 2026-05-29 18:14:03,987 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:03,987 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:03,988 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:04,098 Parameters: current_time              = 3.3826000000006703e-09
# yt : [INFO     ] 2026-05-29 18:14:04,100 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:04,101 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:04,101 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:04,219 Parameters: current_time              = 4.016000000000865e-09
# yt : [INFO     ] 2026-05-29 18:14:04,220 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:04,221 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:04,221 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:04,333 Parameters: current_time              = 5.426000000001297e-09
# yt : [INFO     ] 2026-05-29 18:14:04,333 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:04,334 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:04,334 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:04,452 Parameters: current_time              = 5.525800000001328e-09
# yt : [INFO     ] 2026-05-29 18:14:04,453 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:04,453 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:04,454 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:04,569 Parameters: current_time              = 6.223600000001542e-09
# yt : [INFO     ] 2026-05-29 18:14:04,569 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:04,570 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:04,570 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:04,683 Parameters: current_time              = 7.045000000001794e-09
# yt : [INFO     ] 2026-05-29 18:14:04,683 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:04,684 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:04,685 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:04,791 Parameters: current_time              = 7.1228000000018176e-09
# yt : [INFO     ] 2026-05-29 18:14:04,792 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:04,793 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:04,793 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:04,902 Parameters: current_time              = 7.2170000000018465e-09
# yt : [INFO     ] 2026-05-29 18:14:04,902 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:04,903 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:04,903 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:05,017 Parameters: current_time              = 7.382400000001897e-09
# yt : [INFO     ] 2026-05-29 18:14:05,018 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:05,018 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:05,019 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:05,123 Parameters: current_time              = 7.483200000001792e-09
# yt : [INFO     ] 2026-05-29 18:14:05,124 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:05,125 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:05,125 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:05,232 Parameters: current_time              = 7.586200000001398e-09
# yt : [INFO     ] 2026-05-29 18:14:05,234 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:05,234 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:05,235 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:05,673 Parameters: current_time              = 7.78960000000062e-09
# yt : [INFO     ] 2026-05-29 18:14:05,674 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:05,675 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:05,675 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read records:
# plt00000098  step=98  Vtop=-5.0867 V  Vround=-5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000164  step=164  Vtop=-4.0911 V  Vround=-4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000239  step=239  Vtop=-3.0943 V  Vround=-3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000327  step=327  Vtop=-2.0960 V  Vround=-2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000435  step=435  Vtop=-1.0958 V  Vround=-1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000577  step=577  Vtop=-0.0925 V  Vround=-0  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000801  step=801  Vtop=+0.9166 V  Vround=+1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00008361  step=8361  Vtop=+2.0200 V  Vround=+2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00011960  step=11960  Vtop=+3.0234 V  Vround=+3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00016913  step=16913  Vtop=+4.0258 V  Vround=+4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00020080  step=20080  Vtop=+5.0300 V  Vround=+5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00027130  step=27130  Vtop=+4.0246 V  Vround=+4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00027629  step=27629  Vtop=+3.0245 V  Vround=+3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00031118  step=31118  Vtop=+2.0200 V  Vround=+2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00035225  step=35225  Vtop=+1.0154 V  Vround=+1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00035614  step=35614  Vtop=+0.0155 V  Vround=+0  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00036085  step=36085  Vtop=-0.9844 V  Vround=-1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00036912  step=36912  Vtop=-1.9878 V  Vround=-2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00037416  step=37416  Vtop=-2.9934 V  Vround=-3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00037931  step=37931  Vtop=-3.9936 V  Vround=-4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00038948  step=38948  Vtop=-4.9978 V  Vround=-5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
#
# Positive sweep records:
#   V=-5  plt00000098
#   V=-4  plt00000164
#   V=-3  plt00000239
#   V=-2  plt00000327
#   V=-1  plt00000435
#   V=-0  plt00000577
#   V=+1  plt00000801
#   V=+2  plt00008361
#   V=+3  plt00011960
#   V=+4  plt00016913
#   V=+5  plt00020080
#
# Negative sweep records:
#   V=+5  plt00020080
#   V=+4  plt00027130
#   V=+3  plt00027629
#   V=+2  plt00031118
#   V=+1  plt00035225
#   V=+0  plt00035614
#   V=-1  plt00036085
#   V=-2  plt00036912
#   V=-3  plt00037416
#   V=-4  plt00037931
#   V=-5  plt00038948
# /tmp/ipykernel_694794/2315896281.py:387: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0.04, 0.03, 0.94, 0.93])
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/Pz_FE_3D_2x11_sweep.png

# %% [markdown]
# ## 3D Contour plot

# %% [markdown]
# * 畫出長方體三個面
# * 選擇要畫的三個面C1,C2,C3
# * 選擇視角

# %%
from pathlib import Path

import yt
import numpy as np
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_plt")
   # 改成你要畫的 plotfile

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 如果 FE 只想取部分 x/y 範圍
USE_FE_X_RANGE = False


USE_FE_Y_RANGE = False


# contour levels
N_LEVELS = 21

# 視角
ELEV = 35
AZIM = -45

# 色階是否對稱於 0
SYMMETRIC_COLOR_SCALE = True

SAVE_FIG= True
OUT_FIG = PLOT_DIR/"Pz_FE_3D_contour.png"

# ==========================
# Helper
# ==========================

def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


# ==========================
# Load data
# ==========================

plotfile = PLOT_DIR / PLOTFILE_NAME
ds = yt.load(str(plotfile))
g = ds.index.grids[0]

P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

if PHI_FIELD in ds.field_list:
    Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
else:
    Phi = None

Nx, Ny, Nz = P.shape

lo = ds.domain_left_edge.to_value()
hi = ds.domain_right_edge.to_value()
dx = (hi - lo) / np.array([Nx, Ny, Nz])

x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9


# ==========================
# Select FE layer
# ==========================

z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

if USE_FE_X_RANGE:
    x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
else:
    x_sel = np.ones_like(x_nm, dtype=bool)

if USE_FE_Y_RANGE:
    y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
else:
    y_sel = np.ones_like(y_nm, dtype=bool)

P_fe = P[np.ix_(x_sel, y_sel, z_sel)]

x_fe = x_nm[x_sel]
y_fe = y_nm[y_sel]
z_fe = z_nm[z_sel]

Nx_fe, Ny_fe, Nz_fe = P_fe.shape

# 選三個切面：
# xy plane at top FE surface
k_top = Nz_fe - 1

# xz plane at y min side
#j_mid = Ny_fe // 2

# yz plane at x max side
i_right = Nx_fe - 1

P_xy = P_fe[:, :, k_top]      # shape (Nx, Ny)
P_xz = P_fe[:, 0, :]      # shape (Nx, Nz)
P_yz = P_fe[i_right, :, :]    # shape (Ny, Nz)

# 建立 2D coordinates
X_xy, Y_xy = np.meshgrid(x_fe, y_fe, indexing="ij")
X_xz, Z_xz = np.meshgrid(x_fe, z_fe, indexing="ij")
Y_yz, Z_yz = np.meshgrid(y_fe, z_fe, indexing="ij")


# ==========================
# Voltage label
# ==========================

if Phi is not None:
    top_phi = Phi[:, :, -1]
    Vtop_mean = float(np.mean(top_phi))
else:
    Vtop_mean = np.nan


# ==========================
# Color scale
# ==========================

if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(P_fe))
    vmin = -vmax
else:
    vmin = np.nanmin(P_fe)
    vmax = np.nanmax(P_fe)

levels = np.linspace(vmin, vmax, N_LEVELS)

kw = dict(
    levels=levels,
    vmin=vmin,
    vmax=vmax,
    cmap="RdBu",
)


# ==========================
# Plot 3D contour walls
# ==========================

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection="3d")

xmin, xmax = x_fe.min(), x_fe.max()
ymin, ymax = y_fe.min(), y_fe.max()
zmin, zmax = z_fe.min(), z_fe.max()

# 1. xy plane, placed at z = zmax
# contourf expects arrays with same shape.
# X_xy/Y_xy/P_xy are (Nx, Ny)
C1 = ax.contourf(
    X_xy,
    Y_xy,
    P_xy,
    zdir="z",
    offset=zmax,
    **kw
)

# 2. xz plane, placed at y = ymin
# Here x-axis is X_xz, vertical is Z_xz, color is P_xz
C2 = ax.contourf(
    X_xz,
    P_xz,
    Z_xz,
    zdir="y",
    offset=ymin,
    **kw
)

# 3. yz plane, placed at x = xmax
# Here horizontal axis is Y_yz, vertical is Z_yz, color is P_yz
C3 = ax.contourf(
    P_yz,
    Y_yz,
    Z_yz,
    zdir="x",
    offset=xmax,
    **kw
)

# Set axis limits
ax.set(
    xlim=[xmin, xmax],
    ylim=[ymin, ymax],
    zlim=[zmin, zmax],
)

# Draw box edges
edges_kw = dict(color="0.35", linewidth=1.0, zorder=1000)

# 只畫可見的外框邊，不畫背後被內容遮住的線
visible_edges = [
    # bottom/front-ish edges
    ([xmin, xmax], [ymin, ymin], [zmin, zmin]),
    ([xmax, xmax], [ymin, ymax], [zmin, zmin]),
    ([xmax, xmax], [ymin, ymin], [zmin, zmax]),

    # top/front-ish edges
    ([xmin, xmax], [ymin, ymin], [zmax, zmax]),
    ([xmax, xmax], [ymin, ymax], [zmax, zmax]),
    ([xmax, xmax], [ymin, ymin], [zmin, zmax]),
]

for xs, ys, zs in visible_edges:
    ax.plot(xs, ys, zs, **edges_kw)
ax.set_xlabel("x (nm)")
ax.set_ylabel("y (nm)")
ax.set_zlabel("z (nm)")

ax.view_init(ELEV, AZIM)
Z_VISUAL_SCALE = 2.5
ax.set_box_aspect((
    xmax - xmin,
    ymax - ymin,
    Z_VISUAL_SCALE * (zmax - zmin)
))

ax.set_title(
    f"{PLOTFILE_NAME}\n"
    f"FE-layer Pz contour walls | Vg ≈ {Vtop_mean:+.3f} V"
)

cbar = fig.colorbar(C3, ax=ax, fraction=0.035, pad=0.12)
cbar.set_label(r"Pz (C/m$^2$)")

plt.tight_layout()

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=300)
    print(f"\nSaved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 18:14:12,948 Parameters: current_time              = 4.016000000000865e-09
# yt : [INFO     ] 2026-05-29 18:14:12,949 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:12,950 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:12,950 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/Pz_FE_3D_contour.png

# %% [markdown]
# ## PV

# %%
from pathlib import Path
import re

import yt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_1_plt")

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 如果 FE 是全幅 MFIS，通常不用限制 x/y
USE_FE_X_RANGE = False


USE_FE_Y_RANGE = False
# 若你已經有 steady-state plot_names，就用 AUTO_FIND_PLOTS=False
# plot_names = [...]
AUTO_FIND_PLOTS = True

# 如果沒有 plot_names，可以自動找所有 plt########
# 但建議最好只用 steady-state plotfiles
SKIP_INITIAL = True

OUT_CSV = PLOT_DIR/"MFIS_PV_curve.csv"
OUT_FIG = PLOT_DIR/"MFIS_PV_curve.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v

def read_full_field_from_grids(ds, field):
    """
    Read a cell-centered AMReX field from all yt grids
    and stitch them into one full-domain numpy array.

    Return:
        full: numpy array with shape ds.domain_dimensions
    """
    dims = np.array(ds.domain_dimensions, dtype=int)
    full = np.empty(tuple(dims), dtype=float)

    domain_lo = ds.domain_left_edge.to_value()
    domain_hi = ds.domain_right_edge.to_value()
    dx = (domain_hi - domain_lo) / dims

    for grid in ds.index.grids:
        arr = to_numpy(grid[field])

        left = grid.LeftEdge.to_value()

        # grid start index in global domain
        start = np.rint((left - domain_lo) / dx).astype(int)

        nx, ny, nz = arr.shape
        i0, j0, k0 = start
        i1, j1, k1 = i0 + nx, j0 + ny, k0 + nz

        full[i0:i1, j0:j1, k0:k1] = arr

    return full

def read_pv_from_plot(plotfile):
    ds = yt.load(str(plotfile))
    Pz = read_full_field_from_grids(ds, P_FIELD)
    Phi = read_full_field_from_grids(ds, PHI_FIELD)

    Nx, Ny, Nz = Pz.shape
    print(f"Read Pz with shape {Pz.shape} from {plotfile}")

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    print(f"Domain: x [{lo[0]:.3e}, {hi[0]:.3e}] m, "
          f"y [{lo[1]:.3e}, {hi[1]:.3e}] m, "
          f"z [{lo[2]:.3e}, {hi[2]:.3e}] m")
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    if USE_FE_Y_RANGE:
        y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
    else:
        y_sel = np.ones_like(y_nm, dtype=bool)

    Pz_FE = Pz[np.ix_(x_sel, y_sel, z_sel)]

    P_mean = float(np.mean(Pz_FE))
    P_min = float(np.min(Pz_FE))
    P_max = float(np.max(Pz_FE))
    P_std = float(np.std(Pz_FE))

    # 用最上層 cell 的 Phi 平均值估 top electrode potential
    # 注意：這是 top cell center，不是真正 ghost boundary
    top_phi = Phi[:, :, -1]
    Vg_mean = float(np.mean(top_phi))
    Vg_min = float(np.min(top_phi))
    Vg_max = float(np.max(top_phi))
    Vg_std = float(np.std(top_phi))

    return {
        "P_mean": P_mean,
        "P_min": P_min,
        "P_max": P_max,
        "P_std": P_std,
        "Vg_mean": Vg_mean,
        "Vg_min": Vg_min,
        "Vg_max": Vg_max,
        "Vg_std": Vg_std,
        "Nx": Nx,
        "Ny": Ny,
        "Nz": Nz,
        "num_FE_cells": int(Pz_FE.size),
    }


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    print(f"Finding plotfiles in {PLOT_DIR}...")
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

plot_names_use = sorted(
    plot_names_use,
    key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99
)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

rows = []

print(plot_names_use)

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    step = get_step_from_name(name)

    info = read_pv_from_plot(plotfile)

    rows.append({
        "plotfile": name,
        "step": step,
        **info,
    })

    print(
        f"{name} | step={step} | "
        f"Vg={info['Vg_mean']:+.4f} V | "
        f"<Pz>_FE={info['P_mean']:+.6e}"
    )

df = pd.DataFrame(rows)
df.to_csv(OUT_CSV, index=False)
print(f"Saved CSV: {OUT_CSV}")


# ==========================
# Determine sweep direction
# ==========================

V = df["Vg_mean"].to_numpy()
P = df["P_mean"].to_numpy()


direction = np.zeros_like(V)

for i in range(1, len(V)):
    dV = V[i] - V[i - 1]
    if dV > 1e-8:
        direction[i] = 1   # positive sweep
    elif dV < -1e-8:
        direction[i] = -1  # negative sweep
    else:
        direction[i] = direction[i - 1]

#np.append(direction, direction[-1])  # 複製第一筆到最後

df["sweep_direction"] = direction
df.to_csv(OUT_CSV, index=False)
# Out:
# yt : [INFO     ] 2026-05-29 18:14:13,592 Parameters: current_time              = 1.96e-11
# yt : [INFO     ] 2026-05-29 18:14:13,593 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:13,593 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:13,594 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Finding plotfiles in /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt...
# ['plt00000098', 'plt00000164', 'plt00000239', 'plt00000327', 'plt00000435', 'plt00000577', 'plt00000801', 'plt00008361', 'plt00011960', 'plt00016913', 'plt00020080', 'plt00027130', 'plt00027629', 'plt00031118', 'plt00035225', 'plt00035614', 'plt00036085', 'plt00036912', 'plt00037416', 'plt00037931', 'plt00038948']
# yt : [INFO     ] 2026-05-29 18:14:13,708 Parameters: current_time              = 3.280000000000006e-11
# yt : [INFO     ] 2026-05-29 18:14:13,708 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:13,709 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:13,709 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00000098
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000098 | step=98 | Vg=-5.0867 V | <Pz>_FE=+2.102149e-01
# yt : [INFO     ] 2026-05-29 18:14:14,167 Parameters: current_time              = 4.7800000000000296e-11
# yt : [INFO     ] 2026-05-29 18:14:14,168 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:14,168 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:14,169 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:14,277 Parameters: current_time              = 6.540000000000035e-11
# yt : [INFO     ] 2026-05-29 18:14:14,277 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:14,278 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:14,278 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00000164
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000164 | step=164 | Vg=-4.0911 V | <Pz>_FE=+2.026026e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00000239
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000239 | step=239 | Vg=-3.0943 V | <Pz>_FE=+1.941537e-01
# yt : [INFO     ] 2026-05-29 18:14:14,392 Parameters: current_time              = 8.7e-11
# yt : [INFO     ] 2026-05-29 18:14:14,393 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:14,393 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:14,394 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:14,503 Parameters: current_time              = 1.1539999999999953e-10
# yt : [INFO     ] 2026-05-29 18:14:14,503 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:14,504 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:14,504 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00000327
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000327 | step=327 | Vg=-2.0960 V | <Pz>_FE=+1.845859e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00000435
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000435 | step=435 | Vg=-1.0958 V | <Pz>_FE=+1.734153e-01
# yt : [INFO     ] 2026-05-29 18:14:14,613 Parameters: current_time              = 1.6020000000000163e-10
# yt : [INFO     ] 2026-05-29 18:14:14,613 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:14,614 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:14,614 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:14,723 Parameters: current_time              = 1.6722000000001457e-09
# yt : [INFO     ] 2026-05-29 18:14:14,725 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:14,725 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:14,726 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00000577
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000577 | step=577 | Vg=-0.0925 V | <Pz>_FE=+1.596732e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00000801
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000801 | step=801 | Vg=+0.9166 V | <Pz>_FE=+1.407351e-01
# yt : [INFO     ] 2026-05-29 18:14:14,834 Parameters: current_time              = 2.3920000000003665e-09
# yt : [INFO     ] 2026-05-29 18:14:14,835 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:14,835 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:14,836 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:14,945 Parameters: current_time              = 3.3826000000006703e-09
# yt : [INFO     ] 2026-05-29 18:14:14,945 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:14,946 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:14,946 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00008361
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00008361 | step=8361 | Vg=+2.0200 V | <Pz>_FE=-3.537357e-02
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00011960
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00011960 | step=11960 | Vg=+3.0234 V | <Pz>_FE=-5.964483e-02
# yt : [INFO     ] 2026-05-29 18:14:15,055 Parameters: current_time              = 4.016000000000865e-09
# yt : [INFO     ] 2026-05-29 18:14:15,056 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:15,056 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:15,057 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:15,164 Parameters: current_time              = 5.426000000001297e-09
# yt : [INFO     ] 2026-05-29 18:14:15,165 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:15,166 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:15,167 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00016913
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00016913 | step=16913 | Vg=+4.0258 V | <Pz>_FE=-8.332748e-02
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00020080
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00020080 | step=20080 | Vg=+5.0300 V | <Pz>_FE=-1.120265e-01
# yt : [INFO     ] 2026-05-29 18:14:15,275 Parameters: current_time              = 5.525800000001328e-09
# yt : [INFO     ] 2026-05-29 18:14:15,276 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:15,277 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:15,277 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:15,384 Parameters: current_time              = 6.223600000001542e-09
# yt : [INFO     ] 2026-05-29 18:14:15,385 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:15,386 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:15,386 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00027130
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00027130 | step=27130 | Vg=+4.0246 V | <Pz>_FE=-8.223359e-02
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00027629
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00027629 | step=27629 | Vg=+3.0245 V | <Pz>_FE=-6.072433e-02
# yt : [INFO     ] 2026-05-29 18:14:15,494 Parameters: current_time              = 7.045000000001794e-09
# yt : [INFO     ] 2026-05-29 18:14:15,495 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:15,496 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:15,496 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:15,603 Parameters: current_time              = 7.1228000000018176e-09
# yt : [INFO     ] 2026-05-29 18:14:15,604 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:15,605 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:15,605 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00031118
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00031118 | step=31118 | Vg=+2.0200 V | <Pz>_FE=-3.509942e-02
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00035225
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00035225 | step=35225 | Vg=+1.0154 V | <Pz>_FE=-9.625756e-03
# yt : [INFO     ] 2026-05-29 18:14:15,714 Parameters: current_time              = 7.2170000000018465e-09
# yt : [INFO     ] 2026-05-29 18:14:15,715 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:15,715 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:15,716 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00035614
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00035614 | step=35614 | Vg=+0.0155 V | <Pz>_FE=-5.638333e-05
# yt : [INFO     ] 2026-05-29 18:14:16,138 Parameters: current_time              = 7.382400000001897e-09
# yt : [INFO     ] 2026-05-29 18:14:16,139 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:16,139 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:16,140 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:16,249 Parameters: current_time              = 7.483200000001792e-09
# yt : [INFO     ] 2026-05-29 18:14:16,250 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:16,250 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:16,251 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00036085
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00036085 | step=36085 | Vg=-0.9844 V | <Pz>_FE=+8.887416e-03
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00036912
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00036912 | step=36912 | Vg=-1.9878 V | <Pz>_FE=+3.387642e-02
# yt : [INFO     ] 2026-05-29 18:14:16,369 Parameters: current_time              = 7.586200000001398e-09
# yt : [INFO     ] 2026-05-29 18:14:16,370 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:16,370 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:16,371 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 18:14:16,491 Parameters: current_time              = 7.78960000000062e-09
# yt : [INFO     ] 2026-05-29 18:14:16,492 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 18:14:16,493 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 18:14:16,494 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00037416
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00037416 | step=37416 | Vg=-2.9934 V | <Pz>_FE=+5.914409e-02
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00037931
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00037931 | step=37931 | Vg=-3.9936 V | <Pz>_FE=+8.014763e-02
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/plt00038948
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00038948 | step=38948 | Vg=-4.9978 V | <Pz>_FE=+1.089965e-01
# Saved CSV: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/MFIS_PV_curve.csv

# %%
def sci_tex(x, sig=2):
    """Return LaTeX like 1.23\\times10^{-4} (no 'e')."""
    if x == 0:
        return r"0"
    exp = int(np.floor(np.log10(abs(x))))
    mant = x / (10 ** exp)
    return rf"{mant:.{sig}f}\times 10^{{{exp}}}"

# ==========================
# Plot PV curve
# ==========================

plt.figure(figsize=(6, 5))

textstr = '\n'.join((
    r'In SI units:',
    rf'$\alpha={sci_tex(ALPHA, sig=2)}$',
    rf'$\beta={sci_tex(BETA, sig=2)}$',
    rf'$\gamma={sci_tex(SMALL_GAMMA, sig=2)}$',
    rf'$g_{{11}}={sci_tex(G11, sig=2)}$',
    rf'$g_{{44}}={sci_tex(G44, sig=2)}$',
    rf'$t_{{fe}}={sci_tex((FE_Z_HI_NM-FE_Z_LO_NM)*1e-9, sig=2)}$',
))

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
plt.text(-5, -0.005, textstr, fontsize=12,
        verticalalignment='top', bbox=props)

# time-order full loop
plt.plot(V, P, "-o", markersize=4, linewidth=1.2, label="time order")

# optional: highlight positive / negative sweep
pos = df["sweep_direction"].to_numpy() >= 0
neg = df["sweep_direction"].to_numpy() < 0

if np.any(pos):
    plt.plot(V[pos], P[pos], "o", markersize=5, label="positive sweep")

if np.any(neg):
    plt.plot(V[neg], P[neg], "s", markersize=5, label="negative sweep")

plt.axhline(0, linewidth=0.8)
plt.axvline(0, linewidth=0.8)

plt.xlabel(r"$V_g$ (V)")
plt.ylabel(r"$\langle P_z \rangle_\mathrm{FE}$ (C/m$^2$)")
plt.title("MFIS P-V Curve")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

plt.savefig(OUT_FIG, dpi=200)
print(f"Saved figure: {OUT_FIG}")

plt.show()
# Out:
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_6_plt/MFIS_PV_curve.png
