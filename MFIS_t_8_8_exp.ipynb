# %% [markdown]
# # 本次模擬cmd log資訊
#
# * 2026/05/29（20點）開始模擬
# * 只保留最後一個iteration(1853)的迭代資訊和AMReX finalize(如下)

# %% [markdown]
# MLMG: Initial rhs               = 546504261.5
# MLMG: Initial residual (resid0) = 8500032522
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.001470077528, 1.729496357e-13
# MLMG: Timers: Solve = 0.806847835 Iter = 0.802902916 Bottom = 0.796813341
# 1 iterations :: err = 1
# MLMG: Initial rhs               = 546504261.5
# MLMG: Initial residual (resid0) = 8500032522
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.0004759900079, 5.59986102e-14
# MLMG: Timers: Solve = 0.81080057 Iter = 0.806846013 Bottom = 0.800838711
# 2 iterations :: err = 3.718542828e-11
# Steady state check : (phi(t) - phi(t-1)).norm0() = 8.486500976e-08
# Advanced step 1853 in 1.699021871 seconds
#
# step = 1853, Phi_Bc_hi = -4, num_Vapp = 21, sign = 1
# MLMG: Initial rhs               = 546504413.5
# MLMG: Initial residual (resid0) = 6800832518
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.002540775298, 3.73597687e-13
# MLMG: Timers: Solve = 0.815492866 Iter = 0.811604799 Bottom = 0.805517737
# 1 iterations :: err = 1
# MLMG: Initial rhs               = 546504413.5
# MLMG: Initial residual (resid0) = 6800832518
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.002265312136, 3.330933574e-13
# MLMG: Timers: Solve = 0.830834132 Iter = 0.826895639 Bottom = 0.820756265
# 2 iterations :: err = 2.044390748e-05
# MLMG: Initial rhs               = 546504413.5
# MLMG: Initial residual (resid0) = 6800832518
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.002085980217, 3.067242447e-13
# MLMG: Timers: Solve = 0.811910135 Iter = 0.80797653 Bottom = 0.801893729
# 3 iterations :: err = 4.001795054e-09
# voltage_sweep == 1 && num_Vapp == num_Vapp_max!
# High-water FAB megabyte spread across MPI nodes: [44 ... 44]
# Current     FAB megabyte spread across MPI nodes: [34 ... 34]
# Total run time 3422.663947 seconds
#
#
# TinyProfiler total time across processes [min...avg...max]: 3423 ... 3423 ... 3423
#
# ---------------------------------------------------------------------------------------------
# Name                                          NCalls  Excl. Min  Excl. Avg  Excl. Max   Max %
# ---------------------------------------------------------------------------------------------
# amrex::Dot()                                 2113844      698.8      705.8      718.4  20.99%
# MLABecLaplacian::Fapply()                    1072108      411.6      417.9      425.6  12.43%
# MLABecLaplacian::normalize()                 1068311      417.4      421.6      425.1  12.42%
# MLCGSolver::ParallelAllReduce                2657415      331.4      360.9      394.6  11.53%
# FabArray::norminf()                          1091000      374.2      374.5      375.1  10.96%
# FillBoundary_finish()                        1087051      338.4      340.4      342.4  10.00%
# FillBoundary_nowait()                        1087051      256.1      269.7      285.6   8.34%
# FabArray::Saxpy_Saxpy()                       532182      104.6      111.4      124.5   3.64%
# FabArray::Saypy_Saxpy()                       524740      100.4      107.2      124.2   3.63%
# FabArray::Saxpy_Xpay()                        520793      92.45      96.54      100.1   2.93%
# ComputePhi_Rho()                                1874      35.68      39.37      46.69   1.36%
# amrex::Copy()                                  62935      25.19      30.03      32.27   0.94%
# FabArray::setVal()                             70133      28.27       28.5      28.75   0.84%
# Calculate_Landau()                              1853      25.16      25.93      26.67   0.78%
# Calculate_Grad()                                1853      12.81       13.4      13.96   0.41%
# MLCGSolver::bicgstab                           11389      13.13      13.14      13.16   0.38%
# ComputeEfromPhi()                               3706      7.474      8.986      10.53   0.31%
# FabArray::LinComb()                             9356      6.156      8.437      9.583   0.28%
# MLCellLinOp::applyBC()                       1072108      8.721      8.746      8.771   0.26%
# Calculate_Elec()                                1853      3.621      5.924      8.358   0.24%
# FabArray::FillBoundary()                     1087051      4.621      4.623      4.624   0.14%
# MLCellLinOp::apply()                         1072108      4.553      4.555      4.557   0.13%
# main()                                             1      2.858      3.435      3.902   0.11%
# MLMG::ResNormInf()                             15186      1.122      1.527      1.829   0.05%
# MLMG::solve()                                   3797     0.4761     0.6769      0.774   0.02%
# MLMG::actualBottomSolve()                      11389     0.1064     0.1071     0.1075   0.00%
# MLCellLinOp::solutionResidual()                15186    0.06473    0.06476    0.06479   0.00%
# MLMG::oneIter()                                11389    0.05123      0.052    0.05227   0.00%
# MLMG::mgVcycle_bottom                          11389    0.03346    0.03368    0.03423   0.00%
# MLMG::computeResidual()                        11389    0.03252    0.03255    0.03259   0.00%
# MLMG::mgVcycle()                               11389    0.03183    0.03192     0.0321   0.00%
# MLMG::computeMLResidual()                       3797    0.01075    0.01077     0.0108   0.00%
# Other                                        1161371      18.44      19.25      20.05   0.59%
# ---------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------
# Name                                          NCalls  Incl. Min  Incl. Avg  Incl. Max   Max %
# ---------------------------------------------------------------------------------------------
# main()                                             1       3423       3423       3423 100.00%
# ComputePhi_Rho()                                1874       3349       3349       3349  97.85%
# MLMG::solve()                                   3797       3268       3268       3269  95.50%
# MLMG::oneIter()                                11389       3233       3233       3233  94.47%
# MLMG::mgVcycle()                               11389       3231       3231       3231  94.39%
# MLMG::mgVcycle_bottom                          11389       3231       3231       3231  94.39%
# MLMG::actualBottomSolve()                      11389       3231       3231       3231  94.39%
# MLCGSolver::bicgstab                           11389       3228       3229       3229  94.34%
# MLCellLinOp::apply()                         1072108       1019       1039       1064  31.08%
# amrex::Dot()                                 2113844      698.8      705.8      718.4  20.99%
# MLCGSolver::ParallelAllReduce                2657415      652.9      684.4      713.8  20.86%
# FabArray::FillBoundary()                     1087051      603.1      616.3      634.1  18.53%
# MLCellLinOp::applyBC()                       1072108      603.3      616.2      633.8  18.52%
# MLABecLaplacian::Fapply()                    1072108      411.6      417.9      425.6  12.43%
# MLABecLaplacian::normalize()                 1068311      417.4      421.6      425.1  12.42%
# FabArray::norminf()                          1091000      374.2      374.5      375.1  10.96%
# FillBoundary_finish()                        1087051      338.4      340.4      342.4  10.00%
# FillBoundary_nowait()                        1087051      257.6      271.3      287.1   8.39%
# FabArray::Saxpy_Saxpy()                       532182      104.6      111.4      124.5   3.64%
# FabArray::Saypy_Saxpy()                       524740      100.4      107.2      124.2   3.63%
# FabArray::Saxpy_Xpay()                        520793      92.45      96.54      100.1   2.93%
# amrex::Copy()                                  62935      25.19      30.03      32.27   0.94%
# FabArray::setVal()                             70133      28.27       28.5      28.75   0.84%
# Calculate_Landau()                              1853      25.16      25.93      26.67   0.78%
# MLCellLinOp::solutionResidual()                15186      22.64      22.64      22.66   0.66%
# MLMG::computeResidual()                        11389      15.56      15.57      15.57   0.45%
# Calculate_Grad()                                1853      12.81       13.4      13.96   0.41%
# ComputeEfromPhi()                               3706      7.474      8.986      10.53   0.31%
# FabArray::LinComb()                             9356      6.156      8.437      9.583   0.28%
# Calculate_Elec()                                1853      3.621      5.924      8.358   0.24%
# MLMG::computeMLResidual()                       3797      7.117      7.123      7.135   0.21%
# MLMG::ResNormInf()                             15186      6.108      6.479      6.773   0.20%
# Other                                        1161371       28.4      29.19      30.02   0.88%
# ---------------------------------------------------------------------------------------------
#
# Device Memory Usage:
# ----------------------------------------------------------------------------------------------------------------------------
# Name                                          Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ----------------------------------------------------------------------------------------------------------------------------
# The_Arena::Initialize()                            4       0   B       0   B       0   B     731 MiB     731 MiB     731 MiB
# main()                                           976      29 MiB      29 MiB      29 MiB      30 MiB      30 MiB      30 MiB
# WritePlotfile()                                  352    2091   B    2115   B    2180   B    8496 KiB    8496 KiB    8496 KiB
# ResizeRandomSeed                                   8    4607 KiB    4607 KiB    4607 KiB    4608 KiB    4608 KiB    4608 KiB
# MLCGSolver::bicgstab                          911120    2495 KiB    2496 KiB    2496 KiB    2652 KiB    2652 KiB    2652 KiB
# MLMG::prepareForSolve()                           64    2033 KiB    2033 KiB    2033 KiB    2034 KiB    2034 KiB    2034 KiB
# MLABecLaplacian::define()                         64    1955 KiB    1955 KiB    1955 KiB    1956 KiB    1956 KiB    1956 KiB
# ComputePhi_Rho()                              426048      18 KiB      18 KiB      19 KiB    1888 KiB    1888 KiB    1888 KiB
# MultiFab::OverlapMask()                        76920     836   B     861   B     877   B     472 KiB     472 KiB     472 KiB
# BndryData::define()                              192     433 KiB     433 KiB     433 KiB     434 KiB     434 KiB     434 KiB
# MLCellLinOp::defineAuxData()                     192     203 KiB     203 KiB     203 KiB     204 KiB     204 KiB     204 KiB
# VisMF::Write(FabArray)                          6336       5   B       5   B       6   B      48 KiB      48 KiB      48 KiB
# FillBoundary_nowait()                         212672      43 KiB      43 KiB      43 KiB      44 KiB      44 KiB      44 KiB
# MultiFab::max()                                 7504     514   B     514   B     515   B      24 KiB      24 KiB      24 KiB
# amrex::Dot()                                 8455376    4952   B    5002   B    5093   B      24 KiB      24 KiB      24 KiB
# FabArray::norminf()                          4364000    2649   B    2652   B    2657   B      24 KiB      24 KiB      24 KiB
# MultiFab::norm1                                15384       8   B       8   B       8   B      24 KiB      24 KiB      24 KiB
# FabArray::setVal()                            152008      18 KiB      18 KiB      18 KiB      19 KiB      19 KiB      19 KiB
# FillBoundary_finish()                         106336      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB
# amrex::Copy()                                  76276    8166   B    8166   B    8166   B    8192   B    8192   B    8192   B
# MLCellLinOp::applyBC()                       4303648    6910   B    6910   B    6910   B    7168   B    7168   B    7168   B
# MLCellLinOp::prepareForSolve()                     4       0   B       0   B       0   B    4096   B    4096   B    4096   B
# FabArray::setVal(val, thecmd, scomp, ncomp)       56       0   B       0   B       0   B    1024   B    1024   B    1024   B
# FabArray::LinComb()                            15192     512   B     512   B     513   B    1024   B    1024   B    1024   B
# MLABecLaplacian::Fapply()                      91112     946   B     946   B     946   B    1024   B    1024   B    1024   B
# MultiFab::Divide()                             15384       0   B       0   B       0   B     512   B     512   B     512   B
# MLCellLinOp::defineBC()                            4     511   B     511   B     511   B     512   B     512   B     512   B
# ----------------------------------------------------------------------------------------------------------------------------
#
# Managed Memory Usage:
# ---------------------------------------------------------------------------------------------------------------
# Name                             Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ---------------------------------------------------------------------------------------------------------------
# The_Managed_Arena::Initialize()       4       0   B       0   B       0   B    8192 KiB    8192 KiB    8192 KiB
# main()                                4       0   B       0   B       0   B      31 KiB      31 KiB      31 KiB
# ---------------------------------------------------------------------------------------------------------------
#
# Pinned Memory Usage:
# ----------------------------------------------------------------------------------------------------------------------------
# Name                                          Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ----------------------------------------------------------------------------------------------------------------------------
# The_Pinned_Arena::Initialize()                     4       0   B       0   B       0   B    8192 KiB    8192 KiB    8192 KiB
# VisMF::Write(FabArray)                          6688     136   B     136   B     137   B    2124 KiB    2124 KiB    2124 KiB
# FillBoundary_nowait()                        8909080      54 KiB      54 KiB      54 KiB     104 KiB     104 KiB     104 KiB
# FabArray::setVal()                            152008      18 KiB      18 KiB      18 KiB      19 KiB      19 KiB      19 KiB
# FillBoundary_finish()                         106336      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB
# amrex::Copy()                                  76276    8166   B    8166   B    8166   B    8192   B    8192   B    8192   B
# MLCellLinOp::applyBC()                         15216    6910   B    6910   B    6910   B    6912   B    6912   B    6912   B
# MLCellLinOp::prepareForSolve()                     4       0   B       0   B       0   B    4096   B    4096   B    4096   B
# FabArray::LinComb()                            15192     512   B     512   B     513   B    1024   B    1024   B    1024   B
# FabArray::setVal(val, thecmd, scomp, ncomp)       56       0   B       0   B       0   B    1024   B    1024   B    1024   B
# MLABecLaplacian::Fapply()                      91112     946   B     946   B     946   B    1024   B    1024   B    1024   B
# MultiFab::OverlapMask()                        15384       0   B       0   B       0   B     768   B     768   B     768   B
# MultiFab::max()                                 7504     512   B     512   B     512   B     768   B     768   B     768   B
# MLCellLinOp::setLevelBC()                         88       0   B       0   B       0   B     512   B     512   B     512   B
# MultiFab::Divide()                             15384       0   B       0   B       0   B     512   B     512   B     512   B
# amrex::Dot()                                 8455376      51   B      51   B      53   B     256   B     256   B     256   B
# Unprofiled                                        60       0   B       0   B       0   B     256   B     256   B     256   B
# MultiFab::norm1                                15384       0   B       0   B       0   B     256   B     256   B     256   B
# FabArray::norminf()                          4364000      27   B      27   B      27   B     256   B     256   B     256   B
# ----------------------------------------------------------------------------------------------------------------------------
#
# Total GPU global memory (MB) spread across MPI: [3901 ... 3901]
# Free  GPU global memory (MB) spread across MPI: [547 ... 547]
# [The         Arena] max space (MB) allocated spread across MPI: [731 ... 731]
# [The         Arena] max space (MB) used      spread across MPI: [47 ... 47]
# [The Managed Arena] max space (MB) allocated spread across MPI: [8 ... 8]
# [The Managed Arena] max space (MB) used      spread across MPI: [0 ... 0]
# [The  Pinned Arena] max space (MB) allocated spread across MPI: [8 ... 8]
# [The  Pinned Arena] max space (MB) used      spread across MPI: [2 ... 2]
# AMReX (26.05-39-gbe2cc437644f) finalized

# %% [markdown]
# # 使用者設定

# %%
import re
from pathlib import Path

import yt
import numpy as np
import pandas as pd


# =========================
# User settings
# =========================
PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt")          # plotfile 所在資料夾
PLOT_PREFIX = "plt"
PLOT_INTERVAL = 10000000           # 你的 plot_int，例如 100

# 如果你的 field 名稱不是 ("boxlib", "Phi")，後面會自動列出 field_list 方便你改
PHI_FIELD_CANDIDATES = [
    ("boxlib", "Phi"),
    ("boxlib", "phi"),
    ("boxlib", "PoissonPhi"),
    "Phi",
    "phi",
    "PoissonPhi",
]

# FE layer range, unit: nm
FE_Z_LO_NM = 21.5
FE_Z_HI_NM = 29.5

# 如果你想只畫 FE 的 x 範圍，也可以打開這兩行
# 若是 MFIS 全幅 FE，通常用整個 x 範圍即可

FE_X_LO_NM = -16.0
FE_X_HI_NM = 16.0

FE_Y_LO_NM = -16.0
FE_Y_HI_NM = 16.0

ALPHA = -6.25e9
BETA = 4.0e10
SMALL_GAMMA = 1.5e11
G11 = 1.0e-9
G44 = 1.0e-9


# 3D sweep plot要畫的電壓欄位：-5, -4, ..., 5
VOLTAGES = np.arange(-5, 6, 1)
# 3D contour 要畫的plotfile
PLOTFILE_NAME = "plt00000517"

# %% [markdown]
# ## Utils

# %%
def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v

def read_full_field_from_grids(ds, field):
    """
    Read a cell-centered AMReX field from all yt grids
    and stitch them into one full-domain numpy array.

    Return:
        full: numpy array with shape ds.domain_dimensions
    """
    dims = np.array(ds.domain_dimensions, dtype=int)
    full = np.empty(tuple(dims), dtype=float)

    domain_lo = ds.domain_left_edge.to_value()
    domain_hi = ds.domain_right_edge.to_value()
    dx = (domain_hi - domain_lo) / dims

    for grid in ds.index.grids:
        arr = to_numpy(grid[field])

        left = grid.LeftEdge.to_value()

        # grid start index in global domain
        start = np.rint((left - domain_lo) / dx).astype(int)

        nx, ny, nz = arr.shape
        i0, j0, k0 = start
        i1, j1, k1 = i0 + nx, j0 + ny, k0 + nz

        full[i0:i1, j0:j1, k0:k1] = arr

    return full

# %% [markdown]
# # plot

# %% [markdown]
# ## 看有哪些 plotfile

# %%
from pathlib import Path
import yt


plot_paths = sorted([p for p in PLOT_DIR.glob(f"{PLOT_PREFIX}*") if p.is_dir()])

# 只要名稱 (plt000100, ...)
plot_names = [p.name for p in plot_paths]

print("Available plotfiles:")
for name in plot_names:
    print("  ", name)
# Out:
# Available plotfiles:
#    plt00000000
#    plt00000077
#    plt00000122
#    plt00000170
#    plt00000223
#    plt00000282
#    plt00000348
#    plt00000425
#    plt00000517
#    plt00000633
#    plt00000790
#    plt00001069
#    plt00001239
#    plt00001361
#    plt00001456
#    plt00001535
#    plt00001603
#    plt00001663
#    plt00001717
#    plt00001766
#    plt00001811
#    plt00001853

# %% [markdown]
# ## 探索yt資料結構

# %% [markdown]
# ### dir(ds) # 列出 ds 所有(variable和property和method)

# %% [markdown]
# * Note: variable和property和method統稱attribute

# %%
ds = yt.load(PLOT_DIR/plot_names[0])  # 載入指定的 plotfile
dir(ds) # 列出 ds 所有變數和屬性和方法
#[a for a in dir(ds) if not a.startswith("_")]
# Out:
# yt : [INFO     ] 2026-05-29 20:58:31,054 Parameters: current_time              = 0.0
# yt : [INFO     ] 2026-05-29 20:58:31,055 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:31,056 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:31,057 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_object_class',
#  '_arr',
#  '_assign_unit_system',
#  '_create_unit_registry',
#  '_default_cparam_filename',
#  '_determined_fields',
#  '_field_info',
#  '_field_info_class',
#  '_field_list',
#  '_find_extremum',
#  '_force_periodicity',
#  '_get_field_info',
#  '_get_field_info_helper',
#  '_guess_candidates',
#  '_hash',
#  '_header_mesh_start',
#  '_index_class',
#  '_input_filename',
#  '_instantiated',
#  '_instantiated_index',
#  '_ionization_label_format',
#  '_is_valid',
#  '_is_within_domain',
#  '_load_requirements',
#  '_localize_check',
#  '_lookup_cparam_filepath',
#  '_max_level',
#  '_min_level',
#  '_missing_load_requirements',
#  '_mrep',
#  '_output_prefix',
#  '_override_code_units',
#  '_parse_cparams',
#  '_parse_fparams',
#  '_parse_header_file',
#  '_parse_parameter_file',
#  '_particle_type_counts',
#  '_periodicity',
#  '_proj_type',
#  '_quan',
#  '_sanitize_units_override',
#  '_set_code_unit_attributes',
#  '_set_derived_attrs',
#  '_setup_classes',
#  '_setup_coordinate_handler',
#  '_setup_filtered_type',
#  '_setup_particle_type',
#  '_setup_particle_types',
#  '_skip_cache',
#  '_unit_system_id',
#  '_unit_system_name',
#  '_units',
#  '_uses_code_length_unit',
#  '_uses_code_time_unit',
#  '_validate_units_override_keys',
#  'add_deposited_particle_field',
#  'add_field',
#  'add_gradient_fields',
#  'add_mesh_sampling_particle_field',
#  'add_particle_filter',
#  'add_particle_union',
#  'all_data',
#  'arbitrary_grid',
#  'arr',
#  'backup_filename',
#  'basename',
#  'bool',
#  'box',
#  'checksum',
#  'close',
#  'conversion_factors',
#  'coordinates',
#  'covering_grid',
#  'cparam_filename',
#  'create_field_info',
#  'current_time',
#  'cut_region',
#  'cutting',
#  'data_collection',
#  'dataset_type',
#  'default_field',
#  'default_fluid_type',
#  'default_species_fields',
#  'default_units',
#  'define_unit',
#  'derived_field_list',
#  'dimensionality',
#  'directory',
#  'disk',
#  'domain_center',
#  'domain_dimensions',
#  'domain_left_edge',
#  'domain_offset',
#  'domain_right_edge',
#  'domain_width',
#  'ellipsoid',
#  'field_info',
#  'field_list',
#  'field_units',
#  'fields',
#  'fields_detected',
#  'filename',
#  'find_field_values_at_point',
#  'find_field_values_at_points',
#  'find_max',
#  'find_min',
#  'fluid_types',
#  'force_periodicity',
#  'fparam_filename',
#  'fullpath',
#  'geometry',
#  'get_smallest_appropriate_unit',
#  'get_unit_from_registry',
#  'has_key',
#  'index',
#  'intersection',
#  'ires_factor',
#  'known_filters',
#  'length_unit',
#  'level_offsets',
#  'mass_unit',
#  'max_level',
#  'min_level',
#  'minimal_sphere',
#  'no_cgs_equiv_length',
#  'object_types',
#  'objects',
#  'octree',
#  'orion_version',
#  'ortho_ray',
#  'output_dir',
#  'parameter_filename',
#  'parameters',
#  'particle_fields_by_type',
#  'particle_type_counts',
#  'particle_types',
#  'particle_types_raw',
#  'particle_unions',
#  'particles_exist',
#  'periodicity',
#  'plots',
#  'point',
#  'print_key_parameters',
#  'print_stats',
#  'proj',
#  'quan',
#  'r',
#  'ray',
#  'ref_factors',
#  'refine_by',
#  'region',
#  'region_expression',
#  'relative_refinement',
#  'set_code_units',
#  'set_field_label_format',
#  'set_units',
#  'setup_cosmology',
#  'setup_deprecated_fields',
#  'slice',
#  'smoothed_covering_grid',
#  'sphere',
#  'storage_filename',
#  'streamline',
#  'surface',
#  'time_unit',
#  'union',
#  'unique_identifier',
#  'unit_registry',
#  'unit_system',
#  'units',
#  'units_override',
#  'velocity_unit']

# %% [markdown]
# ### 用key word查看dir(ds)中可能會用到的attribute

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "domain"
    if "domain" in a.lower():
        print(a)
# Out:
# _is_within_domain
# domain_center
# domain_dimensions
# domain_left_edge
# domain_offset
# domain_right_edge
# domain_width

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "field"
    if "field" in a.lower():
        print(a)
# Out:
# _determined_fields
# _field_info
# _field_info_class
# _field_list
# _get_field_info
# _get_field_info_helper
# add_deposited_particle_field
# add_field
# add_gradient_fields
# add_mesh_sampling_particle_field
# create_field_info
# default_field
# default_species_fields
# derived_field_list
# field_info
# field_list
# field_units
# fields
# fields_detected
# find_field_values_at_point
# find_field_values_at_points
# particle_fields_by_type
# set_field_label_format
# setup_deprecated_fields

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "index"
    if "index" in a.lower():
        print(a)
# Out:
# _index_class
# _instantiated_index
# index

# %% [markdown]
# * **grid相關attribute在index內**

# %%
for a in dir(ds.index): # 列出 ds.index 裡有哪些屬性和方法，特別是包含 "index"
    if "grid" in a.lower():
        print(a)
# Out:
# _count_grids
# _get_grid_objs
# _get_grid_tree
# _get_grids
# _grid_chunksize
# _grids
# _initialize_grid_arrays
# _populate_grid_objects
# grid
# grid_corners
# grid_dimensions
# grid_left_edge
# grid_levels
# grid_particle_count
# grid_right_edge
# grid_start_index
# grids
# lock_grids_to_parents
# num_grids
# select_grids

# %%
for a in dir(ds.index.grids[0]): # 列出 ds.index.grids[0] 裡有哪些屬性和方法，特別是包含 "index"
    
        print(a)
# Out:
# ActiveDimensions
# Children
# LeftEdge
# Level
# NumberOfParticles
# OverlappingSiblings
# Parent
# RightEdge
# __abstractmethods__
# __add__
# __and__
# __annotations__
# __class__
# __delattr__
# __delitem__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __int__
# __invert__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __or__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __setitem__
# __sizeof__
# __slots__
# __str__
# __sub__
# __subclasshook__
# __weakref__
# __xor__
# _abc_impl
# _activate_cache
# _base_offset
# _cache_mask
# _child_index_mask
# _child_indices
# _child_mask
# _children_ids
# _chunk_info
# _chunked_read
# _compute_extrema
# _con_args
# _container_fields
# _count_particles
# _current_chunk
# _current_fluid_type
# _current_particle_type
# _data_source
# _debug
# _default_field_parameters
# _derived_quantity_chunking
# _determine_fields
# _distributed
# _ds_hold
# _extrema_cache
# _field_cache
# _field_lock
# _field_parameter_state
# _field_type_state
# _fill_child_mask
# _finalize_parallel
# _first_matching_field
# _generate_container_field
# _generate_field
# _generate_fields
# _generate_fluid_field
# _generate_particle_field
# _generate_spatial_fluid
# _get_grid_objs
# _get_grids
# _get_objs
# _get_offset
# _get_selector_mask
# _grids
# _hash
# _id_offset
# _identify_dependencies
# _index
# _initialize_cache
# _initialize_parallel
# _ipython_key_completions_
# _is_default_field_parameter
# _last_count
# _last_mask
# _last_selector_id
# _locked
# _max_level
# _min_level
# _num_ghost_zones
# _offset
# _parameter_iterate
# _parent_id
# _pdata
# _prepare_grid
# _reshape_vals
# _selector
# _set_center
# _set_default_field_parameters
# _setup_dx
# _skip_add
# _sort_by
# _spatial
# _tds_attrs
# _tds_fields
# _tree
# _type_name
# apply_units
# argmax
# argmin
# blocks
# child_index_mask
# child_indices
# child_mask
# chunks
# clear_data
# clone
# comm
# convert
# count
# count_particles
# create_firefly_object
# dds
# deposit
# ds
# fcoords
# fcoords_vertex
# field_data
# field_parameters
# filename
# fwidth
# get_data
# get_dependencies
# get_field_parameter
# get_global_startindex
# get_position
# get_vertex_centered_data
# has_field_parameter
# has_key
# icoords
# id
# index
# integrate
# ires
# keys
# max
# max_level
# mean
# min
# min_level
# particle_operation
# partition_index_2d
# partition_index_3d
# partition_index_3d_bisection_list
# partition_region_3d
# pf
# profile
# ptp
# quantities
# retrieve_ghost_zones
# save_as_dataset
# select
# select_blocks
# select_fcoords
# select_fwidth
# select_icoords
# select_ires
# select_particles
# select_tcoords
# selector
# set_field_parameter
# shape
# smooth
# start_index
# std
# sum
# tiles
# to_astropy_table
# to_dataframe
# to_glue
# write_out

# %% [markdown]
# ## yt dataset

# %% [markdown]
# * 可以從上一個部份"探索yt資料結構"找想用的attribute

# %%
print("========== Dataset ==========")
print("type:", type(ds))
print("用SI單位")
print("current_time(s):", ds.current_time)
print("domain_left_edge(m) :", ds.domain_left_edge)
print("domain_right_edge(m):", ds.domain_right_edge)
print("domain_center:", ds.domain_center)
print("domain_width(domain邊長):", ds.domain_width)
print("domain_offset:", ds.domain_offset)
print("domain_dimensions(xyz方向各切成幾格):", ds.domain_dimensions)
print("dimensionality:", ds.dimensionality)
print("geometry:", ds.geometry)
#print("periodicity:", ds.periodicity)

print("\n========== Fields ==========")
for f in ds.field_list:
    print(" ", f)
# Out:
# ========== Dataset ==========
# type: <class 'yt.frontends.amrex.data_structures.BoxlibDataset'>
# 用SI單位
# current_time(s): 0.0 code_time
# domain_left_edge(m) : [-1.6e-08 -1.6e-08  0.0e+00] code_length
# domain_right_edge(m): [1.60e-08 1.60e-08 2.95e-08] code_length
# domain_center: [0.000e+00 0.000e+00 1.475e-08] code_length
# domain_width(domain邊長): [3.20e-08 3.20e-08 2.95e-08] code_length
# domain_offset: [0 0 0]
# domain_dimensions(xyz方向各切成幾格): [64 64 59]
# dimensionality: 3
# geometry: cartesian
#
# ========== Fields ==========
#   ('boxlib', 'Ex')
#   ('boxlib', 'Ey')
#   ('boxlib', 'Ez')
#   ('boxlib', 'Phi')
#   ('boxlib', 'PhiDiff')
#   ('boxlib', 'PoissonRHS')
#   ('boxlib', 'Px')
#   ('boxlib', 'Py')
#   ('boxlib', 'Pz')
#   ('boxlib', 'alpha')
#   ('boxlib', 'beta')
#   ('boxlib', 'charge')
#   ('boxlib', 'electrons')
#   ('boxlib', 'epsilon')
#   ('boxlib', 'holes')
#   ('boxlib', 'mask')
#   ('boxlib', 'theta')
#   ('boxlib', 'tphase')

# %% [markdown]
# * domain切成多個grid分配給mpi rank平行運算，**資料分散在每個grid**

# %%
print("\n========== Grids ==========")
print("number of grids:", len(ds.index.grids))
for i, g in enumerate(ds.index.grids):
    print(f"grid {i}:")
    print("  LeftEdge:", g.LeftEdge)
    print("  RightEdge:", g.RightEdge)
    print("  ActiveDimensions:", g.ActiveDimensions)
    print("  Level:", g.Level)
print(ds.index.grid_start_index)
# Out:
# ========== Grids ==========
# number of grids: 16
# grid 0:
#   LeftEdge: [-1.6e-08 -1.6e-08  0.0e+00] code_length
#   RightEdge: [-8.00e-09 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 1:
#   LeftEdge: [-8.0e-09 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 0.00e+00 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 2:
#   LeftEdge: [ 0.0e+00 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 8.00e-09 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 3:
#   LeftEdge: [ 8.0e-09 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 1.60e-08 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 4:
#   LeftEdge: [-1.6e-08 -8.0e-09  0.0e+00] code_length
#   RightEdge: [-8.00e-09  0.00e+00  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 5:
#   LeftEdge: [-8.e-09 -8.e-09  0.e+00] code_length
#   RightEdge: [0.00e+00 0.00e+00 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 6:
#   LeftEdge: [ 0.e+00 -8.e-09  0.e+00] code_length
#   RightEdge: [8.00e-09 0.00e+00 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 7:
#   LeftEdge: [ 8.e-09 -8.e-09  0.e+00] code_length
#   RightEdge: [1.60e-08 0.00e+00 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 8:
#   LeftEdge: [-1.6e-08  0.0e+00  0.0e+00] code_length
#   RightEdge: [-8.00e-09  8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 9:
#   LeftEdge: [-8.e-09  0.e+00  0.e+00] code_length
#   RightEdge: [0.00e+00 8.00e-09 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 10:
#   LeftEdge: [0. 0. 0.] code_length
#   RightEdge: [8.00e-09 8.00e-09 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 11:
#   LeftEdge: [8.e-09 0.e+00 0.e+00] code_length
#   RightEdge: [1.60e-08 8.00e-09 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 12:
#   LeftEdge: [-1.6e-08  8.0e-09  0.0e+00] code_length
#   RightEdge: [-8.00e-09  1.60e-08  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 13:
#   LeftEdge: [-8.e-09  8.e-09  0.e+00] code_length
#   RightEdge: [0.00e+00 1.60e-08 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 14:
#   LeftEdge: [0.e+00 8.e-09 0.e+00] code_length
#   RightEdge: [8.00e-09 1.60e-08 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 15:
#   LeftEdge: [8.e-09 8.e-09 0.e+00] code_length
#   RightEdge: [1.60e-08 1.60e-08 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# [[ 0  0  0]
#  [16  0  0]
#  [32  0  0]
#  [48  0  0]
#  [ 0 16  0]
#  [16 16  0]
#  [32 16  0]
#  [48 16  0]
#  [ 0 32  0]
#  [16 32  0]
#  [32 32  0]
#  [48 32  0]
#  [ 0 48  0]
#  [16 48  0]
#  [32 48  0]
#  [48 48  0]]

# %% [markdown]
# ## **2Dfield繪製**

# %% [markdown]
# * g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
# * x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置

# %%
import yt
import numpy as np
import matplotlib.pyplot as plt
for i in range(len(plot_names)):
    plotfile = PLOT_DIR/plot_names[i] 
    field = ("boxlib", "Phi")

    ds = yt.load(plotfile)

    #g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
    Phi_array = read_full_field_from_grids(ds, field) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid

    print("Phi_array shape =", Phi_array.shape)

    Nx, Ny, Nz = Phi_array.shape #用index存資料

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dims = np.array([Nx, Ny, Nz])

    dx = (hi - lo) / dims

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    y0 = Ny // 2
    slice2d = Phi_array[:, y0, :]

    plt.figure(figsize=(6, 5))
    im = plt.pcolormesh(
        x_nm,
        z_nm,
        slice2d.T,
        shading="auto",
        cmap="RdBu"
    )

    plt.colorbar(im, label="Ex")
    plt.xlabel("x (nm)")
    plt.ylabel("z (nm)")
    plt.title(f"Phi x-z slice at y index = {y0}")
    plt.tight_layout()
    plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 20:58:31,445 Parameters: current_time              = 0.0
# yt : [INFO     ] 2026-05-29 20:58:31,446 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:31,446 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:31,447 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:31,767 Parameters: current_time              = 1.54e-11
# yt : [INFO     ] 2026-05-29 20:58:31,769 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:31,769 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:31,770 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:32,036 Parameters: current_time              = 2.4399999999999998e-11
# yt : [INFO     ] 2026-05-29 20:58:32,038 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:32,038 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:32,039 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:32,293 Parameters: current_time              = 3.4000000000000076e-11
# yt : [INFO     ] 2026-05-29 20:58:32,294 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:32,294 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:32,295 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:32,696 Parameters: current_time              = 4.4600000000000245e-11
# yt : [INFO     ] 2026-05-29 20:58:32,697 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:32,697 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:32,698 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:32,947 Parameters: current_time              = 5.6400000000000433e-11
# yt : [INFO     ] 2026-05-29 20:58:32,948 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:32,948 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:32,949 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:33,268 Parameters: current_time              = 6.960000000000028e-11
# yt : [INFO     ] 2026-05-29 20:58:33,268 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:33,269 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:33,270 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:33,518 Parameters: current_time              = 8.500000000000003e-11
# yt : [INFO     ] 2026-05-29 20:58:33,519 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:33,519 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:33,520 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:33,753 Parameters: current_time              = 1.0339999999999973e-10
# yt : [INFO     ] 2026-05-29 20:58:33,754 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:33,754 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:33,754 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:33,995 Parameters: current_time              = 1.266e-10
# yt : [INFO     ] 2026-05-29 20:58:33,995 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:33,996 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:33,996 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:34,391 Parameters: current_time              = 1.5800000000000152e-10
# yt : [INFO     ] 2026-05-29 20:58:34,391 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:34,392 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:34,392 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:34,643 Parameters: current_time              = 2.1380000000000421e-10
# yt : [INFO     ] 2026-05-29 20:58:34,644 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:34,645 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:34,645 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:34,877 Parameters: current_time              = 2.4780000000000585e-10
# yt : [INFO     ] 2026-05-29 20:58:34,878 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:34,879 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:34,880 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:35,122 Parameters: current_time              = 2.7220000000000703e-10
# yt : [INFO     ] 2026-05-29 20:58:35,122 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:35,123 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:35,124 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:35,366 Parameters: current_time              = 2.9120000000000795e-10
# yt : [INFO     ] 2026-05-29 20:58:35,366 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:35,366 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:35,367 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:35,760 Parameters: current_time              = 3.070000000000087e-10
# yt : [INFO     ] 2026-05-29 20:58:35,760 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:35,761 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:35,761 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:35,989 Parameters: current_time              = 3.2060000000000937e-10
# yt : [INFO     ] 2026-05-29 20:58:35,989 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:35,990 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:35,990 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:36,214 Parameters: current_time              = 3.3260000000000995e-10
# yt : [INFO     ] 2026-05-29 20:58:36,215 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:36,215 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:36,216 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:36,442 Parameters: current_time              = 3.4340000000001047e-10
# yt : [INFO     ] 2026-05-29 20:58:36,442 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:36,443 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:36,443 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:36,893 Parameters: current_time              = 3.5320000000001094e-10
# yt : [INFO     ] 2026-05-29 20:58:36,894 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:36,894 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:36,895 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:37,128 Parameters: current_time              = 3.6220000000001137e-10
# yt : [INFO     ] 2026-05-29 20:58:37,129 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:37,129 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:37,130 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 20:58:37,363 Parameters: current_time              = 3.706000000000118e-10
# yt : [INFO     ] 2026-05-29 20:58:37,364 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:37,365 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:37,365 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)

# %%
import yt
import numpy as np
import matplotlib.pyplot as plt

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_plt")  # 改成你 plotfile 所在的資料夾
plotfile = PLOT_DIR/plot_names[2] 
field = ("boxlib", "Ex")

ds = yt.load(plotfile)

#g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
E_array = read_full_field_from_grids(ds, field) # 讀取整個 domain 的 Ex 資料，會自動合併多個 grid

print("E_array shape =", E_array.shape)

Nx, Ny, Nz = E_array.shape #用index存資料

lo = ds.domain_left_edge.to_value()
hi = ds.domain_right_edge.to_value()
dims = np.array([Nx, Ny, Nz])

dx = (hi - lo) / dims

x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置
z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

y0 = Ny // 2
slice2d = E_array[:, y0, :]

plt.figure(figsize=(6, 5))
im = plt.pcolormesh(
    x_nm,
    z_nm,
    slice2d.T,
    shading="auto",
    cmap="RdBu"
)

plt.colorbar(im, label="Ex")
plt.xlabel("x (nm)")
plt.ylabel("z (nm)")
plt.title(f"Ex x-z slice at y index = {y0}")
plt.tight_layout()
plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 20:58:37,596 Parameters: current_time              = 2.4399999999999998e-11
# yt : [INFO     ] 2026-05-29 20:58:37,597 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:37,597 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:37,598 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# E_array shape = (64, 64, 59)

# %% [markdown]
# ## 2D Pz slice plot(all voltage in same graph)

# %%
from pathlib import Path
import re

import yt
import numpy as np
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec")          # plotfile 所在資料夾
P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")



USE_FE_X_RANGE = False

# y slice: None 表示取 y 方向正中間
Y_INDEX = None

# 若 plot_names 已經是你前面整理好的 steady-state plot list，就直接用
# plot_names = [...]
# 若沒有，就自動抓目前資料夾內所有 plt########
AUTO_FIND_PLOTS = False

# 跳過 initial plt00000000
SKIP_INITIAL = True

# 色階是否對稱於 0，畫 Pz 通常建議 True
SYMMETRIC_COLOR_SCALE = True

# 輸出圖片名稱
SAVE_FIG = True
OUT_FIG = PLOT_DIR/"Pz_FE_layer_stack.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


def read_one_plot(plotfile, y_index=None):
    ds = yt.load(str(plotfile))
    #g = ds.index.grids[0]

    P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

    if PHI_FIELD in ds.field_list:
        Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
    else:
        Phi = None

    Nx, Ny, Nz = P.shape

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    if y_index is None:
        y_index = Ny // 2

    # FE z range mask
    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    # P slice: shape after selection = (Nx_sel, Nz_sel)
    P_slice = P[np.ix_(x_sel, [y_index], z_sel)][:, 0, :]

    x_plot = x_nm[x_sel]
    z_plot = z_nm[z_sel]

    # 用最上層 cell 的 Phi 平均值當 top potential
    # 注意：這是 top cell center，不是真正 ghost boundary
    if Phi is not None:
        top_phi = Phi[:, :, -1]
        Vtop_mean = float(np.mean(top_phi))
        Vtop_min = float(np.min(top_phi))
        Vtop_max = float(np.max(top_phi))
    else:
        Vtop_mean = np.nan
        Vtop_min = np.nan
        Vtop_max = np.nan

    info = {
        "ds": ds,
        "P_slice": P_slice,
        "x_nm": x_plot,
        "z_nm": z_plot,
        "y_index": y_index,
        "y_nm": float(y_nm[y_index]),
        "Vtop_mean": Vtop_mean,
        "Vtop_min": Vtop_min,
        "Vtop_max": Vtop_max,
        "shape": P.shape,
    }

    return info


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

# sort by step if names are plt########
plot_names_use = sorted(plot_names_use, key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

print("Plotfiles to draw:")
for n in plot_names_use:
    print(" ", n)

records = []
all_values = []

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    info = read_one_plot(plotfile, y_index=Y_INDEX)

    step = get_step_from_name(name)

    records.append({
        "name": name,
        "step": step,
        **info,
    })

    all_values.append(info["P_slice"])

# shared color scale
all_concat = np.concatenate([v.ravel() for v in all_values])
if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(all_concat))
    vmin = -vmax
else:
    vmin = np.nanmin(all_concat)
    vmax = np.nanmax(all_concat)

# determine sweep direction from Vtop sequence
Vseq = np.array([r["Vtop_mean"] for r in records], dtype=float)

directions = []
for idx, V in enumerate(Vseq):
    if idx == 0 or not np.isfinite(Vseq[idx-1]) or not np.isfinite(V):
        directions.append("start")
    else:
        dV = V - Vseq[idx-1]
        if dV > 1e-8:
            directions.append("positive sweep")
        elif dV < -1e-8:
            directions.append("negative sweep")
        else:
            directions.append("same V")

# figure size
n = len(records)
fig_height = max(2.0 * n, 4.0)
fig, axes = plt.subplots(
    nrows=n,
    ncols=1,
    figsize=(7.5, fig_height),
    sharex=True,
    constrained_layout=True
)

if n == 1:
    axes = [axes]

last_im = None

for ax, rec, sweep_dir in zip(axes, records, directions):
    P_slice = rec["P_slice"]
    x_nm = rec["x_nm"]
    z_nm = rec["z_nm"]

    last_im = ax.pcolormesh(
        x_nm,
        z_nm,
        P_slice.T,
        shading="auto",
        cmap="RdBu",
        vmin=vmin,
        vmax=vmax
    )

    Vmean = rec["Vtop_mean"]
    Vmin = rec["Vtop_min"]
    Vmax = rec["Vtop_max"]

    if np.isfinite(Vmean):
        v_label = f"Vg = {Vmean:+.0f} V"
        # 若你想檢查 top x/y variation，也可以顯示 min/max
        # v_label += f" [{Vmin:+.3f}, {Vmax:+.3f}]"
    else:
        v_label = "Vtop unavailable"

    step_label = f"step={rec['step']}" if rec["step"] is not None else rec["name"]

    ax.set_ylabel("z (nm)")

    ax.set_title(
        f"{v_label} | {sweep_dir} | "
        f"y center ≈ {rec['y_nm']:.2f} nm",
        fontsize=9
    )

axes[-1].set_xlabel("x (nm)")

cbar = fig.colorbar(last_im, ax=axes, shrink=0.8)
cbar.set_label(r"Pz (C/m$^2$)")

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=200)
    print(f"Saved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 20:58:37,839 Parameters: current_time              = 1.54e-11
# yt : [INFO     ] 2026-05-29 20:58:37,840 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:37,840 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:37,841 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Plotfiles to draw:
#   plt00000077
#   plt00000122
#   plt00000170
#   plt00000223
#   plt00000282
#   plt00000348
#   plt00000425
#   plt00000517
#   plt00000633
#   plt00000790
#   plt00001069
#   plt00001239
#   plt00001361
#   plt00001456
#   plt00001535
#   plt00001603
#   plt00001663
#   plt00001717
#   plt00001766
#   plt00001811
#   plt00001853
# yt : [INFO     ] 2026-05-29 20:58:38,098 Parameters: current_time              = 2.4399999999999998e-11
# yt : [INFO     ] 2026-05-29 20:58:38,098 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:38,099 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:38,099 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:38,221 Parameters: current_time              = 3.4000000000000076e-11
# yt : [INFO     ] 2026-05-29 20:58:38,222 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:38,222 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:38,223 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:38,333 Parameters: current_time              = 4.4600000000000245e-11
# yt : [INFO     ] 2026-05-29 20:58:38,334 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:38,334 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:38,335 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:38,443 Parameters: current_time              = 5.6400000000000433e-11
# yt : [INFO     ] 2026-05-29 20:58:38,444 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:38,444 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:38,444 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:38,554 Parameters: current_time              = 6.960000000000028e-11
# yt : [INFO     ] 2026-05-29 20:58:38,554 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:38,555 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:38,555 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:38,669 Parameters: current_time              = 8.500000000000003e-11
# yt : [INFO     ] 2026-05-29 20:58:38,669 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:38,669 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:38,670 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:38,786 Parameters: current_time              = 1.0339999999999973e-10
# yt : [INFO     ] 2026-05-29 20:58:38,787 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:38,787 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:38,788 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:38,900 Parameters: current_time              = 1.266e-10
# yt : [INFO     ] 2026-05-29 20:58:38,900 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:38,901 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:38,901 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:39,015 Parameters: current_time              = 1.5800000000000152e-10
# yt : [INFO     ] 2026-05-29 20:58:39,016 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:39,017 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:39,017 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:39,134 Parameters: current_time              = 2.1380000000000421e-10
# yt : [INFO     ] 2026-05-29 20:58:39,134 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:39,135 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:39,135 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:39,394 Parameters: current_time              = 2.4780000000000585e-10
# yt : [INFO     ] 2026-05-29 20:58:39,395 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:39,395 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:39,396 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:39,508 Parameters: current_time              = 2.7220000000000703e-10
# yt : [INFO     ] 2026-05-29 20:58:39,509 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:39,510 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:39,510 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:39,626 Parameters: current_time              = 2.9120000000000795e-10
# yt : [INFO     ] 2026-05-29 20:58:39,626 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:39,627 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:39,627 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:39,744 Parameters: current_time              = 3.070000000000087e-10
# yt : [INFO     ] 2026-05-29 20:58:39,745 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:39,746 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:39,746 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:39,863 Parameters: current_time              = 3.2060000000000937e-10
# yt : [INFO     ] 2026-05-29 20:58:39,864 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:39,864 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:39,864 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:39,977 Parameters: current_time              = 3.3260000000000995e-10
# yt : [INFO     ] 2026-05-29 20:58:39,978 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:39,978 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:39,978 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:40,092 Parameters: current_time              = 3.4340000000001047e-10
# yt : [INFO     ] 2026-05-29 20:58:40,092 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:40,093 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:40,093 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:40,206 Parameters: current_time              = 3.5320000000001094e-10
# yt : [INFO     ] 2026-05-29 20:58:40,207 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:40,207 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:40,208 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:40,322 Parameters: current_time              = 3.6220000000001137e-10
# yt : [INFO     ] 2026-05-29 20:58:40,322 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:40,323 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:40,323 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:40,438 Parameters: current_time              = 3.706000000000118e-10
# yt : [INFO     ] 2026-05-29 20:58:40,438 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:40,438 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:40,439 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/Pz_FE_layer_stack.png

# %% [markdown]
# ## 3D Scatter plot (all voltage in same graph)

# %% [markdown]
# * trash

# %%
from pathlib import Path
import re

import yt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec")

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 若 FE 只在部分 x/y 範圍，打開這裡
USE_FE_X_RANGE = False

USE_FE_Y_RANGE = False




# 用 top Phi 平均值四捨五入到整數電壓來分類
V_ROUND_DECIMALS = 0

# 3D 點太多會慢，STRIDE=2 表示 x/y/z 每 2 點取 1 點
# 若想更細可設 1；若很慢可設 3 或 4
STRIDE = 2

# 顏色是否以 0 對稱，畫 Pz 建議 True
SYMMETRIC_COLOR_SCALE = True

# 3D 視角
ELEV = 22
AZIM = -55

# 點大小
POINT_SIZE = 2

# 跳過 initial plt00000000
SKIP_INITIAL = True

# 若你已經有 plot_names，就保留 AUTO_FIND_PLOTS=False
# plot_names = [...]
AUTO_FIND_PLOTS = False

SAVE_FIG = True
OUT_FIG = PLOT_DIR/"Pz_FE_3D_2x11_sweep.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


def read_one_plot_3d(plotfile):
    ds = yt.load(str(plotfile))
    #g = ds.index.grids[0]

    P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

    if PHI_FIELD in ds.field_list:
        Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
    else:
        Phi = None

    Nx, Ny, Nz = P.shape

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    # FE selection
    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    if USE_FE_Y_RANGE:
        y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
    else:
        y_sel = np.ones_like(y_nm, dtype=bool)

    # Apply selection
    P_fe = P[np.ix_(x_sel, y_sel, z_sel)]

    x_fe = x_nm[x_sel]
    y_fe = y_nm[y_sel]
    z_fe = z_nm[z_sel]

    # Downsample for 3D plotting
    P_ds = P_fe[::STRIDE, ::STRIDE, ::STRIDE]
    x_ds = x_fe[::STRIDE]
    y_ds = y_fe[::STRIDE]
    z_ds = z_fe[::STRIDE]

    X, Y, Z = np.meshgrid(x_ds, y_ds, z_ds, indexing="ij")

    # Estimate top voltage from top cell Phi
    if Phi is not None:
        top_phi = Phi[:, :, -1]
        Vtop_mean = float(np.mean(top_phi))
        Vtop_min = float(np.min(top_phi))
        Vtop_max = float(np.max(top_phi))
    else:
        Vtop_mean = np.nan
        Vtop_min = np.nan
        Vtop_max = np.nan

    return {
        "P": P_ds,
        "X": X,
        "Y": Y,
        "Z": Z,
        "x_range": (float(np.min(x_fe)), float(np.max(x_fe))),
        "y_range": (float(np.min(y_fe)), float(np.max(y_fe))),
        "z_range": (float(np.min(z_fe)), float(np.max(z_fe))),
        "Vtop_mean": Vtop_mean,
        "Vtop_min": Vtop_min,
        "Vtop_max": Vtop_max,
        "shape_full": P.shape,
        "shape_fe": P_fe.shape,
        "shape_plot": P_ds.shape,
    }


def classify_sweep(records):
    """
    根據 records 原本的時間順序，用 Vtop 的變化判斷正掃/負掃。
    第一個點歸到 positive，因為通常是正掃起點。
    turning point 會同時加入 positive 與 negative，讓上下排都有 +5。
    """
    pos = []
    neg = []

    V = np.array([r["Vtop_mean"] for r in records], dtype=float)

    if len(records) == 0:
        return pos, neg

    pos.append(records[0])

    for i in range(1, len(records)):
        dV = V[i] - V[i - 1]

        if dV > 1e-8:
            pos.append(records[i])
        elif dV < -1e-8:
            # 如果剛從正掃轉負掃，把上一個 turning point 也放進 neg
            if len(neg) == 0:
                neg.append(records[i - 1])
            neg.append(records[i])
        else:
            # 同電壓重複時，不確定歸類；先放到目前方向
            if len(neg) == 0:
                pos.append(records[i])
            else:
                neg.append(records[i])

    return pos, neg


def pick_record_by_voltage(records, target_v):
    """
    從一組 records 中挑最接近 target_v 的那筆。
    """
    if len(records) == 0:
        return None

    V = np.array([r["Vround"] for r in records], dtype=float)
    idx = int(np.argmin(np.abs(V - target_v)))

    if np.abs(V[idx] - target_v) > 0.25:
        return None

    return records[idx]


def draw_3d_fe(ax, rec, norm, cmap):
    P = rec["P"]
    X = rec["X"]
    Y = rec["Y"]
    Z = rec["Z"]

    ax.scatter(
        X.ravel(),
        Y.ravel(),
        Z.ravel(),
        c=P.ravel(),
        cmap=cmap,
        norm=norm,
        s=POINT_SIZE,
        marker="s",
        linewidths=0,
        alpha=0.95,
    )

    ax.set_xlim(rec["x_range"])
    ax.set_ylim(rec["y_range"])
    ax.set_zlim(rec["z_range"])

    ax.view_init(elev=ELEV, azim=AZIM)

    # 22 張小圖，不要塞太多刻度
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])

    ax.set_box_aspect((
        rec["x_range"][1] - rec["x_range"][0],
        rec["y_range"][1] - rec["y_range"][0],
        rec["z_range"][1] - rec["z_range"][0],
    ))


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

plot_names_use = sorted(
    plot_names_use,
    key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99
)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

print("Plotfiles to read:")
for n in plot_names_use:
    print(" ", n)

records = []

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    info = read_one_plot_3d(plotfile)

    Vround = np.round(info["Vtop_mean"], V_ROUND_DECIMALS)

    rec = {
        "name": name,
        "step": get_step_from_name(name),
        "Vround": float(Vround),
        **info,
    }

    records.append(rec)

print("\nRead records:")
for r in records:
    print(
        f"{r['name']}  step={r['step']}  "
        f"Vtop={r['Vtop_mean']:+.4f} V  Vround={r['Vround']:+.0f}  "
        f"shape_fe={r['shape_fe']}  shape_plot={r['shape_plot']}"
    )

# classify positive / negative sweep from time ordering
pos_records, neg_records = classify_sweep(records)

print("\nPositive sweep records:")
for r in pos_records:
    print(f"  V={r['Vround']:+.0f}  {r['name']}")

print("\nNegative sweep records:")
for r in neg_records:
    print(f"  V={r['Vround']:+.0f}  {r['name']}")

# Arrange columns left-to-right by increasing voltage: -5, -4, ..., 5
pos_grid = [pick_record_by_voltage(pos_records, v) for v in VOLTAGES]
neg_grid = [pick_record_by_voltage(neg_records, v) for v in VOLTAGES]

# shared color scale from all selected records
selected_records = [r for r in pos_grid + neg_grid if r is not None]
if len(selected_records) == 0:
    raise RuntimeError("No records selected. Check plot_names or voltage classification.")

all_p = np.concatenate([r["P"].ravel() for r in selected_records])

if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(all_p))
    vmin = -vmax
else:
    vmin = np.nanmin(all_p)
    vmax = np.nanmax(all_p)

cmap = "RdBu"
norm = Normalize(vmin=vmin, vmax=vmax)

# 2 x 11 figure
fig = plt.figure(figsize=(22, 6.2))

axes = np.empty((2, len(VOLTAGES)), dtype=object)

for row in range(2):
    for col in range(len(VOLTAGES)):
        axes[row, col] = fig.add_subplot(
            2,
            len(VOLTAGES),
            row * len(VOLTAGES) + col + 1,
            projection="3d"
        )

for col, Vtarget in enumerate(VOLTAGES):
    rec = pos_grid[col]
    ax = axes[0, col]

    if rec is not None:
        draw_3d_fe(ax, rec, norm, cmap)
        ax.set_title(f"{Vtarget:+.0f} V\npos sweep", fontsize=9)
    else:
        ax.set_title(f"{Vtarget:+.0f} V\nmissing", fontsize=9)
        ax.axis("off")

for col, Vtarget in enumerate(VOLTAGES):
    rec = neg_grid[col]
    ax = axes[1, col]

    if rec is not None:
        draw_3d_fe(ax, rec, norm, cmap)
        ax.set_title(f"{Vtarget:+.0f} V\nneg sweep", fontsize=9)
    else:
        ax.set_title(f"{Vtarget:+.0f} V\nmissing", fontsize=9)
        ax.axis("off")

# row labels
fig.text(0.01, 0.72, "Positive sweep\n(-5 → +5)", va="center", ha="left", fontsize=12)
fig.text(0.01, 0.28, "Negative sweep\n(+5 → -5)\nshown as -5 → +5", va="center", ha="left", fontsize=12)

# shared colorbar
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])

cbar = fig.colorbar(
    sm,
    ax=axes.ravel().tolist(),
    shrink=0.75,
    pad=0.01,
    location="right"
)
cbar.set_label(r"Pz (C/m$^2$)")

fig.suptitle(
    "3D FE-layer Pz colormap | columns ordered by increasing applied voltage",
    fontsize=14
)

plt.tight_layout(rect=[0.04, 0.03, 0.94, 0.93])

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=200)
    print(f"\nSaved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 20:58:44,482 Parameters: current_time              = 1.54e-11
# yt : [INFO     ] 2026-05-29 20:58:44,482 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:44,483 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:44,483 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:44,589 Parameters: current_time              = 2.4399999999999998e-11
# yt : [INFO     ] 2026-05-29 20:58:44,589 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:44,590 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:44,590 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Plotfiles to read:
#   plt00000077
#   plt00000122
#   plt00000170
#   plt00000223
#   plt00000282
#   plt00000348
#   plt00000425
#   plt00000517
#   plt00000633
#   plt00000790
#   plt00001069
#   plt00001239
#   plt00001361
#   plt00001456
#   plt00001535
#   plt00001603
#   plt00001663
#   plt00001717
#   plt00001766
#   plt00001811
#   plt00001853
# yt : [INFO     ] 2026-05-29 20:58:44,962 Parameters: current_time              = 3.4000000000000076e-11
# yt : [INFO     ] 2026-05-29 20:58:44,963 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:44,964 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:44,964 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:45,072 Parameters: current_time              = 4.4600000000000245e-11
# yt : [INFO     ] 2026-05-29 20:58:45,073 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:45,073 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:45,074 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:45,177 Parameters: current_time              = 5.6400000000000433e-11
# yt : [INFO     ] 2026-05-29 20:58:45,178 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:45,178 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:45,179 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:45,282 Parameters: current_time              = 6.960000000000028e-11
# yt : [INFO     ] 2026-05-29 20:58:45,283 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:45,283 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:45,284 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:45,396 Parameters: current_time              = 8.500000000000003e-11
# yt : [INFO     ] 2026-05-29 20:58:45,397 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:45,398 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:45,398 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:45,504 Parameters: current_time              = 1.0339999999999973e-10
# yt : [INFO     ] 2026-05-29 20:58:45,504 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:45,505 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:45,506 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:45,615 Parameters: current_time              = 1.266e-10
# yt : [INFO     ] 2026-05-29 20:58:45,615 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:45,616 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:45,617 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:45,727 Parameters: current_time              = 1.5800000000000152e-10
# yt : [INFO     ] 2026-05-29 20:58:45,727 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:45,728 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:45,728 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:45,835 Parameters: current_time              = 2.1380000000000421e-10
# yt : [INFO     ] 2026-05-29 20:58:45,837 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:45,837 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:45,838 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:45,942 Parameters: current_time              = 2.4780000000000585e-10
# yt : [INFO     ] 2026-05-29 20:58:45,942 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:45,943 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:45,944 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:46,048 Parameters: current_time              = 2.7220000000000703e-10
# yt : [INFO     ] 2026-05-29 20:58:46,049 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:46,049 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:46,050 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:46,163 Parameters: current_time              = 2.9120000000000795e-10
# yt : [INFO     ] 2026-05-29 20:58:46,164 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:46,164 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:46,165 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:46,271 Parameters: current_time              = 3.070000000000087e-10
# yt : [INFO     ] 2026-05-29 20:58:46,272 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:46,273 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:46,273 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:46,384 Parameters: current_time              = 3.2060000000000937e-10
# yt : [INFO     ] 2026-05-29 20:58:46,384 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:46,385 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:46,385 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:46,747 Parameters: current_time              = 3.3260000000000995e-10
# yt : [INFO     ] 2026-05-29 20:58:46,748 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:46,748 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:46,749 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:46,853 Parameters: current_time              = 3.4340000000001047e-10
# yt : [INFO     ] 2026-05-29 20:58:46,854 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:46,854 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:46,855 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:46,959 Parameters: current_time              = 3.5320000000001094e-10
# yt : [INFO     ] 2026-05-29 20:58:46,959 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:46,960 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:46,960 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:47,062 Parameters: current_time              = 3.6220000000001137e-10
# yt : [INFO     ] 2026-05-29 20:58:47,063 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:47,063 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:47,063 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:47,171 Parameters: current_time              = 3.706000000000118e-10
# yt : [INFO     ] 2026-05-29 20:58:47,172 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:47,173 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:47,173 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read records:
# plt00000077  step=77  Vtop=-5.1370 V  Vround=-5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000122  step=122  Vtop=-4.1430 V  Vround=-4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000170  step=170  Vtop=-3.1483 V  Vround=-3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000223  step=223  Vtop=-2.1527 V  Vround=-2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000282  step=282  Vtop=-1.1562 V  Vround=-1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000348  step=348  Vtop=-0.1585 V  Vround=-0  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000425  step=425  Vtop=+0.8408 V  Vround=+1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000517  step=517  Vtop=+1.8422 V  Vround=+2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000633  step=633  Vtop=+2.8467 V  Vround=+3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000790  step=790  Vtop=+3.8566 V  Vround=+4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001069  step=1069  Vtop=+4.8787 V  Vround=+5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001239  step=1239  Vtop=+3.8566 V  Vround=+4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001361  step=1361  Vtop=+2.8467 V  Vround=+3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001456  step=1456  Vtop=+1.8422 V  Vround=+2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001535  step=1535  Vtop=+0.8408 V  Vround=+1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001603  step=1603  Vtop=-0.1585 V  Vround=-0  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001663  step=1663  Vtop=-1.1562 V  Vround=-1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001717  step=1717  Vtop=-2.1527 V  Vround=-2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001766  step=1766  Vtop=-3.1483 V  Vround=-3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001811  step=1811  Vtop=-4.1430 V  Vround=-4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001853  step=1853  Vtop=-5.1370 V  Vround=-5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
#
# Positive sweep records:
#   V=-5  plt00000077
#   V=-4  plt00000122
#   V=-3  plt00000170
#   V=-2  plt00000223
#   V=-1  plt00000282
#   V=-0  plt00000348
#   V=+1  plt00000425
#   V=+2  plt00000517
#   V=+3  plt00000633
#   V=+4  plt00000790
#   V=+5  plt00001069
#
# Negative sweep records:
#   V=+5  plt00001069
#   V=+4  plt00001239
#   V=+3  plt00001361
#   V=+2  plt00001456
#   V=+1  plt00001535
#   V=-0  plt00001603
#   V=-1  plt00001663
#   V=-2  plt00001717
#   V=-3  plt00001766
#   V=-4  plt00001811
#   V=-5  plt00001853
# /tmp/ipykernel_707859/2315896281.py:387: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0.04, 0.03, 0.94, 0.93])
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/Pz_FE_3D_2x11_sweep.png

# %% [markdown]
# ## 3D Contour plot

# %% [markdown]
# * 畫出長方體三個面
# * 選擇要畫的三個面C1,C2,C3
# * 選擇視角

# %%
from pathlib import Path

import yt
import numpy as np
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_plt")
   # 改成你要畫的 plotfile

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 如果 FE 只想取部分 x/y 範圍
USE_FE_X_RANGE = False


USE_FE_Y_RANGE = False


# contour levels
N_LEVELS = 21

# 視角
ELEV = 35
AZIM = -45

# 色階是否對稱於 0
SYMMETRIC_COLOR_SCALE = True

SAVE_FIG= True
OUT_FIG = PLOT_DIR/"Pz_FE_3D_contour.png"

# ==========================
# Helper
# ==========================

def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


# ==========================
# Load data
# ==========================

plotfile = PLOT_DIR / PLOTFILE_NAME
ds = yt.load(str(plotfile))
g = ds.index.grids[0]

P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

if PHI_FIELD in ds.field_list:
    Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
else:
    Phi = None

Nx, Ny, Nz = P.shape

lo = ds.domain_left_edge.to_value()
hi = ds.domain_right_edge.to_value()
dx = (hi - lo) / np.array([Nx, Ny, Nz])

x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9


# ==========================
# Select FE layer
# ==========================

z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

if USE_FE_X_RANGE:
    x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
else:
    x_sel = np.ones_like(x_nm, dtype=bool)

if USE_FE_Y_RANGE:
    y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
else:
    y_sel = np.ones_like(y_nm, dtype=bool)

P_fe = P[np.ix_(x_sel, y_sel, z_sel)]

x_fe = x_nm[x_sel]
y_fe = y_nm[y_sel]
z_fe = z_nm[z_sel]

Nx_fe, Ny_fe, Nz_fe = P_fe.shape

# 選三個切面：
# xy plane at top FE surface
k_top = Nz_fe - 1

# xz plane at y min side
#j_mid = Ny_fe // 2

# yz plane at x max side
i_right = Nx_fe - 1

P_xy = P_fe[:, :, k_top]      # shape (Nx, Ny)
P_xz = P_fe[:, 0, :]      # shape (Nx, Nz)
P_yz = P_fe[i_right, :, :]    # shape (Ny, Nz)

# 建立 2D coordinates
X_xy, Y_xy = np.meshgrid(x_fe, y_fe, indexing="ij")
X_xz, Z_xz = np.meshgrid(x_fe, z_fe, indexing="ij")
Y_yz, Z_yz = np.meshgrid(y_fe, z_fe, indexing="ij")


# ==========================
# Voltage label
# ==========================

if Phi is not None:
    top_phi = Phi[:, :, -1]
    Vtop_mean = float(np.mean(top_phi))
else:
    Vtop_mean = np.nan


# ==========================
# Color scale
# ==========================

if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(P_fe))
    vmin = -vmax
else:
    vmin = np.nanmin(P_fe)
    vmax = np.nanmax(P_fe)

levels = np.linspace(vmin, vmax, N_LEVELS)

kw = dict(
    levels=levels,
    vmin=vmin,
    vmax=vmax,
    cmap="RdBu",
)


# ==========================
# Plot 3D contour walls
# ==========================

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection="3d")

xmin, xmax = x_fe.min(), x_fe.max()
ymin, ymax = y_fe.min(), y_fe.max()
zmin, zmax = z_fe.min(), z_fe.max()

# 1. xy plane, placed at z = zmax
# contourf expects arrays with same shape.
# X_xy/Y_xy/P_xy are (Nx, Ny)
C1 = ax.contourf(
    X_xy,
    Y_xy,
    P_xy,
    zdir="z",
    offset=zmax,
    **kw
)

# 2. xz plane, placed at y = ymin
# Here x-axis is X_xz, vertical is Z_xz, color is P_xz
C2 = ax.contourf(
    X_xz,
    P_xz,
    Z_xz,
    zdir="y",
    offset=ymin,
    **kw
)

# 3. yz plane, placed at x = xmax
# Here horizontal axis is Y_yz, vertical is Z_yz, color is P_yz
C3 = ax.contourf(
    P_yz,
    Y_yz,
    Z_yz,
    zdir="x",
    offset=xmax,
    **kw
)

# Set axis limits
ax.set(
    xlim=[xmin, xmax],
    ylim=[ymin, ymax],
    zlim=[zmin, zmax],
)

# Draw box edges
edges_kw = dict(color="0.35", linewidth=1.0, zorder=1000)

# 只畫可見的外框邊，不畫背後被內容遮住的線
visible_edges = [
    # bottom/front-ish edges
    ([xmin, xmax], [ymin, ymin], [zmin, zmin]),
    ([xmax, xmax], [ymin, ymax], [zmin, zmin]),
    ([xmax, xmax], [ymin, ymin], [zmin, zmax]),

    # top/front-ish edges
    ([xmin, xmax], [ymin, ymin], [zmax, zmax]),
    ([xmax, xmax], [ymin, ymax], [zmax, zmax]),
    ([xmax, xmax], [ymin, ymin], [zmin, zmax]),
]

for xs, ys, zs in visible_edges:
    ax.plot(xs, ys, zs, **edges_kw)
ax.set_xlabel("x (nm)")
ax.set_ylabel("y (nm)")
ax.set_zlabel("z (nm)")

ax.view_init(ELEV, AZIM)
Z_VISUAL_SCALE = 2.5
ax.set_box_aspect((
    xmax - xmin,
    ymax - ymin,
    Z_VISUAL_SCALE * (zmax - zmin)
))

ax.set_title(
    f"{PLOTFILE_NAME}\n"
    f"FE-layer Pz contour walls | Vg ≈ {Vtop_mean:+.3f} V"
)

cbar = fig.colorbar(C3, ax=ax, fraction=0.035, pad=0.12)
cbar.set_label(r"Pz (C/m$^2$)")

plt.tight_layout()

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=300)
    print(f"\nSaved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 20:58:54,623 Parameters: current_time              = 1.0339999999999973e-10
# yt : [INFO     ] 2026-05-29 20:58:54,624 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:54,625 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:54,625 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/Pz_FE_3D_contour.png

# %% [markdown]
# ## PV

# %%
from pathlib import Path
import re

import yt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_1_plt")

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 如果 FE 是全幅 MFIS，通常不用限制 x/y
USE_FE_X_RANGE = False


USE_FE_Y_RANGE = False
# 若你已經有 steady-state plot_names，就用 AUTO_FIND_PLOTS=False
# plot_names = [...]
AUTO_FIND_PLOTS = True

# 如果沒有 plot_names，可以自動找所有 plt########
# 但建議最好只用 steady-state plotfiles
SKIP_INITIAL = True

OUT_CSV = PLOT_DIR/"MFIS_PV_curve.csv"
OUT_FIG = PLOT_DIR/"MFIS_PV_curve.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v

def read_full_field_from_grids(ds, field):
    """
    Read a cell-centered AMReX field from all yt grids
    and stitch them into one full-domain numpy array.

    Return:
        full: numpy array with shape ds.domain_dimensions
    """
    dims = np.array(ds.domain_dimensions, dtype=int)
    full = np.empty(tuple(dims), dtype=float)

    domain_lo = ds.domain_left_edge.to_value()
    domain_hi = ds.domain_right_edge.to_value()
    dx = (domain_hi - domain_lo) / dims

    for grid in ds.index.grids:
        arr = to_numpy(grid[field])

        left = grid.LeftEdge.to_value()

        # grid start index in global domain
        start = np.rint((left - domain_lo) / dx).astype(int)

        nx, ny, nz = arr.shape
        i0, j0, k0 = start
        i1, j1, k1 = i0 + nx, j0 + ny, k0 + nz

        full[i0:i1, j0:j1, k0:k1] = arr

    return full

def read_pv_from_plot(plotfile):
    ds = yt.load(str(plotfile))
    Pz = read_full_field_from_grids(ds, P_FIELD)
    Phi = read_full_field_from_grids(ds, PHI_FIELD)

    Nx, Ny, Nz = Pz.shape
    print(f"Read Pz with shape {Pz.shape} from {plotfile}")

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    print(f"Domain: x [{lo[0]:.3e}, {hi[0]:.3e}] m, "
          f"y [{lo[1]:.3e}, {hi[1]:.3e}] m, "
          f"z [{lo[2]:.3e}, {hi[2]:.3e}] m")
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    if USE_FE_Y_RANGE:
        y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
    else:
        y_sel = np.ones_like(y_nm, dtype=bool)

    Pz_FE = Pz[np.ix_(x_sel, y_sel, z_sel)]

    P_mean = float(np.mean(Pz_FE))
    P_min = float(np.min(Pz_FE))
    P_max = float(np.max(Pz_FE))
    P_std = float(np.std(Pz_FE))

    # 用最上層 cell 的 Phi 平均值估 top electrode potential
    # 注意：這是 top cell center，不是真正 ghost boundary
    top_phi = Phi[:, :, -1]
    Vg_mean = float(np.mean(top_phi))
    Vg_min = float(np.min(top_phi))
    Vg_max = float(np.max(top_phi))
    Vg_std = float(np.std(top_phi))

    return {
        "P_mean": P_mean,
        "P_min": P_min,
        "P_max": P_max,
        "P_std": P_std,
        "Vg_mean": Vg_mean,
        "Vg_min": Vg_min,
        "Vg_max": Vg_max,
        "Vg_std": Vg_std,
        "Nx": Nx,
        "Ny": Ny,
        "Nz": Nz,
        "num_FE_cells": int(Pz_FE.size),
    }


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    print(f"Finding plotfiles in {PLOT_DIR}...")
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

plot_names_use = sorted(
    plot_names_use,
    key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99
)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

rows = []

print(plot_names_use)

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    step = get_step_from_name(name)

    info = read_pv_from_plot(plotfile)

    rows.append({
        "plotfile": name,
        "step": step,
        **info,
    })

    print(
        f"{name} | step={step} | "
        f"Vg={info['Vg_mean']:+.4f} V | "
        f"<Pz>_FE={info['P_mean']:+.6e}"
    )

df = pd.DataFrame(rows)
df.to_csv(OUT_CSV, index=False)
print(f"Saved CSV: {OUT_CSV}")


# ==========================
# Determine sweep direction
# ==========================

V = df["Vg_mean"].to_numpy()
P = df["P_mean"].to_numpy()


direction = np.zeros_like(V)

for i in range(1, len(V)):
    dV = V[i] - V[i - 1]
    if dV > 1e-8:
        direction[i] = 1   # positive sweep
    elif dV < -1e-8:
        direction[i] = -1  # negative sweep
    else:
        direction[i] = direction[i - 1]

#np.append(direction, direction[-1])  # 複製第一筆到最後

df["sweep_direction"] = direction
df.to_csv(OUT_CSV, index=False)
# Out:
# yt : [INFO     ] 2026-05-29 20:58:55,240 Parameters: current_time              = 1.54e-11
# yt : [INFO     ] 2026-05-29 20:58:55,241 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:55,241 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:55,242 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Finding plotfiles in /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt...
# ['plt00000077', 'plt00000122', 'plt00000170', 'plt00000223', 'plt00000282', 'plt00000348', 'plt00000425', 'plt00000517', 'plt00000633', 'plt00000790', 'plt00001069', 'plt00001239', 'plt00001361', 'plt00001456', 'plt00001535', 'plt00001603', 'plt00001663', 'plt00001717', 'plt00001766', 'plt00001811', 'plt00001853']
# yt : [INFO     ] 2026-05-29 20:58:55,348 Parameters: current_time              = 2.4399999999999998e-11
# yt : [INFO     ] 2026-05-29 20:58:55,349 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:55,349 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:55,350 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000077
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000077 | step=77 | Vg=-5.1370 V | <Pz>_FE=+2.735730e-01
# yt : [INFO     ] 2026-05-29 20:58:55,455 Parameters: current_time              = 3.4000000000000076e-11
# yt : [INFO     ] 2026-05-29 20:58:55,456 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:55,456 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:55,457 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000122
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000122 | step=122 | Vg=-4.1430 V | <Pz>_FE=+2.679171e-01
# yt : [INFO     ] 2026-05-29 20:58:55,565 Parameters: current_time              = 4.4600000000000245e-11
# yt : [INFO     ] 2026-05-29 20:58:55,566 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:55,566 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:55,567 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000170
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000170 | step=170 | Vg=-3.1483 V | <Pz>_FE=+2.618729e-01
# yt : [INFO     ] 2026-05-29 20:58:55,675 Parameters: current_time              = 5.6400000000000433e-11
# yt : [INFO     ] 2026-05-29 20:58:55,675 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:55,676 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:55,676 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000223
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000223 | step=223 | Vg=-2.1527 V | <Pz>_FE=+2.553672e-01
# yt : [INFO     ] 2026-05-29 20:58:55,781 Parameters: current_time              = 6.960000000000028e-11
# yt : [INFO     ] 2026-05-29 20:58:55,782 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:55,783 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:55,783 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000282
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000282 | step=282 | Vg=-1.1562 V | <Pz>_FE=+2.483013e-01
# yt : [INFO     ] 2026-05-29 20:58:55,888 Parameters: current_time              = 8.500000000000003e-11
# yt : [INFO     ] 2026-05-29 20:58:55,889 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:55,889 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:55,890 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000348
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000348 | step=348 | Vg=-0.1585 V | <Pz>_FE=+2.405359e-01
# yt : [INFO     ] 2026-05-29 20:58:55,993 Parameters: current_time              = 1.0339999999999973e-10
# yt : [INFO     ] 2026-05-29 20:58:55,994 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:55,994 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:55,995 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000425
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000425 | step=425 | Vg=+0.8408 V | <Pz>_FE=+2.318634e-01
# yt : [INFO     ] 2026-05-29 20:58:56,096 Parameters: current_time              = 1.266e-10
# yt : [INFO     ] 2026-05-29 20:58:56,097 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:56,098 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:56,098 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000517
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000517 | step=517 | Vg=+1.8422 V | <Pz>_FE=+2.219502e-01
# yt : [INFO     ] 2026-05-29 20:58:56,202 Parameters: current_time              = 1.5800000000000152e-10
# yt : [INFO     ] 2026-05-29 20:58:56,203 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:56,203 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:56,204 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000633
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000633 | step=633 | Vg=+2.8467 V | <Pz>_FE=+2.101952e-01
# yt : [INFO     ] 2026-05-29 20:58:56,536 Parameters: current_time              = 2.1380000000000421e-10
# yt : [INFO     ] 2026-05-29 20:58:56,537 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:56,537 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:56,538 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:56,643 Parameters: current_time              = 2.4780000000000585e-10
# yt : [INFO     ] 2026-05-29 20:58:56,644 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:56,644 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:56,645 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00000790
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000790 | step=790 | Vg=+3.8566 V | <Pz>_FE=+1.952844e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001069
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001069 | step=1069 | Vg=+4.8787 V | <Pz>_FE=+1.729039e-01
# yt : [INFO     ] 2026-05-29 20:58:56,747 Parameters: current_time              = 2.7220000000000703e-10
# yt : [INFO     ] 2026-05-29 20:58:56,748 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:56,748 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:56,749 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:56,851 Parameters: current_time              = 2.9120000000000795e-10
# yt : [INFO     ] 2026-05-29 20:58:56,852 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:56,853 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:56,853 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001239
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001239 | step=1239 | Vg=+3.8566 V | <Pz>_FE=+1.952840e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001361
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001361 | step=1361 | Vg=+2.8467 V | <Pz>_FE=+2.101950e-01
# yt : [INFO     ] 2026-05-29 20:58:56,958 Parameters: current_time              = 3.070000000000087e-10
# yt : [INFO     ] 2026-05-29 20:58:56,959 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:56,959 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:56,959 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:57,062 Parameters: current_time              = 3.2060000000000937e-10
# yt : [INFO     ] 2026-05-29 20:58:57,063 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:57,063 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:57,064 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001456
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001456 | step=1456 | Vg=+1.8422 V | <Pz>_FE=+2.219501e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001535
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001535 | step=1535 | Vg=+0.8408 V | <Pz>_FE=+2.318633e-01
# yt : [INFO     ] 2026-05-29 20:58:57,167 Parameters: current_time              = 3.3260000000000995e-10
# yt : [INFO     ] 2026-05-29 20:58:57,168 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:57,169 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:57,169 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:57,272 Parameters: current_time              = 3.4340000000001047e-10
# yt : [INFO     ] 2026-05-29 20:58:57,273 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:57,273 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:57,274 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001603
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001603 | step=1603 | Vg=-0.1585 V | <Pz>_FE=+2.405358e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001663
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001663 | step=1663 | Vg=-1.1562 V | <Pz>_FE=+2.483012e-01
# yt : [INFO     ] 2026-05-29 20:58:57,376 Parameters: current_time              = 3.5320000000001094e-10
# yt : [INFO     ] 2026-05-29 20:58:57,377 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:57,377 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:57,378 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 20:58:57,481 Parameters: current_time              = 3.6220000000001137e-10
# yt : [INFO     ] 2026-05-29 20:58:57,481 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:57,482 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:57,482 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001717
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001717 | step=1717 | Vg=-2.1527 V | <Pz>_FE=+2.553671e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001766
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001766 | step=1766 | Vg=-3.1483 V | <Pz>_FE=+2.618728e-01
# yt : [INFO     ] 2026-05-29 20:58:57,590 Parameters: current_time              = 3.706000000000118e-10
# yt : [INFO     ] 2026-05-29 20:58:57,591 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 20:58:57,591 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 20:58:57,592 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001811
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001811 | step=1811 | Vg=-4.1430 V | <Pz>_FE=+2.679171e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/plt00001853
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001853 | step=1853 | Vg=-5.1370 V | <Pz>_FE=+2.735730e-01
# Saved CSV: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/MFIS_PV_curve.csv

# %%
def sci_tex(x, sig=2):
    """Return LaTeX like 1.23\\times10^{-4} (no 'e')."""
    if x == 0:
        return r"0"
    exp = int(np.floor(np.log10(abs(x))))
    mant = x / (10 ** exp)
    return rf"{mant:.{sig}f}\times 10^{{{exp}}}"

# ==========================
# Plot PV curve
# ==========================

plt.figure(figsize=(6, 5))

textstr = '\n'.join((
    r'In SI units:',
    rf'$\alpha={sci_tex(ALPHA, sig=2)}$',
    rf'$\beta={sci_tex(BETA, sig=2)}$',
    rf'$\gamma={sci_tex(SMALL_GAMMA, sig=2)}$',
    rf'$g_{{11}}={sci_tex(G11, sig=2)}$',
    rf'$g_{{44}}={sci_tex(G44, sig=2)}$',
    rf'$t_{{fe}}={sci_tex((FE_Z_HI_NM-FE_Z_LO_NM)*1e-9, sig=2)}$',
))

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
plt.text(-5, -0.005, textstr, fontsize=12,
        verticalalignment='top', bbox=props)

# time-order full loop
plt.plot(V, P, "-o", markersize=4, linewidth=1.2, label="time order")

# optional: highlight positive / negative sweep
pos = df["sweep_direction"].to_numpy() >= 0
neg = df["sweep_direction"].to_numpy() < 0

if np.any(pos):
    plt.plot(V[pos], P[pos], "o", markersize=5, label="positive sweep")

if np.any(neg):
    plt.plot(V[neg], P[neg], "s", markersize=5, label="negative sweep")

plt.axhline(0, linewidth=0.8)
plt.axvline(0, linewidth=0.8)

plt.xlabel(r"$V_g$ (V)")
plt.ylabel(r"$\langle P_z \rangle_\mathrm{FE}$ (C/m$^2$)")
plt.title("MFIS P-V Curve")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

plt.savefig(OUT_FIG, dpi=200)
print(f"Saved figure: {OUT_FIG}")

plt.show()
# Out:
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_8_plt/MFIS_PV_curve.png
