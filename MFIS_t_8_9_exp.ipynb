# %% [markdown]
# # 本次模擬cmd log資訊
#
# * 2026/05/29（21點）開始模擬
# * 只保留最後一個iteration(1049)的迭代資訊和AMReX finalize(如下)

# %% [markdown]
# MLMG: Initial rhs               = 709757916.1
# MLMG: Initial residual (resid0) = 8508544871
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.002629175782, 3.090041625e-13
# MLMG: Timers: Solve = 0.783956338 Iter = 0.779976323 Bottom = 0.773815771
# 1 iterations :: err = 1
# MLMG: Initial rhs               = 709757916.1
# MLMG: Initial residual (resid0) = 8508544871
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.003484736985, 4.095573377e-13
# MLMG: Timers: Solve = 0.798654656 Iter = 0.794660183 Bottom = 0.788434677
# 2 iterations :: err = 9.20368548e-11
# Steady state check : (phi(t) - phi(t-1)).norm0() = 9.344238075e-08
# Advanced step 1049 in 1.665358246 seconds
#
# step = 1049, Phi_Bc_hi = -4, num_Vapp = 21, sign = 1
# MLMG: Initial rhs               = 709758370.9
# MLMG: Initial residual (resid0) = 6809344814
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.001146739364, 1.68406711e-13
# MLMG: Timers: Solve = 0.791813914 Iter = 0.787923855 Bottom = 0.781789283
# 1 iterations :: err = 1
# MLMG: Initial rhs               = 709758370.9
# MLMG: Initial residual (resid0) = 6809344814
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.0009852488292, 1.446906944e-13
# MLMG: Timers: Solve = 0.855205436 Iter = 0.851205027 Bottom = 0.845039726
# 2 iterations :: err = 1.341314829e-05
# MLMG: Initial rhs               = 709758370.9
# MLMG: Initial residual (resid0) = 6809344814
# MLMG: Final Iter. 3 resid, resid/resid0 = 0.001639665905, 2.407964275e-13
# MLMG: Timers: Solve = 0.813937134 Iter = 0.809946362 Bottom = 0.803786508
# 3 iterations :: err = 1.594971212e-09
# voltage_sweep == 1 && num_Vapp == num_Vapp_max!
# High-water FAB megabyte spread across MPI nodes: [44 ... 44]
# Current     FAB megabyte spread across MPI nodes: [34 ... 34]
# Total run time 1988.265503 seconds
#
#
# TinyProfiler total time across processes [min...avg...max]: 1988 ... 1988 ... 1988
#
# ---------------------------------------------------------------------------------------------
# Name                                          NCalls  Excl. Min  Excl. Avg  Excl. Max   Max %
# ---------------------------------------------------------------------------------------------
# amrex::Dot()                                 1212282      403.6      408.6        415  20.87%
# MLABecLaplacian::normalize()                  612717      242.8      244.9      247.7  12.46%
# MLABecLaplacian::Fapply()                     614909      237.6      242.8      246.4  12.39%
# MLCGSolver::ParallelAllReduce                1524094      189.8      209.6      235.4  11.84%
# FabArray::norminf()                           625775      216.9      217.2      217.4  10.93%
# FillBoundary_finish()                         623423        197      197.7      198.2   9.97%
# FillBoundary_nowait()                         623423        149      156.6      161.5   8.12%
# FabArray::Saypy_Saxpy()                       300905       54.2      61.88      70.89   3.57%
# FabArray::Saxpy_Saxpy()                       305236      62.23      65.11      69.02   3.47%
# FabArray::Saxpy_Xpay()                        298660      52.21      58.08      62.86   3.16%
# ComputePhi_Rho()                                1070      21.67      22.99      25.72   1.29%
# amrex::Copy()                                  36457      15.47      17.59      18.37   0.92%
# FabArray::setVal()                             40442      16.45      16.65      16.99   0.85%
# Calculate_Landau()                              1049      14.68      14.82      14.96   0.75%
# Calculate_Grad()                                1049      7.641      7.735      7.833   0.39%
# MLCGSolver::bicgstab                            6576      7.495      7.501      7.507   0.38%
# ComputeEfromPhi()                               2098      4.773      5.116      5.366   0.27%
# FabArray::LinComb()                             5339      4.148      4.846      5.348   0.27%
# MLCellLinOp::applyBC()                        614909       5.08      5.088      5.099   0.26%
# Calculate_Elec()                                1049      2.974      3.398      3.795   0.19%
# FabArray::FillBoundary()                      623423      2.615      2.616      2.617   0.13%
# MLCellLinOp::apply()                          614909      2.584      2.584      2.585   0.13%
# main()                                             1      1.658      1.973      2.364   0.12%
# MLMG::ResNormInf()                              8768     0.7911     0.8933     0.9488   0.05%
# MLMG::solve()                                   2192     0.3667     0.4192     0.4635   0.02%
# MLMG::actualBottomSolve()                       6576    0.06711    0.06779    0.06827   0.00%
# MLCellLinOp::solutionResidual()                 8768    0.03699    0.03708    0.03718   0.00%
# MLMG::oneIter()                                 6576    0.03209    0.03249    0.03265   0.00%
# MLMG::mgVcycle_bottom                           6576    0.02073     0.0208    0.02091   0.00%
# MLMG::computeResidual()                         6576    0.01904    0.01909    0.01917   0.00%
# MLMG::mgVcycle()                                6576    0.01884    0.01888    0.01892   0.00%
# MLMG::computeMLResidual()                       2192   0.006199   0.006223   0.006263   0.00%
# Other                                         666459      11.37      11.56      11.82   0.59%
# ---------------------------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------------------------
# Name                                          NCalls  Incl. Min  Incl. Avg  Incl. Max   Max %
# ---------------------------------------------------------------------------------------------
# main()                                             1       1988       1988       1988 100.00%
# ComputePhi_Rho()                                1070       1946       1946       1946  97.86%
# MLMG::solve()                                   2192       1899       1899       1899  95.49%
# MLMG::oneIter()                                 6576       1878       1878       1878  94.45%
# MLMG::mgVcycle()                                6576       1877       1877       1877  94.38%
# MLMG::mgVcycle_bottom                           6576       1877       1877       1877  94.38%
# MLMG::actualBottomSolve()                       6576       1877       1877       1877  94.38%
# MLCGSolver::bicgstab                            6576       1875       1875       1876  94.33%
# MLCellLinOp::apply()                          614909      589.7      603.1      612.3  30.79%
# MLCGSolver::ParallelAllReduce                1524094      377.7      396.3      419.2  21.08%
# amrex::Dot()                                 1212282      403.6      408.6        415  20.87%
# MLCellLinOp::applyBC()                        614909      349.5      357.8      363.3  18.27%
# FabArray::FillBoundary()                      623423      349.5      357.7      363.2  18.27%
# MLABecLaplacian::normalize()                  612717      242.8      244.9      247.7  12.46%
# MLABecLaplacian::Fapply()                     614909      237.6      242.8      246.4  12.39%
# FabArray::norminf()                           625775      216.9      217.2      217.4  10.93%
# FillBoundary_finish()                         623423        197      197.7      198.2   9.97%
# FillBoundary_nowait()                         623423      149.9      157.5      162.4   8.17%
# FabArray::Saypy_Saxpy()                       300905       54.2      61.88      70.89   3.57%
# FabArray::Saxpy_Saxpy()                       305236      62.23      65.11      69.02   3.47%
# FabArray::Saxpy_Xpay()                        298660      52.21      58.08      62.86   3.16%
# amrex::Copy()                                  36457      15.47      17.59      18.37   0.92%
# FabArray::setVal()                             40442      16.45      16.65      16.99   0.85%
# Calculate_Landau()                              1049      14.68      14.82      14.96   0.75%
# MLCellLinOp::solutionResidual()                 8768      13.24      13.24      13.25   0.67%
# MLMG::computeResidual()                         6576      9.102      9.105      9.108   0.46%
# Calculate_Grad()                                1049      7.641      7.735      7.833   0.39%
# ComputeEfromPhi()                               2098      4.773      5.116      5.366   0.27%
# FabArray::LinComb()                             5339      4.148      4.846      5.348   0.27%
# MLMG::computeMLResidual()                       2192       4.16      4.162      4.167   0.21%
# MLMG::ResNormInf()                              8768      3.691      3.787      3.836   0.19%
# Calculate_Elec()                                1049      2.974      3.398      3.795   0.19%
# Other                                         666459      17.88      18.07      18.36   0.92%
# ---------------------------------------------------------------------------------------------
#
# Device Memory Usage:
# ----------------------------------------------------------------------------------------------------------------------------
# Name                                          Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ----------------------------------------------------------------------------------------------------------------------------
# The_Arena::Initialize()                            4       0   B       0   B       0   B     731 MiB     731 MiB     731 MiB
# main()                                           976      29 MiB      29 MiB      29 MiB      30 MiB      30 MiB      30 MiB
# WritePlotfile()                                  352    3744   B    3783   B    3893   B    8496 KiB    8496 KiB    8496 KiB
# ResizeRandomSeed                                   8    4607 KiB    4607 KiB    4607 KiB    4608 KiB    4608 KiB    4608 KiB
# MLCGSolver::bicgstab                          526080    2495 KiB    2495 KiB    2495 KiB    2652 KiB    2652 KiB    2652 KiB
# MLMG::prepareForSolve()                           64    2033 KiB    2033 KiB    2033 KiB    2034 KiB    2034 KiB    2034 KiB
# MLABecLaplacian::define()                         64    1955 KiB    1955 KiB    1955 KiB    1956 KiB    1956 KiB    1956 KiB
# ComputePhi_Rho()                              246336      18 KiB      18 KiB      19 KiB    1888 KiB    1888 KiB    1888 KiB
# MultiFab::OverlapMask()                        44880     869   B     876   B     885   B     472 KiB     472 KiB     472 KiB
# BndryData::define()                              192     433 KiB     433 KiB     433 KiB     434 KiB     434 KiB     434 KiB
# MLCellLinOp::defineAuxData()                     192     203 KiB     203 KiB     203 KiB     204 KiB     204 KiB     204 KiB
# VisMF::Write(FabArray)                          6336       9   B       9   B      10   B      48 KiB      48 KiB      48 KiB
# FillBoundary_nowait()                         122824      43 KiB      43 KiB      43 KiB      44 KiB      44 KiB      44 KiB
# MultiFab::max()                                 4288     514   B     514   B     515   B      24 KiB      24 KiB      24 KiB
# amrex::Dot()                                 4849128    4925   B    4986   B    5067   B      24 KiB      24 KiB      24 KiB
# FabArray::norminf()                          2503100    2644   B    2647   B    2651   B      24 KiB      24 KiB      24 KiB
# MultiFab::norm1                                 8976       8   B       8   B       9   B      24 KiB      24 KiB      24 KiB
# FabArray::setVal()                             87824      18 KiB      18 KiB      18 KiB      19 KiB      19 KiB      19 KiB
# FillBoundary_finish()                          61412      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB
# amrex::Copy()                                  44196    8165   B    8165   B    8166   B    8192   B    8192   B    8192   B
# MLCellLinOp::applyBC()                       2468432    6910   B    6910   B    6910   B    7168   B    7168   B    7168   B
# MLCellLinOp::prepareForSolve()                     4       0   B       0   B       0   B    4096   B    4096   B    4096   B
# FabArray::setVal(val, thecmd, scomp, ncomp)       56       0   B       0   B       0   B    1024   B    1024   B    1024   B
# FabArray::LinComb()                             8772     512   B     512   B     513   B    1024   B    1024   B    1024   B
# MLABecLaplacian::Fapply()                      52608     945   B     945   B     945   B    1024   B    1024   B    1024   B
# MultiFab::Divide()                              8976       0   B       0   B       0   B     512   B     512   B     512   B
# MLCellLinOp::defineBC()                            4     511   B     511   B     511   B     512   B     512   B     512   B
# ----------------------------------------------------------------------------------------------------------------------------
#
# Managed Memory Usage:
# ---------------------------------------------------------------------------------------------------------------
# Name                             Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ---------------------------------------------------------------------------------------------------------------
# The_Managed_Arena::Initialize()       4       0   B       0   B       0   B    8192 KiB    8192 KiB    8192 KiB
# main()                                4       0   B       0   B       0   B      31 KiB      31 KiB      31 KiB
# ---------------------------------------------------------------------------------------------------------------
#
# Pinned Memory Usage:
# ----------------------------------------------------------------------------------------------------------------------------
# Name                                          Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ----------------------------------------------------------------------------------------------------------------------------
# The_Pinned_Arena::Initialize()                     4       0   B       0   B       0   B    8192 KiB    8192 KiB    8192 KiB
# VisMF::Write(FabArray)                          6688     262   B     263   B     267   B    2124 KiB    2124 KiB    2124 KiB
# FillBoundary_nowait()                        5110208      54 KiB      54 KiB      54 KiB     104 KiB     104 KiB     104 KiB
# FabArray::setVal()                             87824      18 KiB      18 KiB      18 KiB      19 KiB      19 KiB      19 KiB
# FillBoundary_finish()                          61412      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB      14 KiB
# amrex::Copy()                                  44196    8165   B    8165   B    8166   B    8192   B    8192   B    8192   B
# MLCellLinOp::applyBC()                          8796    6910   B    6910   B    6910   B    6912   B    6912   B    6912   B
# MLCellLinOp::prepareForSolve()                     4       0   B       0   B       0   B    4096   B    4096   B    4096   B
# FabArray::LinComb()                             8772     512   B     512   B     513   B    1024   B    1024   B    1024   B
# FabArray::setVal(val, thecmd, scomp, ncomp)       56       0   B       0   B       0   B    1024   B    1024   B    1024   B
# MLABecLaplacian::Fapply()                      52608     945   B     945   B     945   B    1024   B    1024   B    1024   B
# MultiFab::OverlapMask()                         8976       0   B       0   B       0   B     768   B     768   B     768   B
# MultiFab::max()                                 4288     512   B     512   B     512   B     768   B     768   B     768   B
# MLCellLinOp::setLevelBC()                         88       0   B       0   B       0   B     512   B     512   B     512   B
# MultiFab::Divide()                              8976       0   B       0   B       0   B     512   B     512   B     512   B
# amrex::Dot()                                 4849128      51   B      51   B      52   B     256   B     256   B     256   B
# Unprofiled                                        60       0   B       0   B       0   B     256   B     256   B     256   B
# MultiFab::norm1                                 8976       0   B       0   B       0   B     256   B     256   B     256   B
# FabArray::norminf()                          2503100      27   B      27   B      27   B     256   B     256   B     256   B
# ----------------------------------------------------------------------------------------------------------------------------
#
# Total GPU global memory (MB) spread across MPI: [3901 ... 3901]
# Free  GPU global memory (MB) spread across MPI: [547 ... 547]
# [The         Arena] max space (MB) allocated spread across MPI: [731 ... 731]
# [The         Arena] max space (MB) used      spread across MPI: [47 ... 47]
# [The Managed Arena] max space (MB) allocated spread across MPI: [8 ... 8]
# [The Managed Arena] max space (MB) used      spread across MPI: [0 ... 0]
# [The  Pinned Arena] max space (MB) allocated spread across MPI: [8 ... 8]
# [The  Pinned Arena] max space (MB) used      spread across MPI: [2 ... 2]
# AMReX (26.05-39-gbe2cc437644f) finalized

# %% [markdown]
# # 使用者設定

# %%
import re
from pathlib import Path

import yt
import numpy as np
import pandas as pd


# =========================
# User settings
# =========================
PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt")          # plotfile 所在資料夾
PLOT_PREFIX = "plt"
PLOT_INTERVAL = 10000000           # 你的 plot_int，例如 100

# 如果你的 field 名稱不是 ("boxlib", "Phi")，後面會自動列出 field_list 方便你改
PHI_FIELD_CANDIDATES = [
    ("boxlib", "Phi"),
    ("boxlib", "phi"),
    ("boxlib", "PoissonPhi"),
    "Phi",
    "phi",
    "PoissonPhi",
]

# FE layer range, unit: nm
FE_Z_LO_NM = 21.5
FE_Z_HI_NM = 29.5

# 如果你想只畫 FE 的 x 範圍，也可以打開這兩行
# 若是 MFIS 全幅 FE，通常用整個 x 範圍即可

FE_X_LO_NM = -16.0
FE_X_HI_NM = 16.0

FE_Y_LO_NM = -16.0
FE_Y_HI_NM = 16.0

ALPHA = -6.25e9
BETA = 1.0e10
SMALL_GAMMA = 1.5e11
G11 = 1.0e-9
G44 = 1.0e-9


# 3D sweep plot要畫的電壓欄位：-5, -4, ..., 5
VOLTAGES = np.arange(-5, 6, 1)
# 3D contour 要畫的plotfile
PLOTFILE_NAME = "plt00000425"

# %% [markdown]
# ## Utils

# %%
def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v

def read_full_field_from_grids(ds, field):
    """
    Read a cell-centered AMReX field from all yt grids
    and stitch them into one full-domain numpy array.

    Return:
        full: numpy array with shape ds.domain_dimensions
    """
    dims = np.array(ds.domain_dimensions, dtype=int)
    full = np.empty(tuple(dims), dtype=float)

    domain_lo = ds.domain_left_edge.to_value()
    domain_hi = ds.domain_right_edge.to_value()
    dx = (domain_hi - domain_lo) / dims

    for grid in ds.index.grids:
        arr = to_numpy(grid[field])

        left = grid.LeftEdge.to_value()

        # grid start index in global domain
        start = np.rint((left - domain_lo) / dx).astype(int)

        nx, ny, nz = arr.shape
        i0, j0, k0 = start
        i1, j1, k1 = i0 + nx, j0 + ny, k0 + nz

        full[i0:i1, j0:j1, k0:k1] = arr

    return full

# %% [markdown]
# # plot

# %% [markdown]
# ## 看有哪些 plotfile

# %%
from pathlib import Path
import yt


plot_paths = sorted([p for p in PLOT_DIR.glob(f"{PLOT_PREFIX}*") if p.is_dir()])

# 只要名稱 (plt000100, ...)
plot_names = [p.name for p in plot_paths]

print("Available plotfiles:")
for name in plot_names:
    print("  ", name)
# Out:
# Available plotfiles:
#    plt00000000
#    plt00000070
#    plt00000105
#    plt00000141
#    plt00000179
#    plt00000220
#    plt00000264
#    plt00000312
#    plt00000365
#    plt00000425
#    plt00000495
#    plt00000580
#    plt00000653
#    plt00000715
#    plt00000769
#    plt00000818
#    plt00000863
#    plt00000905
#    plt00000944
#    plt00000981
#    plt00001016
#    plt00001049

# %% [markdown]
# ## 探索yt資料結構

# %% [markdown]
# ### dir(ds) # 列出 ds 所有(variable和property和method)

# %% [markdown]
# * Note: variable和property和method統稱attribute

# %%
ds = yt.load(PLOT_DIR/plot_names[0])  # 載入指定的 plotfile
dir(ds) # 列出 ds 所有變數和屬性和方法
#[a for a in dir(ds) if not a.startswith("_")]
# Out:
# yt : [INFO     ] 2026-05-29 21:45:47,982 Parameters: current_time              = 0.0
# yt : [INFO     ] 2026-05-29 21:45:47,982 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:47,983 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:47,984 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_object_class',
#  '_arr',
#  '_assign_unit_system',
#  '_create_unit_registry',
#  '_default_cparam_filename',
#  '_determined_fields',
#  '_field_info',
#  '_field_info_class',
#  '_field_list',
#  '_find_extremum',
#  '_force_periodicity',
#  '_get_field_info',
#  '_get_field_info_helper',
#  '_guess_candidates',
#  '_hash',
#  '_header_mesh_start',
#  '_index_class',
#  '_input_filename',
#  '_instantiated',
#  '_instantiated_index',
#  '_ionization_label_format',
#  '_is_valid',
#  '_is_within_domain',
#  '_load_requirements',
#  '_localize_check',
#  '_lookup_cparam_filepath',
#  '_max_level',
#  '_min_level',
#  '_missing_load_requirements',
#  '_mrep',
#  '_output_prefix',
#  '_override_code_units',
#  '_parse_cparams',
#  '_parse_fparams',
#  '_parse_header_file',
#  '_parse_parameter_file',
#  '_particle_type_counts',
#  '_periodicity',
#  '_proj_type',
#  '_quan',
#  '_sanitize_units_override',
#  '_set_code_unit_attributes',
#  '_set_derived_attrs',
#  '_setup_classes',
#  '_setup_coordinate_handler',
#  '_setup_filtered_type',
#  '_setup_particle_type',
#  '_setup_particle_types',
#  '_skip_cache',
#  '_unit_system_id',
#  '_unit_system_name',
#  '_units',
#  '_uses_code_length_unit',
#  '_uses_code_time_unit',
#  '_validate_units_override_keys',
#  'add_deposited_particle_field',
#  'add_field',
#  'add_gradient_fields',
#  'add_mesh_sampling_particle_field',
#  'add_particle_filter',
#  'add_particle_union',
#  'all_data',
#  'arbitrary_grid',
#  'arr',
#  'backup_filename',
#  'basename',
#  'bool',
#  'box',
#  'checksum',
#  'close',
#  'conversion_factors',
#  'coordinates',
#  'covering_grid',
#  'cparam_filename',
#  'create_field_info',
#  'current_time',
#  'cut_region',
#  'cutting',
#  'data_collection',
#  'dataset_type',
#  'default_field',
#  'default_fluid_type',
#  'default_species_fields',
#  'default_units',
#  'define_unit',
#  'derived_field_list',
#  'dimensionality',
#  'directory',
#  'disk',
#  'domain_center',
#  'domain_dimensions',
#  'domain_left_edge',
#  'domain_offset',
#  'domain_right_edge',
#  'domain_width',
#  'ellipsoid',
#  'field_info',
#  'field_list',
#  'field_units',
#  'fields',
#  'fields_detected',
#  'filename',
#  'find_field_values_at_point',
#  'find_field_values_at_points',
#  'find_max',
#  'find_min',
#  'fluid_types',
#  'force_periodicity',
#  'fparam_filename',
#  'fullpath',
#  'geometry',
#  'get_smallest_appropriate_unit',
#  'get_unit_from_registry',
#  'has_key',
#  'index',
#  'intersection',
#  'ires_factor',
#  'known_filters',
#  'length_unit',
#  'level_offsets',
#  'mass_unit',
#  'max_level',
#  'min_level',
#  'minimal_sphere',
#  'no_cgs_equiv_length',
#  'object_types',
#  'objects',
#  'octree',
#  'orion_version',
#  'ortho_ray',
#  'output_dir',
#  'parameter_filename',
#  'parameters',
#  'particle_fields_by_type',
#  'particle_type_counts',
#  'particle_types',
#  'particle_types_raw',
#  'particle_unions',
#  'particles_exist',
#  'periodicity',
#  'plots',
#  'point',
#  'print_key_parameters',
#  'print_stats',
#  'proj',
#  'quan',
#  'r',
#  'ray',
#  'ref_factors',
#  'refine_by',
#  'region',
#  'region_expression',
#  'relative_refinement',
#  'set_code_units',
#  'set_field_label_format',
#  'set_units',
#  'setup_cosmology',
#  'setup_deprecated_fields',
#  'slice',
#  'smoothed_covering_grid',
#  'sphere',
#  'storage_filename',
#  'streamline',
#  'surface',
#  'time_unit',
#  'union',
#  'unique_identifier',
#  'unit_registry',
#  'unit_system',
#  'units',
#  'units_override',
#  'velocity_unit']

# %% [markdown]
# ### 用key word查看dir(ds)中可能會用到的attribute

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "domain"
    if "domain" in a.lower():
        print(a)
# Out:
# _is_within_domain
# domain_center
# domain_dimensions
# domain_left_edge
# domain_offset
# domain_right_edge
# domain_width

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "field"
    if "field" in a.lower():
        print(a)
# Out:
# _determined_fields
# _field_info
# _field_info_class
# _field_list
# _get_field_info
# _get_field_info_helper
# add_deposited_particle_field
# add_field
# add_gradient_fields
# add_mesh_sampling_particle_field
# create_field_info
# default_field
# default_species_fields
# derived_field_list
# field_info
# field_list
# field_units
# fields
# fields_detected
# find_field_values_at_point
# find_field_values_at_points
# particle_fields_by_type
# set_field_label_format
# setup_deprecated_fields

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "index"
    if "index" in a.lower():
        print(a)
# Out:
# _index_class
# _instantiated_index
# index

# %% [markdown]
# * **grid相關attribute在index內**

# %%
for a in dir(ds.index): # 列出 ds.index 裡有哪些屬性和方法，特別是包含 "index"
    if "grid" in a.lower():
        print(a)
# Out:
# _count_grids
# _get_grid_objs
# _get_grid_tree
# _get_grids
# _grid_chunksize
# _grids
# _initialize_grid_arrays
# _populate_grid_objects
# grid
# grid_corners
# grid_dimensions
# grid_left_edge
# grid_levels
# grid_particle_count
# grid_right_edge
# grid_start_index
# grids
# lock_grids_to_parents
# num_grids
# select_grids

# %%
for a in dir(ds.index.grids[0]): # 列出 ds.index.grids[0] 裡有哪些屬性和方法，特別是包含 "index"
    
        print(a)
# Out:
# ActiveDimensions
# Children
# LeftEdge
# Level
# NumberOfParticles
# OverlappingSiblings
# Parent
# RightEdge
# __abstractmethods__
# __add__
# __and__
# __annotations__
# __class__
# __delattr__
# __delitem__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __int__
# __invert__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __or__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __setitem__
# __sizeof__
# __slots__
# __str__
# __sub__
# __subclasshook__
# __weakref__
# __xor__
# _abc_impl
# _activate_cache
# _base_offset
# _cache_mask
# _child_index_mask
# _child_indices
# _child_mask
# _children_ids
# _chunk_info
# _chunked_read
# _compute_extrema
# _con_args
# _container_fields
# _count_particles
# _current_chunk
# _current_fluid_type
# _current_particle_type
# _data_source
# _debug
# _default_field_parameters
# _derived_quantity_chunking
# _determine_fields
# _distributed
# _ds_hold
# _extrema_cache
# _field_cache
# _field_lock
# _field_parameter_state
# _field_type_state
# _fill_child_mask
# _finalize_parallel
# _first_matching_field
# _generate_container_field
# _generate_field
# _generate_fields
# _generate_fluid_field
# _generate_particle_field
# _generate_spatial_fluid
# _get_grid_objs
# _get_grids
# _get_objs
# _get_offset
# _get_selector_mask
# _grids
# _hash
# _id_offset
# _identify_dependencies
# _index
# _initialize_cache
# _initialize_parallel
# _ipython_key_completions_
# _is_default_field_parameter
# _last_count
# _last_mask
# _last_selector_id
# _locked
# _max_level
# _min_level
# _num_ghost_zones
# _offset
# _parameter_iterate
# _parent_id
# _pdata
# _prepare_grid
# _reshape_vals
# _selector
# _set_center
# _set_default_field_parameters
# _setup_dx
# _skip_add
# _sort_by
# _spatial
# _tds_attrs
# _tds_fields
# _tree
# _type_name
# apply_units
# argmax
# argmin
# blocks
# child_index_mask
# child_indices
# child_mask
# chunks
# clear_data
# clone
# comm
# convert
# count
# count_particles
# create_firefly_object
# dds
# deposit
# ds
# fcoords
# fcoords_vertex
# field_data
# field_parameters
# filename
# fwidth
# get_data
# get_dependencies
# get_field_parameter
# get_global_startindex
# get_position
# get_vertex_centered_data
# has_field_parameter
# has_key
# icoords
# id
# index
# integrate
# ires
# keys
# max
# max_level
# mean
# min
# min_level
# particle_operation
# partition_index_2d
# partition_index_3d
# partition_index_3d_bisection_list
# partition_region_3d
# pf
# profile
# ptp
# quantities
# retrieve_ghost_zones
# save_as_dataset
# select
# select_blocks
# select_fcoords
# select_fwidth
# select_icoords
# select_ires
# select_particles
# select_tcoords
# selector
# set_field_parameter
# shape
# smooth
# start_index
# std
# sum
# tiles
# to_astropy_table
# to_dataframe
# to_glue
# write_out

# %% [markdown]
# ## yt dataset

# %% [markdown]
# * 可以從上一個部份"探索yt資料結構"找想用的attribute

# %%
print("========== Dataset ==========")
print("type:", type(ds))
print("用SI單位")
print("current_time(s):", ds.current_time)
print("domain_left_edge(m) :", ds.domain_left_edge)
print("domain_right_edge(m):", ds.domain_right_edge)
print("domain_center:", ds.domain_center)
print("domain_width(domain邊長):", ds.domain_width)
print("domain_offset:", ds.domain_offset)
print("domain_dimensions(xyz方向各切成幾格):", ds.domain_dimensions)
print("dimensionality:", ds.dimensionality)
print("geometry:", ds.geometry)
#print("periodicity:", ds.periodicity)

print("\n========== Fields ==========")
for f in ds.field_list:
    print(" ", f)
# Out:
# ========== Dataset ==========
# type: <class 'yt.frontends.amrex.data_structures.BoxlibDataset'>
# 用SI單位
# current_time(s): 0.0 code_time
# domain_left_edge(m) : [-1.6e-08 -1.6e-08  0.0e+00] code_length
# domain_right_edge(m): [1.60e-08 1.60e-08 2.95e-08] code_length
# domain_center: [0.000e+00 0.000e+00 1.475e-08] code_length
# domain_width(domain邊長): [3.20e-08 3.20e-08 2.95e-08] code_length
# domain_offset: [0 0 0]
# domain_dimensions(xyz方向各切成幾格): [64 64 59]
# dimensionality: 3
# geometry: cartesian
#
# ========== Fields ==========
#   ('boxlib', 'Ex')
#   ('boxlib', 'Ey')
#   ('boxlib', 'Ez')
#   ('boxlib', 'Phi')
#   ('boxlib', 'PhiDiff')
#   ('boxlib', 'PoissonRHS')
#   ('boxlib', 'Px')
#   ('boxlib', 'Py')
#   ('boxlib', 'Pz')
#   ('boxlib', 'alpha')
#   ('boxlib', 'beta')
#   ('boxlib', 'charge')
#   ('boxlib', 'electrons')
#   ('boxlib', 'epsilon')
#   ('boxlib', 'holes')
#   ('boxlib', 'mask')
#   ('boxlib', 'theta')
#   ('boxlib', 'tphase')

# %% [markdown]
# * domain切成多個grid分配給mpi rank平行運算，**資料分散在每個grid**

# %%
print("\n========== Grids ==========")
print("number of grids:", len(ds.index.grids))
for i, g in enumerate(ds.index.grids):
    print(f"grid {i}:")
    print("  LeftEdge:", g.LeftEdge)
    print("  RightEdge:", g.RightEdge)
    print("  ActiveDimensions:", g.ActiveDimensions)
    print("  Level:", g.Level)
print(ds.index.grid_start_index)
# Out:
# ========== Grids ==========
# number of grids: 16
# grid 0:
#   LeftEdge: [-1.6e-08 -1.6e-08  0.0e+00] code_length
#   RightEdge: [-8.00e-09 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 1:
#   LeftEdge: [-8.0e-09 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 0.00e+00 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 2:
#   LeftEdge: [ 0.0e+00 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 8.00e-09 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 3:
#   LeftEdge: [ 8.0e-09 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 1.60e-08 -8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 4:
#   LeftEdge: [-1.6e-08 -8.0e-09  0.0e+00] code_length
#   RightEdge: [-8.00e-09  0.00e+00  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 5:
#   LeftEdge: [-8.e-09 -8.e-09  0.e+00] code_length
#   RightEdge: [0.00e+00 0.00e+00 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 6:
#   LeftEdge: [ 0.e+00 -8.e-09  0.e+00] code_length
#   RightEdge: [8.00e-09 0.00e+00 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 7:
#   LeftEdge: [ 8.e-09 -8.e-09  0.e+00] code_length
#   RightEdge: [1.60e-08 0.00e+00 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 8:
#   LeftEdge: [-1.6e-08  0.0e+00  0.0e+00] code_length
#   RightEdge: [-8.00e-09  8.00e-09  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 9:
#   LeftEdge: [-8.e-09  0.e+00  0.e+00] code_length
#   RightEdge: [0.00e+00 8.00e-09 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 10:
#   LeftEdge: [0. 0. 0.] code_length
#   RightEdge: [8.00e-09 8.00e-09 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 11:
#   LeftEdge: [8.e-09 0.e+00 0.e+00] code_length
#   RightEdge: [1.60e-08 8.00e-09 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 12:
#   LeftEdge: [-1.6e-08  8.0e-09  0.0e+00] code_length
#   RightEdge: [-8.00e-09  1.60e-08  2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 13:
#   LeftEdge: [-8.e-09  8.e-09  0.e+00] code_length
#   RightEdge: [0.00e+00 1.60e-08 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 14:
#   LeftEdge: [0.e+00 8.e-09 0.e+00] code_length
#   RightEdge: [8.00e-09 1.60e-08 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# grid 15:
#   LeftEdge: [8.e-09 8.e-09 0.e+00] code_length
#   RightEdge: [1.60e-08 1.60e-08 2.95e-08] code_length
#   ActiveDimensions: [16 16 59]
#   Level: 0
# [[ 0  0  0]
#  [16  0  0]
#  [32  0  0]
#  [48  0  0]
#  [ 0 16  0]
#  [16 16  0]
#  [32 16  0]
#  [48 16  0]
#  [ 0 32  0]
#  [16 32  0]
#  [32 32  0]
#  [48 32  0]
#  [ 0 48  0]
#  [16 48  0]
#  [32 48  0]
#  [48 48  0]]

# %% [markdown]
# ## **2Dfield繪製**

# %% [markdown]
# * g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
# * x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置

# %%
import yt
import numpy as np
import matplotlib.pyplot as plt
for i in range(len(plot_names)):
    plotfile = PLOT_DIR/plot_names[i] 
    field = ("boxlib", "Phi")

    ds = yt.load(plotfile)

    #g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
    Phi_array = read_full_field_from_grids(ds, field) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid

    print("Phi_array shape =", Phi_array.shape)

    Nx, Ny, Nz = Phi_array.shape #用index存資料

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dims = np.array([Nx, Ny, Nz])

    dx = (hi - lo) / dims

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    y0 = Ny // 2
    slice2d = Phi_array[:, y0, :]

    plt.figure(figsize=(6, 5))
    im = plt.pcolormesh(
        x_nm,
        z_nm,
        slice2d.T,
        shading="auto",
        cmap="RdBu"
    )

    plt.colorbar(im, label="Ex")
    plt.xlabel("x (nm)")
    plt.ylabel("z (nm)")
    plt.title(f"Phi x-z slice at y index = {y0}")
    plt.tight_layout()
    plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 21:45:48,344 Parameters: current_time              = 0.0
# yt : [INFO     ] 2026-05-29 21:45:48,345 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:48,345 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:48,346 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:48,667 Parameters: current_time              = 1.3999999999999999e-11
# yt : [INFO     ] 2026-05-29 21:45:48,668 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:48,668 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:48,669 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:48,903 Parameters: current_time              = 2.1e-11
# yt : [INFO     ] 2026-05-29 21:45:48,904 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:48,904 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:48,904 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:49,144 Parameters: current_time              = 2.8199999999999997e-11
# yt : [INFO     ] 2026-05-29 21:45:49,145 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:49,145 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:49,146 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:49,495 Parameters: current_time              = 3.5800000000000105e-11
# yt : [INFO     ] 2026-05-29 21:45:49,496 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:49,496 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:49,497 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:49,715 Parameters: current_time              = 4.4000000000000236e-11
# yt : [INFO     ] 2026-05-29 21:45:49,716 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:49,716 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:49,717 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:49,949 Parameters: current_time              = 5.2800000000000376e-11
# yt : [INFO     ] 2026-05-29 21:45:49,949 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:49,950 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:49,950 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:50,176 Parameters: current_time              = 6.24000000000004e-11
# yt : [INFO     ] 2026-05-29 21:45:50,177 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:50,177 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:50,177 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:50,413 Parameters: current_time              = 7.300000000000023e-11
# yt : [INFO     ] 2026-05-29 21:45:50,413 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:50,414 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:50,415 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:50,649 Parameters: current_time              = 8.500000000000003e-11
# yt : [INFO     ] 2026-05-29 21:45:50,650 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:50,650 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:50,651 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:51,028 Parameters: current_time              = 9.89999999999998e-11
# yt : [INFO     ] 2026-05-29 21:45:51,028 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:51,029 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:51,029 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:51,275 Parameters: current_time              = 1.1599999999999952e-10
# yt : [INFO     ] 2026-05-29 21:45:51,276 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:51,276 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:51,277 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:51,508 Parameters: current_time              = 1.306000000000002e-10
# yt : [INFO     ] 2026-05-29 21:45:51,509 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:51,509 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:51,510 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:51,735 Parameters: current_time              = 1.430000000000008e-10
# yt : [INFO     ] 2026-05-29 21:45:51,735 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:51,736 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:51,736 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:51,958 Parameters: current_time              = 1.5380000000000132e-10
# yt : [INFO     ] 2026-05-29 21:45:51,959 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:51,959 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:51,960 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:52,323 Parameters: current_time              = 1.636000000000018e-10
# yt : [INFO     ] 2026-05-29 21:45:52,323 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:52,324 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:52,324 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:52,540 Parameters: current_time              = 1.7260000000000223e-10
# yt : [INFO     ] 2026-05-29 21:45:52,541 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:52,541 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:52,542 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:52,758 Parameters: current_time              = 1.8100000000000263e-10
# yt : [INFO     ] 2026-05-29 21:45:52,759 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:52,759 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:52,759 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:52,985 Parameters: current_time              = 1.88800000000003e-10
# yt : [INFO     ] 2026-05-29 21:45:52,986 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:52,986 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:52,987 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:53,201 Parameters: current_time              = 1.9620000000000337e-10
# yt : [INFO     ] 2026-05-29 21:45:53,202 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:53,202 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:53,202 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:53,558 Parameters: current_time              = 2.032000000000037e-10
# yt : [INFO     ] 2026-05-29 21:45:53,559 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:53,559 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:53,559 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)
# yt : [INFO     ] 2026-05-29 21:45:53,776 Parameters: current_time              = 2.0980000000000402e-10
# yt : [INFO     ] 2026-05-29 21:45:53,777 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:53,777 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:53,778 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Phi_array shape = (64, 64, 59)

# %%
import yt
import numpy as np
import matplotlib.pyplot as plt

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_plt")  # 改成你 plotfile 所在的資料夾
plotfile = PLOT_DIR/plot_names[2] 
field = ("boxlib", "Ex")

ds = yt.load(plotfile)

#g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
E_array = read_full_field_from_grids(ds, field) # 讀取整個 domain 的 Ex 資料，會自動合併多個 grid

print("E_array shape =", E_array.shape)

Nx, Ny, Nz = E_array.shape #用index存資料

lo = ds.domain_left_edge.to_value()
hi = ds.domain_right_edge.to_value()
dims = np.array([Nx, Ny, Nz])

dx = (hi - lo) / dims

x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置
z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

y0 = Ny // 2
slice2d = E_array[:, y0, :]

plt.figure(figsize=(6, 5))
im = plt.pcolormesh(
    x_nm,
    z_nm,
    slice2d.T,
    shading="auto",
    cmap="RdBu"
)

plt.colorbar(im, label="Ex")
plt.xlabel("x (nm)")
plt.ylabel("z (nm)")
plt.title(f"Ex x-z slice at y index = {y0}")
plt.tight_layout()
plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 21:45:54,014 Parameters: current_time              = 2.1e-11
# yt : [INFO     ] 2026-05-29 21:45:54,015 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:54,016 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:54,017 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# E_array shape = (64, 64, 59)

# %% [markdown]
# ## 2D Pz slice plot(all voltage in same graph)

# %%
from pathlib import Path
import re

import yt
import numpy as np
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec")          # plotfile 所在資料夾
P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")



USE_FE_X_RANGE = False

# y slice: None 表示取 y 方向正中間
Y_INDEX = None

# 若 plot_names 已經是你前面整理好的 steady-state plot list，就直接用
# plot_names = [...]
# 若沒有，就自動抓目前資料夾內所有 plt########
AUTO_FIND_PLOTS = False

# 跳過 initial plt00000000
SKIP_INITIAL = True

# 色階是否對稱於 0，畫 Pz 通常建議 True
SYMMETRIC_COLOR_SCALE = True

# 輸出圖片名稱
SAVE_FIG = True
OUT_FIG = PLOT_DIR/"Pz_FE_layer_stack.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


def read_one_plot(plotfile, y_index=None):
    ds = yt.load(str(plotfile))
    #g = ds.index.grids[0]

    P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

    if PHI_FIELD in ds.field_list:
        Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
    else:
        Phi = None

    Nx, Ny, Nz = P.shape

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    if y_index is None:
        y_index = Ny // 2

    # FE z range mask
    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    # P slice: shape after selection = (Nx_sel, Nz_sel)
    P_slice = P[np.ix_(x_sel, [y_index], z_sel)][:, 0, :]

    x_plot = x_nm[x_sel]
    z_plot = z_nm[z_sel]

    # 用最上層 cell 的 Phi 平均值當 top potential
    # 注意：這是 top cell center，不是真正 ghost boundary
    if Phi is not None:
        top_phi = Phi[:, :, -1]
        Vtop_mean = float(np.mean(top_phi))
        Vtop_min = float(np.min(top_phi))
        Vtop_max = float(np.max(top_phi))
    else:
        Vtop_mean = np.nan
        Vtop_min = np.nan
        Vtop_max = np.nan

    info = {
        "ds": ds,
        "P_slice": P_slice,
        "x_nm": x_plot,
        "z_nm": z_plot,
        "y_index": y_index,
        "y_nm": float(y_nm[y_index]),
        "Vtop_mean": Vtop_mean,
        "Vtop_min": Vtop_min,
        "Vtop_max": Vtop_max,
        "shape": P.shape,
    }

    return info


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

# sort by step if names are plt########
plot_names_use = sorted(plot_names_use, key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

print("Plotfiles to draw:")
for n in plot_names_use:
    print(" ", n)

records = []
all_values = []

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    info = read_one_plot(plotfile, y_index=Y_INDEX)

    step = get_step_from_name(name)

    records.append({
        "name": name,
        "step": step,
        **info,
    })

    all_values.append(info["P_slice"])

# shared color scale
all_concat = np.concatenate([v.ravel() for v in all_values])
if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(all_concat))
    vmin = -vmax
else:
    vmin = np.nanmin(all_concat)
    vmax = np.nanmax(all_concat)

# determine sweep direction from Vtop sequence
Vseq = np.array([r["Vtop_mean"] for r in records], dtype=float)

directions = []
for idx, V in enumerate(Vseq):
    if idx == 0 or not np.isfinite(Vseq[idx-1]) or not np.isfinite(V):
        directions.append("start")
    else:
        dV = V - Vseq[idx-1]
        if dV > 1e-8:
            directions.append("positive sweep")
        elif dV < -1e-8:
            directions.append("negative sweep")
        else:
            directions.append("same V")

# figure size
n = len(records)
fig_height = max(2.0 * n, 4.0)
fig, axes = plt.subplots(
    nrows=n,
    ncols=1,
    figsize=(7.5, fig_height),
    sharex=True,
    constrained_layout=True
)

if n == 1:
    axes = [axes]

last_im = None

for ax, rec, sweep_dir in zip(axes, records, directions):
    P_slice = rec["P_slice"]
    x_nm = rec["x_nm"]
    z_nm = rec["z_nm"]

    last_im = ax.pcolormesh(
        x_nm,
        z_nm,
        P_slice.T,
        shading="auto",
        cmap="RdBu",
        vmin=vmin,
        vmax=vmax
    )

    Vmean = rec["Vtop_mean"]
    Vmin = rec["Vtop_min"]
    Vmax = rec["Vtop_max"]

    if np.isfinite(Vmean):
        v_label = f"Vg = {Vmean:+.0f} V"
        # 若你想檢查 top x/y variation，也可以顯示 min/max
        # v_label += f" [{Vmin:+.3f}, {Vmax:+.3f}]"
    else:
        v_label = "Vtop unavailable"

    step_label = f"step={rec['step']}" if rec["step"] is not None else rec["name"]

    ax.set_ylabel("z (nm)")

    ax.set_title(
        f"{v_label} | {sweep_dir} | "
        f"y center ≈ {rec['y_nm']:.2f} nm",
        fontsize=9
    )

axes[-1].set_xlabel("x (nm)")

cbar = fig.colorbar(last_im, ax=axes, shrink=0.8)
cbar.set_label(r"Pz (C/m$^2$)")

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=200)
    print(f"Saved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 21:45:54,274 Parameters: current_time              = 1.3999999999999999e-11
# yt : [INFO     ] 2026-05-29 21:45:54,275 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:54,275 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:54,276 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Plotfiles to draw:
#   plt00000070
#   plt00000105
#   plt00000141
#   plt00000179
#   plt00000220
#   plt00000264
#   plt00000312
#   plt00000365
#   plt00000425
#   plt00000495
#   plt00000580
#   plt00000653
#   plt00000715
#   plt00000769
#   plt00000818
#   plt00000863
#   plt00000905
#   plt00000944
#   plt00000981
#   plt00001016
#   plt00001049
# yt : [INFO     ] 2026-05-29 21:45:54,385 Parameters: current_time              = 2.1e-11
# yt : [INFO     ] 2026-05-29 21:45:54,386 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:54,386 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:54,387 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:54,683 Parameters: current_time              = 2.8199999999999997e-11
# yt : [INFO     ] 2026-05-29 21:45:54,684 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:54,685 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:54,685 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:54,805 Parameters: current_time              = 3.5800000000000105e-11
# yt : [INFO     ] 2026-05-29 21:45:54,806 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:54,806 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:54,807 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:54,923 Parameters: current_time              = 4.4000000000000236e-11
# yt : [INFO     ] 2026-05-29 21:45:54,924 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:54,925 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:54,925 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:55,040 Parameters: current_time              = 5.2800000000000376e-11
# yt : [INFO     ] 2026-05-29 21:45:55,042 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:55,042 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:55,042 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:55,156 Parameters: current_time              = 6.24000000000004e-11
# yt : [INFO     ] 2026-05-29 21:45:55,157 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:55,157 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:55,158 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:55,274 Parameters: current_time              = 7.300000000000023e-11
# yt : [INFO     ] 2026-05-29 21:45:55,275 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:55,275 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:55,276 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:55,390 Parameters: current_time              = 8.500000000000003e-11
# yt : [INFO     ] 2026-05-29 21:45:55,391 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:55,391 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:55,392 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:55,504 Parameters: current_time              = 9.89999999999998e-11
# yt : [INFO     ] 2026-05-29 21:45:55,505 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:55,505 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:55,506 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:55,618 Parameters: current_time              = 1.1599999999999952e-10
# yt : [INFO     ] 2026-05-29 21:45:55,619 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:55,619 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:55,620 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:55,737 Parameters: current_time              = 1.306000000000002e-10
# yt : [INFO     ] 2026-05-29 21:45:55,738 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:55,738 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:55,739 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:55,991 Parameters: current_time              = 1.430000000000008e-10
# yt : [INFO     ] 2026-05-29 21:45:55,992 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:55,992 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:55,993 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:56,109 Parameters: current_time              = 1.5380000000000132e-10
# yt : [INFO     ] 2026-05-29 21:45:56,109 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:56,110 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:56,110 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:56,232 Parameters: current_time              = 1.636000000000018e-10
# yt : [INFO     ] 2026-05-29 21:45:56,233 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:56,234 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:56,234 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:56,362 Parameters: current_time              = 1.7260000000000223e-10
# yt : [INFO     ] 2026-05-29 21:45:56,363 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:56,363 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:56,364 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:56,482 Parameters: current_time              = 1.8100000000000263e-10
# yt : [INFO     ] 2026-05-29 21:45:56,484 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:56,484 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:56,485 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:56,601 Parameters: current_time              = 1.88800000000003e-10
# yt : [INFO     ] 2026-05-29 21:45:56,602 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:56,603 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:56,603 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:56,721 Parameters: current_time              = 1.9620000000000337e-10
# yt : [INFO     ] 2026-05-29 21:45:56,721 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:56,722 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:56,722 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:56,834 Parameters: current_time              = 2.032000000000037e-10
# yt : [INFO     ] 2026-05-29 21:45:56,834 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:56,835 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:56,836 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:45:56,944 Parameters: current_time              = 2.0980000000000402e-10
# yt : [INFO     ] 2026-05-29 21:45:56,945 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:45:56,946 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:45:56,946 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/Pz_FE_layer_stack.png

# %% [markdown]
# ## 3D Scatter plot (all voltage in same graph)

# %% [markdown]
# * trash

# %%
from pathlib import Path
import re

import yt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec")

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 若 FE 只在部分 x/y 範圍，打開這裡
USE_FE_X_RANGE = False

USE_FE_Y_RANGE = False




# 用 top Phi 平均值四捨五入到整數電壓來分類
V_ROUND_DECIMALS = 0

# 3D 點太多會慢，STRIDE=2 表示 x/y/z 每 2 點取 1 點
# 若想更細可設 1；若很慢可設 3 或 4
STRIDE = 2

# 顏色是否以 0 對稱，畫 Pz 建議 True
SYMMETRIC_COLOR_SCALE = True

# 3D 視角
ELEV = 22
AZIM = -55

# 點大小
POINT_SIZE = 2

# 跳過 initial plt00000000
SKIP_INITIAL = True

# 若你已經有 plot_names，就保留 AUTO_FIND_PLOTS=False
# plot_names = [...]
AUTO_FIND_PLOTS = False

SAVE_FIG = True
OUT_FIG = PLOT_DIR/"Pz_FE_3D_2x11_sweep.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


def read_one_plot_3d(plotfile):
    ds = yt.load(str(plotfile))
    #g = ds.index.grids[0]

    P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

    if PHI_FIELD in ds.field_list:
        Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
    else:
        Phi = None

    Nx, Ny, Nz = P.shape

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    # FE selection
    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    if USE_FE_Y_RANGE:
        y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
    else:
        y_sel = np.ones_like(y_nm, dtype=bool)

    # Apply selection
    P_fe = P[np.ix_(x_sel, y_sel, z_sel)]

    x_fe = x_nm[x_sel]
    y_fe = y_nm[y_sel]
    z_fe = z_nm[z_sel]

    # Downsample for 3D plotting
    P_ds = P_fe[::STRIDE, ::STRIDE, ::STRIDE]
    x_ds = x_fe[::STRIDE]
    y_ds = y_fe[::STRIDE]
    z_ds = z_fe[::STRIDE]

    X, Y, Z = np.meshgrid(x_ds, y_ds, z_ds, indexing="ij")

    # Estimate top voltage from top cell Phi
    if Phi is not None:
        top_phi = Phi[:, :, -1]
        Vtop_mean = float(np.mean(top_phi))
        Vtop_min = float(np.min(top_phi))
        Vtop_max = float(np.max(top_phi))
    else:
        Vtop_mean = np.nan
        Vtop_min = np.nan
        Vtop_max = np.nan

    return {
        "P": P_ds,
        "X": X,
        "Y": Y,
        "Z": Z,
        "x_range": (float(np.min(x_fe)), float(np.max(x_fe))),
        "y_range": (float(np.min(y_fe)), float(np.max(y_fe))),
        "z_range": (float(np.min(z_fe)), float(np.max(z_fe))),
        "Vtop_mean": Vtop_mean,
        "Vtop_min": Vtop_min,
        "Vtop_max": Vtop_max,
        "shape_full": P.shape,
        "shape_fe": P_fe.shape,
        "shape_plot": P_ds.shape,
    }


def classify_sweep(records):
    """
    根據 records 原本的時間順序，用 Vtop 的變化判斷正掃/負掃。
    第一個點歸到 positive，因為通常是正掃起點。
    turning point 會同時加入 positive 與 negative，讓上下排都有 +5。
    """
    pos = []
    neg = []

    V = np.array([r["Vtop_mean"] for r in records], dtype=float)

    if len(records) == 0:
        return pos, neg

    pos.append(records[0])

    for i in range(1, len(records)):
        dV = V[i] - V[i - 1]

        if dV > 1e-8:
            pos.append(records[i])
        elif dV < -1e-8:
            # 如果剛從正掃轉負掃，把上一個 turning point 也放進 neg
            if len(neg) == 0:
                neg.append(records[i - 1])
            neg.append(records[i])
        else:
            # 同電壓重複時，不確定歸類；先放到目前方向
            if len(neg) == 0:
                pos.append(records[i])
            else:
                neg.append(records[i])

    return pos, neg


def pick_record_by_voltage(records, target_v):
    """
    從一組 records 中挑最接近 target_v 的那筆。
    """
    if len(records) == 0:
        return None

    V = np.array([r["Vround"] for r in records], dtype=float)
    idx = int(np.argmin(np.abs(V - target_v)))

    if np.abs(V[idx] - target_v) > 0.25:
        return None

    return records[idx]


def draw_3d_fe(ax, rec, norm, cmap):
    P = rec["P"]
    X = rec["X"]
    Y = rec["Y"]
    Z = rec["Z"]

    ax.scatter(
        X.ravel(),
        Y.ravel(),
        Z.ravel(),
        c=P.ravel(),
        cmap=cmap,
        norm=norm,
        s=POINT_SIZE,
        marker="s",
        linewidths=0,
        alpha=0.95,
    )

    ax.set_xlim(rec["x_range"])
    ax.set_ylim(rec["y_range"])
    ax.set_zlim(rec["z_range"])

    ax.view_init(elev=ELEV, azim=AZIM)

    # 22 張小圖，不要塞太多刻度
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])

    ax.set_box_aspect((
        rec["x_range"][1] - rec["x_range"][0],
        rec["y_range"][1] - rec["y_range"][0],
        rec["z_range"][1] - rec["z_range"][0],
    ))


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

plot_names_use = sorted(
    plot_names_use,
    key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99
)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

print("Plotfiles to read:")
for n in plot_names_use:
    print(" ", n)

records = []

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    info = read_one_plot_3d(plotfile)

    Vround = np.round(info["Vtop_mean"], V_ROUND_DECIMALS)

    rec = {
        "name": name,
        "step": get_step_from_name(name),
        "Vround": float(Vround),
        **info,
    }

    records.append(rec)

print("\nRead records:")
for r in records:
    print(
        f"{r['name']}  step={r['step']}  "
        f"Vtop={r['Vtop_mean']:+.4f} V  Vround={r['Vround']:+.0f}  "
        f"shape_fe={r['shape_fe']}  shape_plot={r['shape_plot']}"
    )

# classify positive / negative sweep from time ordering
pos_records, neg_records = classify_sweep(records)

print("\nPositive sweep records:")
for r in pos_records:
    print(f"  V={r['Vround']:+.0f}  {r['name']}")

print("\nNegative sweep records:")
for r in neg_records:
    print(f"  V={r['Vround']:+.0f}  {r['name']}")

# Arrange columns left-to-right by increasing voltage: -5, -4, ..., 5
pos_grid = [pick_record_by_voltage(pos_records, v) for v in VOLTAGES]
neg_grid = [pick_record_by_voltage(neg_records, v) for v in VOLTAGES]

# shared color scale from all selected records
selected_records = [r for r in pos_grid + neg_grid if r is not None]
if len(selected_records) == 0:
    raise RuntimeError("No records selected. Check plot_names or voltage classification.")

all_p = np.concatenate([r["P"].ravel() for r in selected_records])

if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(all_p))
    vmin = -vmax
else:
    vmin = np.nanmin(all_p)
    vmax = np.nanmax(all_p)

cmap = "RdBu"
norm = Normalize(vmin=vmin, vmax=vmax)

# 2 x 11 figure
fig = plt.figure(figsize=(22, 6.2))

axes = np.empty((2, len(VOLTAGES)), dtype=object)

for row in range(2):
    for col in range(len(VOLTAGES)):
        axes[row, col] = fig.add_subplot(
            2,
            len(VOLTAGES),
            row * len(VOLTAGES) + col + 1,
            projection="3d"
        )

for col, Vtarget in enumerate(VOLTAGES):
    rec = pos_grid[col]
    ax = axes[0, col]

    if rec is not None:
        draw_3d_fe(ax, rec, norm, cmap)
        ax.set_title(f"{Vtarget:+.0f} V\npos sweep", fontsize=9)
    else:
        ax.set_title(f"{Vtarget:+.0f} V\nmissing", fontsize=9)
        ax.axis("off")

for col, Vtarget in enumerate(VOLTAGES):
    rec = neg_grid[col]
    ax = axes[1, col]

    if rec is not None:
        draw_3d_fe(ax, rec, norm, cmap)
        ax.set_title(f"{Vtarget:+.0f} V\nneg sweep", fontsize=9)
    else:
        ax.set_title(f"{Vtarget:+.0f} V\nmissing", fontsize=9)
        ax.axis("off")

# row labels
fig.text(0.01, 0.72, "Positive sweep\n(-5 → +5)", va="center", ha="left", fontsize=12)
fig.text(0.01, 0.28, "Negative sweep\n(+5 → -5)\nshown as -5 → +5", va="center", ha="left", fontsize=12)

# shared colorbar
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])

cbar = fig.colorbar(
    sm,
    ax=axes.ravel().tolist(),
    shrink=0.75,
    pad=0.01,
    location="right"
)
cbar.set_label(r"Pz (C/m$^2$)")

fig.suptitle(
    "3D FE-layer Pz colormap | columns ordered by increasing applied voltage",
    fontsize=14
)

plt.tight_layout(rect=[0.04, 0.03, 0.94, 0.93])

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=200)
    print(f"\nSaved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 21:46:00,979 Parameters: current_time              = 1.3999999999999999e-11
# yt : [INFO     ] 2026-05-29 21:46:00,980 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:00,980 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:00,981 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:01,087 Parameters: current_time              = 2.1e-11
# yt : [INFO     ] 2026-05-29 21:46:01,088 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:01,089 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:01,090 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Plotfiles to read:
#   plt00000070
#   plt00000105
#   plt00000141
#   plt00000179
#   plt00000220
#   plt00000264
#   plt00000312
#   plt00000365
#   plt00000425
#   plt00000495
#   plt00000580
#   plt00000653
#   plt00000715
#   plt00000769
#   plt00000818
#   plt00000863
#   plt00000905
#   plt00000944
#   plt00000981
#   plt00001016
#   plt00001049
# yt : [INFO     ] 2026-05-29 21:46:01,193 Parameters: current_time              = 2.8199999999999997e-11
# yt : [INFO     ] 2026-05-29 21:46:01,194 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:01,194 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:01,194 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:01,535 Parameters: current_time              = 3.5800000000000105e-11
# yt : [INFO     ] 2026-05-29 21:46:01,536 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:01,536 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:01,537 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:01,642 Parameters: current_time              = 4.4000000000000236e-11
# yt : [INFO     ] 2026-05-29 21:46:01,643 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:01,643 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:01,643 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:01,746 Parameters: current_time              = 5.2800000000000376e-11
# yt : [INFO     ] 2026-05-29 21:46:01,746 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:01,747 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:01,747 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:01,852 Parameters: current_time              = 6.24000000000004e-11
# yt : [INFO     ] 2026-05-29 21:46:01,853 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:01,853 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:01,854 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:01,958 Parameters: current_time              = 7.300000000000023e-11
# yt : [INFO     ] 2026-05-29 21:46:01,958 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:01,959 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:01,959 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:02,063 Parameters: current_time              = 8.500000000000003e-11
# yt : [INFO     ] 2026-05-29 21:46:02,063 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:02,064 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:02,065 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:02,169 Parameters: current_time              = 9.89999999999998e-11
# yt : [INFO     ] 2026-05-29 21:46:02,170 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:02,170 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:02,171 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:02,273 Parameters: current_time              = 1.1599999999999952e-10
# yt : [INFO     ] 2026-05-29 21:46:02,273 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:02,274 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:02,274 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:02,383 Parameters: current_time              = 1.306000000000002e-10
# yt : [INFO     ] 2026-05-29 21:46:02,383 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:02,384 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:02,385 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:02,491 Parameters: current_time              = 1.430000000000008e-10
# yt : [INFO     ] 2026-05-29 21:46:02,492 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:02,492 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:02,493 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:02,600 Parameters: current_time              = 1.5380000000000132e-10
# yt : [INFO     ] 2026-05-29 21:46:02,600 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:02,601 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:02,601 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:02,706 Parameters: current_time              = 1.636000000000018e-10
# yt : [INFO     ] 2026-05-29 21:46:02,708 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:02,708 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:02,709 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:02,813 Parameters: current_time              = 1.7260000000000223e-10
# yt : [INFO     ] 2026-05-29 21:46:02,813 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:02,814 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:02,814 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:02,918 Parameters: current_time              = 1.8100000000000263e-10
# yt : [INFO     ] 2026-05-29 21:46:02,920 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:02,920 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:02,921 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:03,260 Parameters: current_time              = 1.88800000000003e-10
# yt : [INFO     ] 2026-05-29 21:46:03,260 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:03,261 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:03,261 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:03,374 Parameters: current_time              = 1.9620000000000337e-10
# yt : [INFO     ] 2026-05-29 21:46:03,375 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:03,376 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:03,376 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:03,491 Parameters: current_time              = 2.032000000000037e-10
# yt : [INFO     ] 2026-05-29 21:46:03,491 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:03,492 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:03,492 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:03,604 Parameters: current_time              = 2.0980000000000402e-10
# yt : [INFO     ] 2026-05-29 21:46:03,605 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:03,606 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:03,606 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read records:
# plt00000070  step=70  Vtop=-5.1996 V  Vround=-5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000105  step=105  Vtop=-4.2063 V  Vround=-4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000141  step=141  Vtop=-3.2125 V  Vround=-3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000179  step=179  Vtop=-2.2181 V  Vround=-2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000220  step=220  Vtop=-1.2230 V  Vround=-1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000264  step=264  Vtop=-0.2271 V  Vround=-0  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000312  step=312  Vtop=+0.7697 V  Vround=+1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000365  step=365  Vtop=+1.7678 V  Vround=+2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000425  step=425  Vtop=+2.7673 V  Vround=+3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000495  step=495  Vtop=+3.7687 V  Vround=+4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000580  step=580  Vtop=+4.7726 V  Vround=+5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000653  step=653  Vtop=+3.7687 V  Vround=+4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000715  step=715  Vtop=+2.7673 V  Vround=+3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000769  step=769  Vtop=+1.7678 V  Vround=+2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000818  step=818  Vtop=+0.7697 V  Vround=+1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000863  step=863  Vtop=-0.2271 V  Vround=-0  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000905  step=905  Vtop=-1.2230 V  Vround=-1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000944  step=944  Vtop=-2.2181 V  Vround=-2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000981  step=981  Vtop=-3.2125 V  Vround=-3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001016  step=1016  Vtop=-4.2063 V  Vround=-4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001049  step=1049  Vtop=-5.1996 V  Vround=-5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
#
# Positive sweep records:
#   V=-5  plt00000070
#   V=-4  plt00000105
#   V=-3  plt00000141
#   V=-2  plt00000179
#   V=-1  plt00000220
#   V=-0  plt00000264
#   V=+1  plt00000312
#   V=+2  plt00000365
#   V=+3  plt00000425
#   V=+4  plt00000495
#   V=+5  plt00000580
#
# Negative sweep records:
#   V=+5  plt00000580
#   V=+4  plt00000653
#   V=+3  plt00000715
#   V=+2  plt00000769
#   V=+1  plt00000818
#   V=-0  plt00000863
#   V=-1  plt00000905
#   V=-2  plt00000944
#   V=-3  plt00000981
#   V=-4  plt00001016
#   V=-5  plt00001049
# /tmp/ipykernel_713660/2315896281.py:387: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0.04, 0.03, 0.94, 0.93])
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/Pz_FE_3D_2x11_sweep.png

# %% [markdown]
# ## 3D Contour plot

# %% [markdown]
# * 畫出長方體三個面
# * 選擇要畫的三個面C1,C2,C3
# * 選擇視角

# %%
from pathlib import Path

import yt
import numpy as np
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_plt")
   # 改成你要畫的 plotfile

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 如果 FE 只想取部分 x/y 範圍
USE_FE_X_RANGE = False


USE_FE_Y_RANGE = False


# contour levels
N_LEVELS = 21

# 視角
ELEV = 35
AZIM = -45

# 色階是否對稱於 0
SYMMETRIC_COLOR_SCALE = True

SAVE_FIG= True
OUT_FIG = PLOT_DIR/"Pz_FE_3D_contour.png"

# ==========================
# Helper
# ==========================

def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


# ==========================
# Load data
# ==========================

plotfile = PLOT_DIR / PLOTFILE_NAME
ds = yt.load(str(plotfile))
g = ds.index.grids[0]

P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

if PHI_FIELD in ds.field_list:
    Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
else:
    Phi = None

Nx, Ny, Nz = P.shape

lo = ds.domain_left_edge.to_value()
hi = ds.domain_right_edge.to_value()
dx = (hi - lo) / np.array([Nx, Ny, Nz])

x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9


# ==========================
# Select FE layer
# ==========================

z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

if USE_FE_X_RANGE:
    x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
else:
    x_sel = np.ones_like(x_nm, dtype=bool)

if USE_FE_Y_RANGE:
    y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
else:
    y_sel = np.ones_like(y_nm, dtype=bool)

P_fe = P[np.ix_(x_sel, y_sel, z_sel)]

x_fe = x_nm[x_sel]
y_fe = y_nm[y_sel]
z_fe = z_nm[z_sel]

Nx_fe, Ny_fe, Nz_fe = P_fe.shape

# 選三個切面：
# xy plane at top FE surface
k_top = Nz_fe - 1

# xz plane at y min side
#j_mid = Ny_fe // 2

# yz plane at x max side
i_right = Nx_fe - 1

P_xy = P_fe[:, :, k_top]      # shape (Nx, Ny)
P_xz = P_fe[:, 0, :]      # shape (Nx, Nz)
P_yz = P_fe[i_right, :, :]    # shape (Ny, Nz)

# 建立 2D coordinates
X_xy, Y_xy = np.meshgrid(x_fe, y_fe, indexing="ij")
X_xz, Z_xz = np.meshgrid(x_fe, z_fe, indexing="ij")
Y_yz, Z_yz = np.meshgrid(y_fe, z_fe, indexing="ij")


# ==========================
# Voltage label
# ==========================

if Phi is not None:
    top_phi = Phi[:, :, -1]
    Vtop_mean = float(np.mean(top_phi))
else:
    Vtop_mean = np.nan


# ==========================
# Color scale
# ==========================

if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(P_fe))
    vmin = -vmax
else:
    vmin = np.nanmin(P_fe)
    vmax = np.nanmax(P_fe)

levels = np.linspace(vmin, vmax, N_LEVELS)

kw = dict(
    levels=levels,
    vmin=vmin,
    vmax=vmax,
    cmap="RdBu",
)


# ==========================
# Plot 3D contour walls
# ==========================

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection="3d")

xmin, xmax = x_fe.min(), x_fe.max()
ymin, ymax = y_fe.min(), y_fe.max()
zmin, zmax = z_fe.min(), z_fe.max()

# 1. xy plane, placed at z = zmax
# contourf expects arrays with same shape.
# X_xy/Y_xy/P_xy are (Nx, Ny)
C1 = ax.contourf(
    X_xy,
    Y_xy,
    P_xy,
    zdir="z",
    offset=zmax,
    **kw
)

# 2. xz plane, placed at y = ymin
# Here x-axis is X_xz, vertical is Z_xz, color is P_xz
C2 = ax.contourf(
    X_xz,
    P_xz,
    Z_xz,
    zdir="y",
    offset=ymin,
    **kw
)

# 3. yz plane, placed at x = xmax
# Here horizontal axis is Y_yz, vertical is Z_yz, color is P_yz
C3 = ax.contourf(
    P_yz,
    Y_yz,
    Z_yz,
    zdir="x",
    offset=xmax,
    **kw
)

# Set axis limits
ax.set(
    xlim=[xmin, xmax],
    ylim=[ymin, ymax],
    zlim=[zmin, zmax],
)

# Draw box edges
edges_kw = dict(color="0.35", linewidth=1.0, zorder=1000)

# 只畫可見的外框邊，不畫背後被內容遮住的線
visible_edges = [
    # bottom/front-ish edges
    ([xmin, xmax], [ymin, ymin], [zmin, zmin]),
    ([xmax, xmax], [ymin, ymax], [zmin, zmin]),
    ([xmax, xmax], [ymin, ymin], [zmin, zmax]),

    # top/front-ish edges
    ([xmin, xmax], [ymin, ymin], [zmax, zmax]),
    ([xmax, xmax], [ymin, ymax], [zmax, zmax]),
    ([xmax, xmax], [ymin, ymin], [zmin, zmax]),
]

for xs, ys, zs in visible_edges:
    ax.plot(xs, ys, zs, **edges_kw)
ax.set_xlabel("x (nm)")
ax.set_ylabel("y (nm)")
ax.set_zlabel("z (nm)")

ax.view_init(ELEV, AZIM)
Z_VISUAL_SCALE = 2.5
ax.set_box_aspect((
    xmax - xmin,
    ymax - ymin,
    Z_VISUAL_SCALE * (zmax - zmin)
))

ax.set_title(
    f"{PLOTFILE_NAME}\n"
    f"FE-layer Pz contour walls | Vg ≈ {Vtop_mean:+.3f} V"
)

cbar = fig.colorbar(C3, ax=ax, fraction=0.035, pad=0.12)
cbar.set_label(r"Pz (C/m$^2$)")

plt.tight_layout()

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=300)
    print(f"\nSaved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-05-29 21:46:10,967 Parameters: current_time              = 8.500000000000003e-11
# yt : [INFO     ] 2026-05-29 21:46:10,968 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:10,969 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:10,969 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/Pz_FE_3D_contour.png

# %% [markdown]
# ## PV

# %%
from pathlib import Path
import re

import yt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_1_plt")

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 如果 FE 是全幅 MFIS，通常不用限制 x/y
USE_FE_X_RANGE = False


USE_FE_Y_RANGE = False
# 若你已經有 steady-state plot_names，就用 AUTO_FIND_PLOTS=False
# plot_names = [...]
AUTO_FIND_PLOTS = True

# 如果沒有 plot_names，可以自動找所有 plt########
# 但建議最好只用 steady-state plotfiles
SKIP_INITIAL = True

OUT_CSV = PLOT_DIR/"MFIS_PV_curve.csv"
OUT_FIG = PLOT_DIR/"MFIS_PV_curve.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v

def read_full_field_from_grids(ds, field):
    """
    Read a cell-centered AMReX field from all yt grids
    and stitch them into one full-domain numpy array.

    Return:
        full: numpy array with shape ds.domain_dimensions
    """
    dims = np.array(ds.domain_dimensions, dtype=int)
    full = np.empty(tuple(dims), dtype=float)

    domain_lo = ds.domain_left_edge.to_value()
    domain_hi = ds.domain_right_edge.to_value()
    dx = (domain_hi - domain_lo) / dims

    for grid in ds.index.grids:
        arr = to_numpy(grid[field])

        left = grid.LeftEdge.to_value()

        # grid start index in global domain
        start = np.rint((left - domain_lo) / dx).astype(int)

        nx, ny, nz = arr.shape
        i0, j0, k0 = start
        i1, j1, k1 = i0 + nx, j0 + ny, k0 + nz

        full[i0:i1, j0:j1, k0:k1] = arr

    return full

def read_pv_from_plot(plotfile):
    ds = yt.load(str(plotfile))
    Pz = read_full_field_from_grids(ds, P_FIELD)
    Phi = read_full_field_from_grids(ds, PHI_FIELD)

    Nx, Ny, Nz = Pz.shape
    print(f"Read Pz with shape {Pz.shape} from {plotfile}")

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    print(f"Domain: x [{lo[0]:.3e}, {hi[0]:.3e}] m, "
          f"y [{lo[1]:.3e}, {hi[1]:.3e}] m, "
          f"z [{lo[2]:.3e}, {hi[2]:.3e}] m")
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    if USE_FE_Y_RANGE:
        y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
    else:
        y_sel = np.ones_like(y_nm, dtype=bool)

    Pz_FE = Pz[np.ix_(x_sel, y_sel, z_sel)]

    P_mean = float(np.mean(Pz_FE))
    P_min = float(np.min(Pz_FE))
    P_max = float(np.max(Pz_FE))
    P_std = float(np.std(Pz_FE))

    # 用最上層 cell 的 Phi 平均值估 top electrode potential
    # 注意：這是 top cell center，不是真正 ghost boundary
    top_phi = Phi[:, :, -1]
    Vg_mean = float(np.mean(top_phi))
    Vg_min = float(np.min(top_phi))
    Vg_max = float(np.max(top_phi))
    Vg_std = float(np.std(top_phi))

    return {
        "P_mean": P_mean,
        "P_min": P_min,
        "P_max": P_max,
        "P_std": P_std,
        "Vg_mean": Vg_mean,
        "Vg_min": Vg_min,
        "Vg_max": Vg_max,
        "Vg_std": Vg_std,
        "Nx": Nx,
        "Ny": Ny,
        "Nz": Nz,
        "num_FE_cells": int(Pz_FE.size),
    }


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    print(f"Finding plotfiles in {PLOT_DIR}...")
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

plot_names_use = sorted(
    plot_names_use,
    key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99
)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

rows = []

print(plot_names_use)

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    step = get_step_from_name(name)

    info = read_pv_from_plot(plotfile)

    rows.append({
        "plotfile": name,
        "step": step,
        **info,
    })

    print(
        f"{name} | step={step} | "
        f"Vg={info['Vg_mean']:+.4f} V | "
        f"<Pz>_FE={info['P_mean']:+.6e}"
    )

df = pd.DataFrame(rows)
df.to_csv(OUT_CSV, index=False)
print(f"Saved CSV: {OUT_CSV}")


# ==========================
# Determine sweep direction
# ==========================

V = df["Vg_mean"].to_numpy()
P = df["P_mean"].to_numpy()


direction = np.zeros_like(V)

for i in range(1, len(V)):
    dV = V[i] - V[i - 1]
    if dV > 1e-8:
        direction[i] = 1   # positive sweep
    elif dV < -1e-8:
        direction[i] = -1  # negative sweep
    else:
        direction[i] = direction[i - 1]

#np.append(direction, direction[-1])  # 複製第一筆到最後

df["sweep_direction"] = direction
df.to_csv(OUT_CSV, index=False)
# Out:
# yt : [INFO     ] 2026-05-29 21:46:11,576 Parameters: current_time              = 1.3999999999999999e-11
# yt : [INFO     ] 2026-05-29 21:46:11,576 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:11,577 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:11,578 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Finding plotfiles in /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt...
# ['plt00000070', 'plt00000105', 'plt00000141', 'plt00000179', 'plt00000220', 'plt00000264', 'plt00000312', 'plt00000365', 'plt00000425', 'plt00000495', 'plt00000580', 'plt00000653', 'plt00000715', 'plt00000769', 'plt00000818', 'plt00000863', 'plt00000905', 'plt00000944', 'plt00000981', 'plt00001016', 'plt00001049']
# yt : [INFO     ] 2026-05-29 21:46:11,689 Parameters: current_time              = 2.1e-11
# yt : [INFO     ] 2026-05-29 21:46:11,690 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:11,690 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:11,691 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000070
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000070 | step=70 | Vg=-5.1996 V | <Pz>_FE=+3.526409e-01
# yt : [INFO     ] 2026-05-29 21:46:11,798 Parameters: current_time              = 2.8199999999999997e-11
# yt : [INFO     ] 2026-05-29 21:46:11,799 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:11,800 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:11,800 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000105
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000105 | step=105 | Vg=-4.2063 V | <Pz>_FE=+3.480261e-01
# yt : [INFO     ] 2026-05-29 21:46:11,910 Parameters: current_time              = 3.5800000000000105e-11
# yt : [INFO     ] 2026-05-29 21:46:11,911 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:11,911 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:11,912 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000141
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000141 | step=141 | Vg=-3.2125 V | <Pz>_FE=+3.431690e-01
# yt : [INFO     ] 2026-05-29 21:46:12,019 Parameters: current_time              = 4.4000000000000236e-11
# yt : [INFO     ] 2026-05-29 21:46:12,019 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:12,020 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:12,020 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000179
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000179 | step=179 | Vg=-2.2181 V | <Pz>_FE=+3.380363e-01
# yt : [INFO     ] 2026-05-29 21:46:12,126 Parameters: current_time              = 5.2800000000000376e-11
# yt : [INFO     ] 2026-05-29 21:46:12,127 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:12,127 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:12,128 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000220
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000220 | step=220 | Vg=-1.2230 V | <Pz>_FE=+3.325866e-01
# yt : [INFO     ] 2026-05-29 21:46:12,236 Parameters: current_time              = 6.24000000000004e-11
# yt : [INFO     ] 2026-05-29 21:46:12,237 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:12,237 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:12,238 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000264
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000264 | step=264 | Vg=-0.2271 V | <Pz>_FE=+3.267672e-01
# yt : [INFO     ] 2026-05-29 21:46:12,344 Parameters: current_time              = 7.300000000000023e-11
# yt : [INFO     ] 2026-05-29 21:46:12,345 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:12,345 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:12,346 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000312
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000312 | step=312 | Vg=+0.7697 V | <Pz>_FE=+3.205096e-01
# yt : [INFO     ] 2026-05-29 21:46:12,452 Parameters: current_time              = 8.500000000000003e-11
# yt : [INFO     ] 2026-05-29 21:46:12,453 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:12,454 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:12,454 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000365
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000365 | step=365 | Vg=+1.7678 V | <Pz>_FE=+3.137210e-01
# yt : [INFO     ] 2026-05-29 21:46:12,561 Parameters: current_time              = 9.89999999999998e-11
# yt : [INFO     ] 2026-05-29 21:46:12,562 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:12,562 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:12,563 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000425
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000425 | step=425 | Vg=+2.7673 V | <Pz>_FE=+3.062715e-01
# yt : [INFO     ] 2026-05-29 21:46:12,668 Parameters: current_time              = 1.1599999999999952e-10
# yt : [INFO     ] 2026-05-29 21:46:12,669 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:12,669 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:12,670 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000495
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000495 | step=495 | Vg=+3.7687 V | <Pz>_FE=+2.979701e-01
# yt : [INFO     ] 2026-05-29 21:46:13,006 Parameters: current_time              = 1.306000000000002e-10
# yt : [INFO     ] 2026-05-29 21:46:13,006 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,007 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,007 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:13,110 Parameters: current_time              = 1.430000000000008e-10
# yt : [INFO     ] 2026-05-29 21:46:13,110 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,111 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,111 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000580
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000580 | step=580 | Vg=+4.7726 V | <Pz>_FE=+2.885152e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000653
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000653 | step=653 | Vg=+3.7687 V | <Pz>_FE=+2.979702e-01
# yt : [INFO     ] 2026-05-29 21:46:13,218 Parameters: current_time              = 1.5380000000000132e-10
# yt : [INFO     ] 2026-05-29 21:46:13,219 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,219 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,219 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:13,324 Parameters: current_time              = 1.636000000000018e-10
# yt : [INFO     ] 2026-05-29 21:46:13,325 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,326 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,327 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000715
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000715 | step=715 | Vg=+2.7673 V | <Pz>_FE=+3.062718e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000769
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000769 | step=769 | Vg=+1.7678 V | <Pz>_FE=+3.137213e-01
# yt : [INFO     ] 2026-05-29 21:46:13,432 Parameters: current_time              = 1.7260000000000223e-10
# yt : [INFO     ] 2026-05-29 21:46:13,433 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,434 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,434 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:13,539 Parameters: current_time              = 1.8100000000000263e-10
# yt : [INFO     ] 2026-05-29 21:46:13,540 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,540 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,541 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000818
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000818 | step=818 | Vg=+0.7697 V | <Pz>_FE=+3.205100e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000863
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000863 | step=863 | Vg=-0.2271 V | <Pz>_FE=+3.267677e-01
# yt : [INFO     ] 2026-05-29 21:46:13,648 Parameters: current_time              = 1.88800000000003e-10
# yt : [INFO     ] 2026-05-29 21:46:13,649 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,649 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,650 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:13,762 Parameters: current_time              = 1.9620000000000337e-10
# yt : [INFO     ] 2026-05-29 21:46:13,763 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,763 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,764 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000905
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000905 | step=905 | Vg=-1.2230 V | <Pz>_FE=+3.325870e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000944
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000944 | step=944 | Vg=-2.2181 V | <Pz>_FE=+3.380368e-01
# yt : [INFO     ] 2026-05-29 21:46:13,872 Parameters: current_time              = 2.032000000000037e-10
# yt : [INFO     ] 2026-05-29 21:46:13,873 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,873 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,874 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-05-29 21:46:13,985 Parameters: current_time              = 2.0980000000000402e-10
# yt : [INFO     ] 2026-05-29 21:46:13,987 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-05-29 21:46:13,987 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-05-29 21:46:13,988 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00000981
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00000981 | step=981 | Vg=-3.2125 V | <Pz>_FE=+3.431695e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00001016
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001016 | step=1016 | Vg=-4.2063 V | <Pz>_FE=+3.480265e-01
# Read Pz with shape (64, 64, 59) from /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/plt00001049
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 2.950e-08] m
# plt00001049 | step=1049 | Vg=-5.1996 V | <Pz>_FE=+3.526408e-01
# Saved CSV: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/MFIS_PV_curve.csv

# %%
def sci_tex(x, sig=2):
    """Return LaTeX like 1.23\\times10^{-4} (no 'e')."""
    if x == 0:
        return r"0"
    exp = int(np.floor(np.log10(abs(x))))
    mant = x / (10 ** exp)
    return rf"{mant:.{sig}f}\times 10^{{{exp}}}"

# ==========================
# Plot PV curve
# ==========================

plt.figure(figsize=(6, 5))

textstr = '\n'.join((
    r'In SI units:',
    rf'$\alpha={sci_tex(ALPHA, sig=2)}$',
    rf'$\beta={sci_tex(BETA, sig=2)}$',
    rf'$\gamma={sci_tex(SMALL_GAMMA, sig=2)}$',
    rf'$g_{{11}}={sci_tex(G11, sig=2)}$',
    rf'$g_{{44}}={sci_tex(G44, sig=2)}$',
    rf'$t_{{fe}}={sci_tex((FE_Z_HI_NM-FE_Z_LO_NM)*1e-9, sig=2)}$',
))

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
plt.text(-5, -0.005, textstr, fontsize=12,
        verticalalignment='top', bbox=props)

# time-order full loop
plt.plot(V, P, "-o", markersize=4, linewidth=1.2, label="time order")

# optional: highlight positive / negative sweep
pos = df["sweep_direction"].to_numpy() >= 0
neg = df["sweep_direction"].to_numpy() < 0

if np.any(pos):
    plt.plot(V[pos], P[pos], "o", markersize=5, label="positive sweep")

if np.any(neg):
    plt.plot(V[neg], P[neg], "s", markersize=5, label="negative sweep")

plt.axhline(0, linewidth=0.8)
plt.axvline(0, linewidth=0.8)

plt.xlabel(r"$V_g$ (V)")
plt.ylabel(r"$\langle P_z \rangle_\mathrm{FE}$ (C/m$^2$)")
plt.title("MFIS P-V Curve")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

plt.savefig(OUT_FIG, dpi=200)
print(f"Saved figure: {OUT_FIG}")

plt.show()
# Out:
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_9_plt/MFIS_PV_curve.png
