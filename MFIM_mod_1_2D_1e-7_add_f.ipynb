# %% [markdown]
# # 本次模擬cmd log資訊
#
# * 2026/06/20（23:45）開始模擬
# * 2026/06/21（14:50）結束
# * Total run time  54296.94233 seconds(15hr5min)
# * 只保留最後一個iteration(266695)的迭代資訊和AMReX finalize(如下)

# %% [raw]
# MLMG: Initial rhs               = 226033172.9
# MLMG: Initial residual (resid0) = 7662697015
# MLMG: Final Iter. 8 resid, resid/resid0 = 0.1905325353, 2.486494441e-11
# MLMG: Timers: Solve = 0.193721985 Iter = 0.179951996 Bottom = 0.01071289101
# Steady state check : (phi(t) - phi(t-1)).norm0() = 9.196003472e-08
# Advanced step 266695 in 0.227364161 seconds
#
# step = 266695, Phi_Bc_hi = -4, num_Vapp = 46, sign = -1
# MLMG: Initial rhs               = 226033214.4
# MLMG: Initial residual (resid0) = 6813097013
# MLMG: Final Iter. 8 resid, resid/resid0 = 0.169685984, 2.490585173e-11
# MLMG: Timers: Solve = 0.192849616 Iter = 0.179193281 Bottom = 0.010939175
# voltage_sweep == 1 && num_Vapp == num_Vapp_max!
# High-water FAB megabyte spread across MPI nodes: [7 ... 8]
# Current     FAB megabyte spread across MPI nodes: [5 ... 6]
# Total run time 54296.94233 seconds
#
#
# TinyProfiler total time across processes [min...avg...max]: 5.43e+04 ... 5.43e+04 ... 5.43e+04
#
# ----------------------------------------------------------------------------------------------
# Name                                           NCalls  Excl. Min  Excl. Avg  Excl. Max   Max %
# ----------------------------------------------------------------------------------------------
# FillBoundary_finish()                        22207039  1.018e+04  1.037e+04  1.047e+04  19.29%
# FillBoundary_nowait()                        22207039  1.014e+04  1.026e+04  1.045e+04  19.25%
# MLABecLaplacian::Fsmooth()                   15003344       8339       8481       8615  15.87%
# FabArray::ParallelCopy_finish()               4817800      912.1       3027       3513   6.47%
# FabArray::setVal()                            6579707       2598       2746       3136   5.78%
# MLABecLaplacian::Fapply()                     7212149       2138       2248       2520   4.64%
# amrex::average_down                           2142159       2176       2178       2180   4.02%
# FabArray::Xpay()                              4017577       2059       2107       2169   3.99%
# FabArray::ParallelCopy_nowait()               4817800       1530       1590       2004   3.69%
# MLMG::addInterpCorrection()                   1875418       1901       1909       1917   3.53%
# FabArray::norminf()                           6371290       1541       1670       1909   3.52%
# amrex::Copy()                                 2571133      981.5       1062       1140   2.10%
# amrex::Add()                                  1875418      976.8       1018       1069   1.97%
# ComputePhi_Rho()                               266741      794.4      840.3      877.4   1.62%
# average_down_faces                            1600446      565.4      675.6      834.1   1.54%
# FabArray::LinComb()                           1066826      759.1      788.8      816.8   1.50%
# MLMG::ResNormInf()                            2142159        145        444      812.6   1.50%
# amrex::Dot()                                  6389145          0      84.28      674.3   1.24%
# Calculate_Grad()                               266695      562.9        578      594.9   1.10%
# Calculate_Landau()                             266695      359.2      460.9      554.3   1.02%
# ComputeEfromPhi()                              533390      375.7      429.6      470.9   0.87%
# MLMG::solve()                                  266741      3.082      153.6      468.2   0.86%
# Calculate_Elec()                               266695      208.4      322.7        449   0.83%
# MLCellLinOp::applyBC()                       22215493      80.07        154      225.7   0.42%
# main()                                              1      186.7      206.7      216.7   0.40%
# MLABecLaplacian::normalize()                  3429000          0      23.13      185.1   0.34%
# CalculateTDGL_RHS()                            266695      147.2        160      171.5   0.32%
# MultiFab::max()                                266742      139.3      140.2        141   0.26%
# MLCGSolver::bicgstab                           234427          0      1.867      14.94   0.03%
# FabArray::FillBoundary()                     22207039      2.749      3.216      6.076   0.01%
# MLCGSolver::ParallelAllReduce                 8287597          0     0.6869      5.495   0.01%
# MLCellLinOp::apply()                          7212149     0.4997     0.9286      3.876   0.01%
# MLCellLinOp::smooth()                         3985263      1.459      1.526      1.811   0.00%
# MLMG::prepareForSolve()                        266741     0.5306     0.5726     0.7857   0.00%
# FabArray::ParallelCopy()                      4817800     0.6665     0.6891     0.7719   0.00%
# MLMG::actualBottomSolve()                     1875418    0.08046     0.1723     0.7697   0.00%
# MLMG::mgVcycle_down::0                        1875418     0.4241     0.4425     0.5169   0.00%
# MLMG::mgVcycle()                              1875418     0.3401     0.3573     0.4014   0.00%
# MLMG::oneIter()                               1875418     0.2815     0.3084      0.398   0.00%
# MLCellLinOp::solutionResidual()               2142159     0.3075     0.3226     0.3786   0.00%
# MLMG::mgVcycle_up::0                          1875418     0.2603      0.276     0.3511   0.00%
# MLCellLinOp::correctionResidual()             1875418     0.2694     0.2817     0.3341   0.00%
# MLMG:computeResOfCorrection()                 1875418     0.2122     0.2238       0.27   0.00%
# MLMG::computeResidual()                       1875418     0.2175     0.2248     0.2557   0.00%
# MLMG::mgVcycle_bottom                         1875418     0.1601     0.1698     0.2194   0.00%
# MLABecLaplacian::averageDownCoeffs()           266741    0.08419    0.09429     0.1277   0.00%
# MLMG::computeMLResidual()                      266741    0.03807    0.04274     0.0525   0.00%
# MLMG::MLResNormInf()                           266741    0.02886    0.03072    0.03401   0.00%
# Other                                        32182849        136      161.5      339.4   0.63%
# ----------------------------------------------------------------------------------------------
#
# ----------------------------------------------------------------------------------------------
# Name                                           NCalls  Incl. Min  Incl. Avg  Incl. Max   Max %
# ----------------------------------------------------------------------------------------------
# main()                                              1   5.43e+04   5.43e+04   5.43e+04 100.00%
# ComputePhi_Rho()                               266741  4.863e+04  4.868e+04  4.871e+04  89.72%
# MLMG::solve()                                  266741  4.528e+04  4.529e+04   4.53e+04  83.43%
# MLMG::oneIter()                               1875418  3.586e+04  3.621e+04   3.65e+04  67.22%
# MLMG::mgVcycle()                              1875418  3.479e+04  3.519e+04  3.552e+04  65.42%
# MLCellLinOp::smooth()                         3985263  2.262e+04  2.269e+04  2.276e+04  41.92%
# FabArray::FillBoundary()                     22207039  2.043e+04  2.063e+04   2.09e+04  38.49%
# MLCellLinOp::applyBC()                       22215493   1.86e+04  1.886e+04  1.909e+04  35.16%
# MLMG::mgVcycle_down::0                        1875418  1.803e+04  1.815e+04  1.837e+04  33.83%
# MLMG::mgVcycle_up::0                          1875418  1.512e+04  1.679e+04  1.749e+04  32.21%
# FillBoundary_finish()                        22207039  1.018e+04  1.037e+04  1.047e+04  19.29%
# FillBoundary_nowait()                        22207039  1.014e+04  1.026e+04  1.045e+04  19.25%
# MLABecLaplacian::Fsmooth()                   15003344       8339       8481       8615  15.87%
# MLCellLinOp::apply()                          7212149       6576       6904       7193  13.25%
# MLMG::addInterpCorrection()                   1875418       2728       4445       5103   9.40%
# MLCellLinOp::solutionResidual()               2142159       4566       4862       5095   9.38%
# FabArray::ParallelCopy()                      4817800       2918       4618       5044   9.29%
# MLMG:computeResOfCorrection()                 1875418       4063       4086       4102   7.56%
# MLCellLinOp::correctionResidual()             1875418       4063       4086       4102   7.56%
# MLMG::computeResidual()                       1875418       4031       4031       4031   7.42%
# amrex::average_down                           2142159       3440       3639       3793   6.99%
# FabArray::ParallelCopy_finish()               4817800      912.1       3027       3513   6.47%
# FabArray::setVal()                            6579707       2598       2746       3136   5.78%
# MLMG::prepareForSolve()                        266741       2288       2405       2785   5.13%
# MLABecLaplacian::Fapply()                     7212149       2138       2248       2520   4.64%
# FabArray::Xpay()                              4017577       2059       2107       2169   3.99%
# MLMG::mgVcycle_bottom                         1875418     0.2416      251.5       2010   3.70%
# MLMG::actualBottomSolve()                     1875418    0.08046      251.3       2010   3.70%
# FabArray::ParallelCopy_nowait()               4817800       1531       1591       2005   3.69%
# MLCGSolver::bicgstab                           234427          0      249.9       1999   3.68%
# FabArray::norminf()                           6371290       1541       1670       1909   3.52%
# MLMG::ResNormInf()                            2142159       1256       1547       1887   3.47%
# MLABecLaplacian::averageDownCoeffs()           266741       1725       1753       1863   3.43%
# average_down_faces                            1600446       1287       1297       1311   2.42%
# amrex::Copy()                                 2571133      981.5       1062       1140   2.10%
# amrex::Add()                                  1875418      976.8       1018       1069   1.97%
# MLMG::computeMLResidual()                      266741      535.1      831.5       1065   1.96%
# FabArray::LinComb()                           1066826      759.1      788.8      816.8   1.50%
# amrex::Dot()                                  6389145          0      84.28      674.3   1.24%
# Calculate_Grad()                               266695      562.9        578      594.9   1.10%
# CalculateTDGL_RHS()                            266695      560.9      571.8      581.8   1.07%
# Calculate_Landau()                             266695      359.2      460.9      554.3   1.02%
# ComputeEfromPhi()                              533390      375.7      429.6      470.9   0.87%
# Calculate_Elec()                               266695      208.4      322.7        449   0.83%
# MLCGSolver::ParallelAllReduce                 8287597          0      45.19      361.5   0.67%
# MLABecLaplacian::normalize()                  3429000          0      23.13      185.1   0.34%
# MultiFab::max()                                266742      139.3      140.2        141   0.26%
# MLMG::MLResNormInf()                           266741      105.5      114.7      139.8   0.26%
# Other                                        32182849      191.5      271.6      481.6   0.89%
# ----------------------------------------------------------------------------------------------
#
# Device Memory Usage:
# ------------------------------------------------------------------------------------------------------------------------------
# Name                                            Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ------------------------------------------------------------------------------------------------------------------------------
# The_Arena::Initialize()                              8       0   B       0   B       0   B    1876 MiB    1876 MiB    1876 MiB
# ResizeRandomSeed                                    16      13 MiB      13 MiB      13 MiB      13 MiB      13 MiB      13 MiB
# main()                                             912    4890 KiB    4890 KiB    4890 KiB    5035 KiB    5035 KiB    5035 KiB
# WritePlotfile()                                    752      33   B      33   B      34   B    1296 KiB    1296 KiB    1296 KiB
# MLMG::prepareForSolve()                             83     418 KiB     449 KiB     662 KiB     419 KiB     449 KiB     662 KiB
# MLABecLaplacian::define()                           68     300 KiB     338 KiB     601 KiB     301 KiB     338 KiB     601 KiB
# MLCGSolver::bicgstab                           9377090       0   B    1942   B      15 KiB       0   B      51 KiB     415 KiB
# ComputePhi_Rho()                              25607136    8393   B    8436   B    8488   B     288 KiB     288 KiB     288 KiB
# VisMF::Write(FabArray)                           13536       2   B       2   B       2   B     144 KiB     144 KiB     144 KiB
# BndryData::define()                                192     102 KiB     102 KiB     102 KiB     103 KiB     103 KiB     103 KiB
# MLCellLinOp::defineAuxData()                       204      39 KiB      44 KiB      77 KiB      40 KiB      44 KiB      78 KiB
# amrex::Dot()                                  52988584       0   B     112   B     899   B       0   B    9248   B      72 KiB
# MultiFab::max()                                2133944     355   B     359   B     368   B      72 KiB      72 KiB      72 KiB
# FabArray::norminf()                           50970321    1993   B    2093   B    2448   B      72 KiB      72 KiB      72 KiB
# FillBoundary_nowait()                          8018852      26 KiB      26 KiB      27 KiB      27 KiB      27 KiB      30 KiB
# FillBoundary_finish()                          2134008      18 KiB      18 KiB      18 KiB      18 KiB      18 KiB      18 KiB
# average_down_faces                            19205376    1024   B    1026   B    1029   B      11 KiB      11 KiB      11 KiB
# FabArray::setVal()                             8536008    9482   B    9482   B    9482   B    9984   B    9984   B    9984   B
# amrex::average_down                           51411824     855   B     889   B     917   B    9728   B    9728   B    9728   B
# MLMG::addInterpCorrection()                   45010032     471   B     762   B     874   B    9472   B    9472   B    9472   B
# FabArray::ParallelCopy_finish()               13127931      19   B    1139   B    8959   B     512   B    1568   B    8960   B
# MLCellLinOp::applyBC()                       181733354    3578   B    3707   B    4612   B    3840   B    4000   B    5120   B
# amrex::Copy()                                  2134408    3336   B    3336   B    3336   B    3584   B    3584   B    3584   B
# MLABecLaplacian::Fsmooth()                          96    3071   B    3071   B    3071   B    3072   B    3072   B    3072   B
# FabArray::ParallelCopy_nowait()               25414475      16   B     244   B    1820   B     512   B     768   B    2560   B
# MLCellLinOp::prepareForSolve()                       9       0   B       0   B       0   B    2304   B    2304   B    2304   B
# MLABecLaplacian::normalize()                   1875422       0   B     129   B    1033   B       0   B     160   B    1280   B
# FabArray::setVal(val, thecmd, scomp, ncomp)        100       0   B       0   B       0   B    1024   B    1024   B    1024   B
# MLCellLinOp::defineBC()                              9     255   B     287   B     511   B     256   B     288   B     512   B
# FabArray::LinComb()                            2133936     257   B     257   B     257   B     512   B     512   B     512   B
# MLABecLaplacian::Fapply()                      3750836       0   B       2   B      16   B       0   B      64   B     512   B
# ------------------------------------------------------------------------------------------------------------------------------
#
# Managed Memory Usage:
# ---------------------------------------------------------------------------------------------------------------
# Name                             Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ---------------------------------------------------------------------------------------------------------------
# The_Managed_Arena::Initialize()       8       0   B       0   B       0   B    8192 KiB    8192 KiB    8192 KiB
# main()                                8       0   B       0   B       0   B      10 KiB      10 KiB      10 KiB
# ---------------------------------------------------------------------------------------------------------------
#
# Pinned Memory Usage:
# ------------------------------------------------------------------------------------------------------------------------------
# Name                                            Nalloc  AvgMem min  AvgMem avg  AvgMem max  MaxMem min  MaxMem avg  MaxMem max
# ------------------------------------------------------------------------------------------------------------------------------
# The_Pinned_Arena::Initialize()                       8       0   B       0   B       0   B    8192 KiB    8192 KiB    8192 KiB
# VisMF::Write(FabArray)                           14288       0   B       0   B       0   B     648 KiB     648 KiB     648 KiB
# FabArray::ParallelCopy_nowait()               63956875     834   B    1419   B    5351   B      10 KiB      18 KiB      73 KiB
# FillBoundary_nowait()                        312218324      37 KiB      37 KiB      37 KiB      56 KiB      56 KiB      56 KiB
# FillBoundary_finish()                          2134008      18 KiB      18 KiB      18 KiB      18 KiB      18 KiB      18 KiB
# FabArray::setVal()                             8536008    9482   B    9482   B    9482   B    9984   B    9984   B    9984   B
# FabArray::ParallelCopy_finish()               13127931      19   B    1139   B    8959   B     512   B    1568   B    8960   B
# MLCellLinOp::applyBC()                         4009403    3578   B    3707   B    4610   B    3584   B    3744   B    4864   B
# amrex::Copy()                                  2134408    3336   B    3336   B    3336   B    3584   B    3584   B    3584   B
# MLABecLaplacian::Fsmooth()                          96    3071   B    3071   B    3071   B    3072   B    3072   B    3072   B
# MLCellLinOp::prepareForSolve()                       9       0   B       0   B       0   B    2304   B    2304   B    2304   B
# MLABecLaplacian::normalize()                   1875422       0   B     129   B    1033   B       0   B     160   B    1280   B
# FabArray::setVal(val, thecmd, scomp, ncomp)        100       0   B       0   B       0   B    1024   B    1024   B    1024   B
# average_down_faces                             6401808     774   B     774   B     774   B    1024   B    1024   B    1024   B
# MLABecLaplacian::Fapply()                      3750836       0   B       2   B      16   B       0   B      64   B     512   B
# FabArray::LinComb()                            2133936     257   B     257   B     257   B     512   B     512   B     512   B
# MultiFab::max()                                2133944     256   B     256   B     256   B     512   B     512   B     512   B
# amrex::Dot()                                  52988584       0   B       1   B      12   B       0   B      64   B     512   B
# amrex::average_down                           17137280     272   B     272   B     273   B     512   B     512   B     512   B
# MLCellLinOp::setLevelBC()                          423       0   B       0   B       0   B     256   B     256   B     256   B
# MLMG::addInterpCorrection()                   15003344       8   B       8   B       9   B     256   B     256   B     256   B
# Unprofiled                                          96       0   B       0   B       0   B     256   B     256   B     256   B
# FabArray::norminf()                           50970321       6   B       6   B       8   B     256   B     256   B     256   B
# ------------------------------------------------------------------------------------------------------------------------------
#
# Total GPU global memory (MB) spread across MPI: [20019 ... 20019]
# Free  GPU global memory (MB) spread across MPI: [3484 ... 3484]
# [The         Arena] max space (MB) allocated spread across MPI: [1876 ... 1876]
# [The         Arena] max space (MB) used      spread across MPI: [20 ... 21]
# [The Managed Arena] max space (MB) allocated spread across MPI: [8 ... 8]
# [The Managed Arena] max space (MB) used      spread across MPI: [0 ... 0]
# [The  Pinned Arena] max space (MB) allocated spread across MPI: [8 ... 8]
# [The  Pinned Arena] max space (MB) used      spread across MPI: [0 ... 0]
# AMReX (26.05-39-gbe2cc437644f) finalized
# EXIT_CODE=0
# Sun Jun 21 14:50:01 CST 2026

# %% [markdown]
# # 使用者設定

# %%
import re
from pathlib import Path

import yt
import numpy as np
import pandas as pd


# =========================
# User settings
# =========================#"/home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1/"
PLOT_DIR = Path("/home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f")          # plotfile 所在資料夾
PLOT_PREFIX = "plt"
PLOT_INTERVAL = 10000000           # 你的 plot_int，例如 100

# 如果你的 field 名稱不是 ("boxlib", "Phi")，後面會自動列出 field_list 方便你改
PHI_FIELD_CANDIDATES = [
    ("boxlib", "Phi"),
    ("boxlib", "phi"),
    ("boxlib", "PoissonPhi"),
    "Phi",
    "phi",
    "PoissonPhi",
]

# FE layer range, unit: nm
FE_Z_LO_NM = 4.0
FE_Z_HI_NM = 9.0

# 如果你想只畫 FE 的 x 範圍，也可以打開這兩行
# 若是 MFIS 全幅 FE，通常用整個 x 範圍即可

FE_X_LO_NM = -16.0
FE_X_HI_NM = 16.0

FE_Y_LO_NM = -16.0
FE_Y_HI_NM = 16.0

ALPHA = -2.5e9
BETA = 6.0e10
SMALL_GAMMA = 1.5e11
G11 = 1.0e-9
G44 = 1.0e-9


# 3D sweep plot要畫的電壓欄位：-4.5, -4.0, ..., 4.5
VOLTAGES = np.arange(-4.5, 5.0, 0.5)
# 3D contour 要畫的plotfile
PLOTFILE_NAME = "plt00203535"

# %% [markdown]
# ## Utils

# %%
def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v

def read_full_field_from_grids(ds, field):
    """
    Read a cell-centered AMReX field from all yt grids
    and stitch them into one full-domain numpy array.

    Return:
        full: numpy array with shape ds.domain_dimensions
    """
    dims = np.array(ds.domain_dimensions, dtype=int)
    full = np.empty(tuple(dims), dtype=float)

    domain_lo = ds.domain_left_edge.to_value()
    domain_hi = ds.domain_right_edge.to_value()
    dx = (domain_hi - domain_lo) / dims

    for grid in ds.index.grids:
        arr = to_numpy(grid[field])

        left = grid.LeftEdge.to_value()

        # grid start index in global domain
        start = np.rint((left - domain_lo) / dx).astype(int)

        nx, ny, nz = arr.shape
        i0, j0, k0 = start
        i1, j1, k1 = i0 + nx, j0 + ny, k0 + nz

        full[i0:i1, j0:j1, k0:k1] = arr

    return full

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names

# %% [markdown]
# # plot

# %% [markdown]
# ## 看有哪些 plotfile

# %%
from pathlib import Path
import yt


plot_paths = sorted([p for p in PLOT_DIR.glob(f"{PLOT_PREFIX}*") if p.is_dir()])

# 只要名稱 (plt000100, ...)
plot_names = [p.name for p in plot_paths]

print("Available plotfiles:")
for name in plot_names:
    print("  ", name)
    
print(len(plot_names), "plotfiles found in", PLOT_DIR)
# Out:
# Available plotfiles:
#    plt00000000
#    plt00127183
#    plt00127394
#    plt00127603
#    plt00127820
#    plt00128080
#    plt00128602
#    plt00128984
#    plt00129052
#    plt00129112
#    plt00129166
#    plt00129225
#    plt00129292
#    plt00129368
#    plt00129457
#    plt00129564
#    plt00129697
#    plt00129870
#    plt00130104
#    plt00201021
#    plt00201232
#    plt00201441
#    plt00201658
#    plt00201918
#    plt00202440
#    plt00202822
#    plt00202890
#    plt00202950
#    plt00203004
#    plt00203063
#    plt00203130
#    plt00203206
#    plt00203295
#    plt00203402
#    plt00203535
#    plt00203708
#    plt00203942
#    plt00264712
#    plt00264923
#    plt00265132
#    plt00265349
#    plt00265609
#    plt00266131
#    plt00266513
#    plt00266581
#    plt00266641
#    plt00266695
# 47 plotfiles found in /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f

# %% [markdown]
# ## 探索yt資料結構

# %% [markdown]
# ### dir(ds) # 列出 ds 所有(variable和property和method)

# %% [markdown]
# * Note: variable和property和method統稱attribute

# %%
ds = yt.load(PLOT_DIR/plot_names[0])  # 載入指定的 plotfile
dir(ds) # 列出 ds 所有變數和屬性和方法
#[a for a in dir(ds) if not a.startswith("_")]
# Out:
# yt : [INFO     ] 2026-06-25 19:25:38,273 Parameters: current_time              = 0.0
# yt : [INFO     ] 2026-06-25 19:25:38,273 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:25:38,273 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:25:38,274 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# ['__abstractmethods__',
#  '__annotate_func__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_object_class',
#  '_arr',
#  '_assign_unit_system',
#  '_create_unit_registry',
#  '_default_cparam_filename',
#  '_determined_fields',
#  '_field_info',
#  '_field_info_class',
#  '_field_list',
#  '_find_extremum',
#  '_force_periodicity',
#  '_get_field_info',
#  '_get_field_info_helper',
#  '_guess_candidates',
#  '_hash',
#  '_header_mesh_start',
#  '_index_class',
#  '_input_filename',
#  '_instantiated',
#  '_instantiated_index',
#  '_ionization_label_format',
#  '_is_valid',
#  '_is_within_domain',
#  '_load_requirements',
#  '_localize_check',
#  '_lookup_cparam_filepath',
#  '_max_level',
#  '_min_level',
#  '_missing_load_requirements',
#  '_mrep',
#  '_output_prefix',
#  '_override_code_units',
#  '_parse_cparams',
#  '_parse_fparams',
#  '_parse_header_file',
#  '_parse_parameter_file',
#  '_particle_type_counts',
#  '_periodicity',
#  '_proj_type',
#  '_quan',
#  '_sanitize_units_override',
#  '_set_code_unit_attributes',
#  '_set_derived_attrs',
#  '_setup_classes',
#  '_setup_coordinate_handler',
#  '_setup_filtered_type',
#  '_setup_particle_type',
#  '_setup_particle_types',
#  '_skip_cache',
#  '_unit_system_id',
#  '_unit_system_name',
#  '_units',
#  '_uses_code_length_unit',
#  '_uses_code_time_unit',
#  '_validate_units_override_keys',
#  'add_deposited_particle_field',
#  'add_field',
#  'add_gradient_fields',
#  'add_mesh_sampling_particle_field',
#  'add_particle_filter',
#  'add_particle_union',
#  'all_data',
#  'arbitrary_grid',
#  'arr',
#  'backup_filename',
#  'basename',
#  'bool',
#  'box',
#  'checksum',
#  'close',
#  'conversion_factors',
#  'coordinates',
#  'covering_grid',
#  'cparam_filename',
#  'create_field_info',
#  'current_time',
#  'cut_region',
#  'cutting',
#  'data_collection',
#  'dataset_type',
#  'default_field',
#  'default_fluid_type',
#  'default_species_fields',
#  'default_units',
#  'define_unit',
#  'derived_field_list',
#  'dimensionality',
#  'directory',
#  'disk',
#  'domain_center',
#  'domain_dimensions',
#  'domain_left_edge',
#  'domain_offset',
#  'domain_right_edge',
#  'domain_width',
#  'ellipsoid',
#  'field_info',
#  'field_list',
#  'field_units',
#  'fields',
#  'fields_detected',
#  'filename',
#  'find_field_values_at_point',
#  'find_field_values_at_points',
#  'find_max',
#  'find_min',
#  'fluid_types',
#  'force_periodicity',
#  'fparam_filename',
#  'fullpath',
#  'geometry',
#  'get_smallest_appropriate_unit',
#  'get_unit_from_registry',
#  'has_key',
#  'index',
#  'intersection',
#  'ires_factor',
#  'known_filters',
#  'length_unit',
#  'level_offsets',
#  'mass_unit',
#  'max_level',
#  'min_level',
#  'minimal_sphere',
#  'no_cgs_equiv_length',
#  'object_types',
#  'objects',
#  'octree',
#  'orion_version',
#  'ortho_ray',
#  'output_dir',
#  'parameter_filename',
#  'parameters',
#  'particle_fields_by_type',
#  'particle_type_counts',
#  'particle_types',
#  'particle_types_raw',
#  'particle_unions',
#  'particles_exist',
#  'periodicity',
#  'plots',
#  'point',
#  'print_key_parameters',
#  'print_stats',
#  'proj',
#  'quan',
#  'r',
#  'ray',
#  'ref_factors',
#  'refine_by',
#  'region',
#  'region_expression',
#  'relative_refinement',
#  'set_code_units',
#  'set_field_label_format',
#  'set_units',
#  'setup_cosmology',
#  'setup_deprecated_fields',
#  'slice',
#  'smoothed_covering_grid',
#  'sphere',
#  'storage_filename',
#  'streamline',
#  'surface',
#  'time_unit',
#  'union',
#  'unique_identifier',
#  'unit_registry',
#  'unit_system',
#  'units',
#  'units_override',
#  'velocity_unit']

# %% [markdown]
# ### 用key word查看dir(ds)中可能會用到的attribute

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "domain"
    if "domain" in a.lower():
        print(a)
# Out:
# _is_within_domain
# domain_center
# domain_dimensions
# domain_left_edge
# domain_offset
# domain_right_edge
# domain_width

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "field"
    if "field" in a.lower():
        print(a)
# Out:
# _determined_fields
# _field_info
# _field_info_class
# _field_list
# _get_field_info
# _get_field_info_helper
# add_deposited_particle_field
# add_field
# add_gradient_fields
# add_mesh_sampling_particle_field
# create_field_info
# default_field
# default_species_fields
# derived_field_list
# field_info
# field_list
# field_units
# fields
# fields_detected
# find_field_values_at_point
# find_field_values_at_points
# particle_fields_by_type
# set_field_label_format
# setup_deprecated_fields

# %%
for a in dir(ds): # 列出 ds 裡有哪些屬性和方法，特別是包含 "index"
    if "index" in a.lower():
        print(a)
# Out:
# _index_class
# _instantiated_index
# index

# %% [markdown]
# * **grid相關attribute在index內**

# %%
for a in dir(ds.index): # 列出 ds.index 裡有哪些屬性和方法，特別是包含 "index"
    if "grid" in a.lower():
        print(a)
# Out:
# _count_grids
# _get_grid_objs
# _get_grid_tree
# _get_grids
# _grid_chunksize
# _grids
# _initialize_grid_arrays
# _populate_grid_objects
# grid
# grid_corners
# grid_dimensions
# grid_left_edge
# grid_levels
# grid_particle_count
# grid_right_edge
# grid_start_index
# grids
# lock_grids_to_parents
# num_grids
# select_grids

# %%
for a in dir(ds.index.grids[0]): # 列出 ds.index.grids[0] 裡有哪些屬性和方法，特別是包含 "index"
    
        print(a)
# Out:
# ActiveDimensions
# Children
# LeftEdge
# Level
# NumberOfParticles
# OverlappingSiblings
# Parent
# RightEdge
# __abstractmethods__
# __add__
# __and__
# __annotate_func__
# __class__
# __delattr__
# __delitem__
# __dict__
# __dir__
# __doc__
# __eq__
# __firstlineno__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __getstate__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __int__
# __invert__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __or__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __setitem__
# __sizeof__
# __slots__
# __static_attributes__
# __str__
# __sub__
# __subclasshook__
# __weakref__
# __xor__
# _abc_impl
# _activate_cache
# _base_offset
# _cache_mask
# _child_index_mask
# _child_indices
# _child_mask
# _children_ids
# _chunk_info
# _chunked_read
# _compute_extrema
# _con_args
# _container_fields
# _count_particles
# _current_chunk
# _current_fluid_type
# _current_particle_type
# _data_source
# _debug
# _default_field_parameters
# _derived_quantity_chunking
# _determine_fields
# _distributed
# _ds_hold
# _extrema_cache
# _field_cache
# _field_lock
# _field_parameter_state
# _field_type_state
# _fill_child_mask
# _finalize_parallel
# _first_matching_field
# _generate_container_field
# _generate_field
# _generate_fields
# _generate_fluid_field
# _generate_particle_field
# _generate_spatial_fluid
# _get_grid_objs
# _get_grids
# _get_objs
# _get_offset
# _get_selector_mask
# _grids
# _hash
# _id_offset
# _identify_dependencies
# _index
# _initialize_cache
# _initialize_parallel
# _ipython_key_completions_
# _is_default_field_parameter
# _last_count
# _last_mask
# _last_selector_id
# _locked
# _max_level
# _min_level
# _num_ghost_zones
# _offset
# _parameter_iterate
# _parent_id
# _pdata
# _prepare_grid
# _reshape_vals
# _selector
# _set_center
# _set_default_field_parameters
# _setup_dx
# _skip_add
# _sort_by
# _spatial
# _tds_attrs
# _tds_fields
# _tree
# _type_name
# apply_units
# argmax
# argmin
# blocks
# child_index_mask
# child_indices
# child_mask
# chunks
# clear_data
# clone
# comm
# convert
# count
# count_particles
# create_firefly_object
# dds
# deposit
# ds
# fcoords
# fcoords_vertex
# field_data
# field_parameters
# filename
# fwidth
# get_data
# get_dependencies
# get_field_parameter
# get_global_startindex
# get_position
# get_vertex_centered_data
# has_field_parameter
# has_key
# icoords
# id
# index
# integrate
# ires
# keys
# max
# max_level
# mean
# min
# min_level
# particle_operation
# partition_index_2d
# partition_index_3d
# partition_index_3d_bisection_list
# partition_region_3d
# pf
# profile
# ptp
# quantities
# retrieve_ghost_zones
# save_as_dataset
# select
# select_blocks
# select_fcoords
# select_fwidth
# select_icoords
# select_ires
# select_particles
# select_tcoords
# selector
# set_field_parameter
# shape
# smooth
# start_index
# std
# sum
# tiles
# to_astropy_table
# to_dataframe
# to_glue
# write_out

# %% [markdown]
# ## yt dataset

# %% [markdown]
# * 可以從上一個部份"探索yt資料結構"找想用的attribute

# %%
print("========== Dataset ==========")
print("type:", type(ds))
print("用SI單位")
print("current_time(s):", ds.current_time)
print("domain_left_edge(m) :", ds.domain_left_edge)
print("domain_right_edge(m):", ds.domain_right_edge)
print("domain_center:", ds.domain_center)
print("domain_width(domain邊長):", ds.domain_width)
print("domain_offset:", ds.domain_offset)
print("domain_dimensions(xyz方向各切成幾格):", ds.domain_dimensions)
print("dimensionality:", ds.dimensionality)
print("geometry:", ds.geometry)
#print("periodicity:", ds.periodicity)

print("\n========== Fields ==========")
for f in ds.field_list:
    print(" ", f)
# Out:
# ========== Dataset ==========
# type: <class 'yt.frontends.amrex.data_structures.BoxlibDataset'>
# 用SI單位
# current_time(s): 0.0 code_time
# domain_left_edge(m) : [-1.6e-08 -1.6e-08  0.0e+00] code_length
# domain_right_edge(m): [1.6e-08 1.6e-08 9.0e-09] code_length
# domain_center: [0.0e+00 0.0e+00 4.5e-09] code_length
# domain_width(domain邊長): [3.2e-08 3.2e-08 9.0e-09] code_length
# domain_offset: [0 0 0]
# domain_dimensions(xyz方向各切成幾格): [64 64 18]
# dimensionality: 3
# geometry: cartesian
#
# ========== Fields ==========
#   ('boxlib', 'Ex')
#   ('boxlib', 'Ey')
#   ('boxlib', 'Ez')
#   ('boxlib', 'Phi')
#   ('boxlib', 'PhiDiff')
#   ('boxlib', 'PoissonRHS')
#   ('boxlib', 'Px')
#   ('boxlib', 'Py')
#   ('boxlib', 'Pz')
#   ('boxlib', 'alpha')
#   ('boxlib', 'beta')
#   ('boxlib', 'charge')
#   ('boxlib', 'electrons')
#   ('boxlib', 'epsilon')
#   ('boxlib', 'holes')
#   ('boxlib', 'mask')
#   ('boxlib', 'theta')
#   ('boxlib', 'tphase')

# %% [markdown]
# * domain切成多個grid分配給mpi rank平行運算，**資料分散在每個grid**

# %%
print("\n========== Grids ==========")
print("number of grids:", len(ds.index.grids))
for i, g in enumerate(ds.index.grids):
    print(f"grid {i}:")
    print("  LeftEdge:", g.LeftEdge)
    print("  RightEdge:", g.RightEdge)
    print("  ActiveDimensions:", g.ActiveDimensions)
    print("  Level:", g.Level)
print(ds.index.grid_start_index)
# Out:
# ========== Grids ==========
# number of grids: 16
# grid 0:
#   LeftEdge: [-1.6e-08 -1.6e-08  0.0e+00] code_length
#   RightEdge: [-8.e-09 -8.e-09  9.e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 1:
#   LeftEdge: [-8.0e-09 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 0.e+00 -8.e-09  9.e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 2:
#   LeftEdge: [ 0.0e+00 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 8.e-09 -8.e-09  9.e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 3:
#   LeftEdge: [ 8.0e-09 -1.6e-08  0.0e+00] code_length
#   RightEdge: [ 1.6e-08 -8.0e-09  9.0e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 4:
#   LeftEdge: [-1.6e-08 -8.0e-09  0.0e+00] code_length
#   RightEdge: [-8.e-09  0.e+00  9.e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 5:
#   LeftEdge: [-8.e-09 -8.e-09  0.e+00] code_length
#   RightEdge: [0.e+00 0.e+00 9.e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 6:
#   LeftEdge: [ 0.e+00 -8.e-09  0.e+00] code_length
#   RightEdge: [8.e-09 0.e+00 9.e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 7:
#   LeftEdge: [ 8.e-09 -8.e-09  0.e+00] code_length
#   RightEdge: [1.6e-08 0.0e+00 9.0e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 8:
#   LeftEdge: [-1.6e-08  0.0e+00  0.0e+00] code_length
#   RightEdge: [-8.e-09  8.e-09  9.e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 9:
#   LeftEdge: [-8.e-09  0.e+00  0.e+00] code_length
#   RightEdge: [0.e+00 8.e-09 9.e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 10:
#   LeftEdge: [0. 0. 0.] code_length
#   RightEdge: [8.e-09 8.e-09 9.e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 11:
#   LeftEdge: [8.e-09 0.e+00 0.e+00] code_length
#   RightEdge: [1.6e-08 8.0e-09 9.0e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 12:
#   LeftEdge: [-1.6e-08  8.0e-09  0.0e+00] code_length
#   RightEdge: [-8.0e-09  1.6e-08  9.0e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 13:
#   LeftEdge: [-8.e-09  8.e-09  0.e+00] code_length
#   RightEdge: [0.0e+00 1.6e-08 9.0e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 14:
#   LeftEdge: [0.e+00 8.e-09 0.e+00] code_length
#   RightEdge: [8.0e-09 1.6e-08 9.0e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# grid 15:
#   LeftEdge: [8.e-09 8.e-09 0.e+00] code_length
#   RightEdge: [1.6e-08 1.6e-08 9.0e-09] code_length
#   ActiveDimensions: [16 16 18]
#   Level: 0
# [[ 0  0  0]
#  [16  0  0]
#  [32  0  0]
#  [48  0  0]
#  [ 0 16  0]
#  [16 16  0]
#  [32 16  0]
#  [48 16  0]
#  [ 0 32  0]
#  [16 32  0]
#  [32 32  0]
#  [48 32  0]
#  [ 0 48  0]
#  [16 48  0]
#  [32 48  0]
#  [48 48  0]]

# %% [markdown]
# ## **2Dfield繪製**

# %% [markdown]
# * g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
# * x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置

# %%
import yt
import numpy as np
import matplotlib.pyplot as plt
for i in range(len(plot_names)):
    plotfile = PLOT_DIR/plot_names[i] 
    field = ("boxlib", "Phi")

    ds = yt.load(plotfile)

    #g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
    Phi_array = read_full_field_from_grids(ds, field) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid

    print("Phi_array shape =", Phi_array.shape)

    Nx, Ny, Nz = Phi_array.shape #用index存資料

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dims = np.array([Nx, Ny, Nz])

    dx = (hi - lo) / dims

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    y0 = Ny // 2
    slice2d = Phi_array[:, y0, :]

    plt.figure(figsize=(6, 5))
    im = plt.pcolormesh(
        x_nm,
        z_nm,
        slice2d.T,
        shading="auto",
        cmap="RdBu"
    )

    plt.colorbar(im, label="Ex")
    plt.xlabel("x (nm)")
    plt.ylabel("z (nm)")
    plt.title(f"Phi x-z slice at y index = {y0}")
    plt.tight_layout()
    plt.show()
# Out:
# yt : [INFO     ] 2026-06-21 15:23:44,533 Parameters: current_time              = 0.0
# yt : [INFO     ] 2026-06-21 15:23:44,533 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:44,534 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:44,534 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:44,643 Parameters: current_time              = 5.0873200000040385e-08
# yt : [INFO     ] 2026-06-21 15:23:44,644 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:44,644 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:44,644 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:44,814 Parameters: current_time              = 5.095760000004076e-08
# yt : [INFO     ] 2026-06-21 15:23:44,815 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:44,815 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:44,815 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:44,907 Parameters: current_time              = 5.104120000004113e-08
# yt : [INFO     ] 2026-06-21 15:23:44,907 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:44,907 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:44,907 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,002 Parameters: current_time              = 5.112800000004152e-08
# yt : [INFO     ] 2026-06-21 15:23:45,002 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,003 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,003 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,100 Parameters: current_time              = 5.123200000004198e-08
# yt : [INFO     ] 2026-06-21 15:23:45,100 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,100 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,100 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,193 Parameters: current_time              = 5.144080000004291e-08
# yt : [INFO     ] 2026-06-21 15:23:45,193 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,193 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,194 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,288 Parameters: current_time              = 5.1593600000043586e-08
# yt : [INFO     ] 2026-06-21 15:23:45,288 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,288 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,288 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,385 Parameters: current_time              = 5.162080000004371e-08
# yt : [INFO     ] 2026-06-21 15:23:45,385 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,385 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,385 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,482 Parameters: current_time              = 5.1644800000043813e-08
# yt : [INFO     ] 2026-06-21 15:23:45,482 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,482 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,482 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,580 Parameters: current_time              = 5.166640000004391e-08
# yt : [INFO     ] 2026-06-21 15:23:45,580 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,580 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,581 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,674 Parameters: current_time              = 5.1690000000044014e-08
# yt : [INFO     ] 2026-06-21 15:23:45,674 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,675 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,675 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,772 Parameters: current_time              = 5.1716800000044133e-08
# yt : [INFO     ] 2026-06-21 15:23:45,772 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,772 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,773 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:45,869 Parameters: current_time              = 5.174720000004427e-08
# yt : [INFO     ] 2026-06-21 15:23:45,870 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:45,870 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:45,870 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,097 Parameters: current_time              = 5.1782800000044427e-08
# yt : [INFO     ] 2026-06-21 15:23:46,098 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,098 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,098 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,192 Parameters: current_time              = 5.1825600000044617e-08
# yt : [INFO     ] 2026-06-21 15:23:46,192 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,192 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,193 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,286 Parameters: current_time              = 5.187880000004485e-08
# yt : [INFO     ] 2026-06-21 15:23:46,286 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,286 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,286 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,382 Parameters: current_time              = 5.194800000004516e-08
# yt : [INFO     ] 2026-06-21 15:23:46,382 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,382 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,382 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,477 Parameters: current_time              = 5.2041600000045576e-08
# yt : [INFO     ] 2026-06-21 15:23:46,478 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,478 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,478 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,573 Parameters: current_time              = 8.040839999982743e-08
# yt : [INFO     ] 2026-06-21 15:23:46,574 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,574 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,574 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,671 Parameters: current_time              = 8.04927999998264e-08
# yt : [INFO     ] 2026-06-21 15:23:46,671 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,671 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,671 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,763 Parameters: current_time              = 8.05763999998254e-08
# yt : [INFO     ] 2026-06-21 15:23:46,764 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,764 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,764 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,859 Parameters: current_time              = 8.066319999982434e-08
# yt : [INFO     ] 2026-06-21 15:23:46,859 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,860 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,860 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:46,955 Parameters: current_time              = 8.076719999982308e-08
# yt : [INFO     ] 2026-06-21 15:23:46,955 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:46,956 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:46,956 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:47,049 Parameters: current_time              = 8.097599999982056e-08
# yt : [INFO     ] 2026-06-21 15:23:47,050 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:47,050 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:47,050 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:47,144 Parameters: current_time              = 8.112879999981871e-08
# yt : [INFO     ] 2026-06-21 15:23:47,144 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:47,144 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:47,144 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:47,370 Parameters: current_time              = 8.115599999981838e-08
# yt : [INFO     ] 2026-06-21 15:23:47,370 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:47,370 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:47,371 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:47,466 Parameters: current_time              = 8.117999999981809e-08
# yt : [INFO     ] 2026-06-21 15:23:47,466 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:47,467 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:47,467 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:47,563 Parameters: current_time              = 8.120159999981783e-08
# yt : [INFO     ] 2026-06-21 15:23:47,563 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:47,563 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:47,563 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:47,656 Parameters: current_time              = 8.122519999981754e-08
# yt : [INFO     ] 2026-06-21 15:23:47,656 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:47,656 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:47,656 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:47,753 Parameters: current_time              = 8.125199999981722e-08
# yt : [INFO     ] 2026-06-21 15:23:47,753 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:47,753 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:47,753 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:47,849 Parameters: current_time              = 8.128239999981685e-08
# yt : [INFO     ] 2026-06-21 15:23:47,849 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:47,849 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:47,849 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:47,944 Parameters: current_time              = 8.131799999981642e-08
# yt : [INFO     ] 2026-06-21 15:23:47,944 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:47,944 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:47,945 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:48,038 Parameters: current_time              = 8.13607999998159e-08
# yt : [INFO     ] 2026-06-21 15:23:48,039 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:48,039 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:48,039 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:48,132 Parameters: current_time              = 8.141399999981526e-08
# yt : [INFO     ] 2026-06-21 15:23:48,132 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:48,132 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:48,133 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:48,229 Parameters: current_time              = 8.148319999981442e-08
# yt : [INFO     ] 2026-06-21 15:23:48,229 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:48,229 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:48,229 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:48,325 Parameters: current_time              = 8.157679999981329e-08
# yt : [INFO     ] 2026-06-21 15:23:48,325 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:48,325 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:48,325 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:48,420 Parameters: current_time              = 1.0588479999951914e-07
# yt : [INFO     ] 2026-06-21 15:23:48,420 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:48,421 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:48,421 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:48,517 Parameters: current_time              = 1.0596919999951812e-07
# yt : [INFO     ] 2026-06-21 15:23:48,517 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:48,517 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:48,517 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:48,742 Parameters: current_time              = 1.060527999995171e-07
# yt : [INFO     ] 2026-06-21 15:23:48,743 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:48,743 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:48,743 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:48,838 Parameters: current_time              = 1.0613959999951605e-07
# yt : [INFO     ] 2026-06-21 15:23:48,838 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:48,838 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:48,839 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:48,935 Parameters: current_time              = 1.062435999995148e-07
# yt : [INFO     ] 2026-06-21 15:23:48,936 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:48,936 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:48,936 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:49,030 Parameters: current_time              = 1.0645239999951227e-07
# yt : [INFO     ] 2026-06-21 15:23:49,030 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:49,030 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:49,030 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:49,125 Parameters: current_time              = 1.0660519999951042e-07
# yt : [INFO     ] 2026-06-21 15:23:49,125 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:49,125 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:49,125 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:49,220 Parameters: current_time              = 1.0663239999951009e-07
# yt : [INFO     ] 2026-06-21 15:23:49,220 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:49,221 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:49,221 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:49,317 Parameters: current_time              = 1.066563999995098e-07
# yt : [INFO     ] 2026-06-21 15:23:49,317 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:49,317 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:49,318 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)
# yt : [INFO     ] 2026-06-21 15:23:49,415 Parameters: current_time              = 1.0667799999950954e-07
# yt : [INFO     ] 2026-06-21 15:23:49,415 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:49,415 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:49,415 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Phi_array shape = (64, 64, 18)

# %%
import yt
import numpy as np
import matplotlib.pyplot as plt

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_plt")  # 改成你 plotfile 所在的資料夾
plotfile = PLOT_DIR/plot_names[2] 
field = ("boxlib", "Ex")

ds = yt.load(plotfile)

#g = ds.index.grids[0] # 先看 grid 0，多個 grid 的話要自己想辦法合併資料
E_array = read_full_field_from_grids(ds, field) # 讀取整個 domain 的 Ex 資料，會自動合併多個 grid

print("E_array shape =", E_array.shape)

Nx, Ny, Nz = E_array.shape #用index存資料

lo = ds.domain_left_edge.to_value()
hi = ds.domain_right_edge.to_value()
dims = np.array([Nx, Ny, Nz])

dx = (hi - lo) / dims

x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9 #index對應空間位置
z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

y0 = Ny // 2
slice2d = E_array[:, y0, :]

plt.figure(figsize=(6, 5))
im = plt.pcolormesh(
    x_nm,
    z_nm,
    slice2d.T,
    shading="auto",
    cmap="RdBu"
)

plt.colorbar(im, label="Ex")
plt.xlabel("x (nm)")
plt.ylabel("z (nm)")
plt.title(f"Ex x-z slice at y index = {y0}")
plt.tight_layout()
plt.show()
# Out:
# yt : [INFO     ] 2026-06-21 15:23:49,513 Parameters: current_time              = 5.095760000004076e-08
# yt : [INFO     ] 2026-06-21 15:23:49,513 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 15:23:49,513 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 15:23:49,513 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# E_array shape = (64, 64, 18)

# %% [markdown]
# ## 2D Pz slice plot(all voltage in same graph)

# %%
from pathlib import Path
import re

import yt
import numpy as np
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec")          # plotfile 所在資料夾
P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")

# ==========================
# Selection list (NEW)
# ==========================
# format: (voltage, direction)
# voltage 用 None 表示 wildcard
# direction 用 None 表示 wildcard

SELECT_LIST = [
    
    (-0.5, "positive sweep"), 
    (-0.5, "negative sweep"),
   
]

#SELECT_LIST = None  # 不過濾，全部畫出來
USE_FE_X_RANGE = False

# y slice: None 表示取 y 方向正中間
Y_INDEX = None

# 若 plot_names 已經是你前面整理好的 steady-state plot list，就直接用
# plot_names = [...]
# 若沒有，就自動抓目前資料夾內所有 plt########
AUTO_FIND_PLOTS = False

# 跳過 initial plt00000000
SKIP_INITIAL = True

# 色階是否對稱於 0，畫 Pz 通常建議 True
SYMMETRIC_COLOR_SCALE = False

# 輸出圖片名稱
SAVE_FIG = False
OUT_FIG = PLOT_DIR/"Pz_FE_layer_stack.png"


# ==========================
# Helper functions
# ==========================


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


def read_one_plot(plotfile, y_index=None):
    ds = yt.load(str(plotfile))
    #g = ds.index.grids[0]

    P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid
    P*=-1
    if PHI_FIELD in ds.field_list:
        Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
    else:
        Phi = None

    Nx, Ny, Nz = P.shape

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    if y_index is None:
        y_index = Ny // 2

    # FE z range mask
    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    # P slice: shape after selection = (Nx_sel, Nz_sel)
    P_slice = P[np.ix_(x_sel, [y_index], z_sel)][:, 0, :]

    x_plot = x_nm[x_sel]
    z_plot = z_nm[z_sel]

    # 用最上層 cell 的 Phi 平均值當 top potential
    # 注意：這是 top cell center，不是真正 ghost boundary
    if Phi is not None:
        top_phi = Phi[:, :, -1]
        Vtop_mean = float(np.mean(top_phi))
        Vtop_min = float(np.min(top_phi))
        Vtop_max = float(np.max(top_phi))
    else:
        Vtop_mean = np.nan
        Vtop_min = np.nan
        Vtop_max = np.nan

    info = {
        "ds": ds,
        "P_slice": P_slice,
        "x_nm": x_plot,
        "z_nm": z_plot,
        "y_index": y_index,
        "y_nm": float(y_nm[y_index]),
        "Vtop_mean": Vtop_mean,
        "Vtop_min": Vtop_min,
        "Vtop_max": Vtop_max,
        "shape": P.shape,
    }

    return info



def match(rec, direction):# FILTER BY SELECT_LIST
    if not SELECT_LIST:
        return True
    V = rec["Vtop_mean"]

    for v_target, d_target in SELECT_LIST:

        ok_v = (v_target is None) or (
            np.isfinite(V) and np.isclose(V, v_target, atol=1e-1)
        )

        ok_d = (d_target is None) or (direction == d_target)

        if ok_v and ok_d:
            return True

    return False

# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

# sort by step if names are plt########
plot_names_use = sorted(plot_names_use, key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

#忽略第一段
plot_names_use = plot_names_use[9:]
    
print("Plotfiles to draw:")
for n in plot_names_use:
    print(" ", n)
print(len(plot_names_use), "number of plotfiles will be drawn after filtering.")

records = []
all_values = []

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    info = read_one_plot(plotfile, y_index=Y_INDEX)

    step = get_step_from_name(name)

    records.append({
        "name": name,
        "step": step,
        **info,
    })

    all_values.append(info["P_slice"])

# shared color scale
all_concat = np.concatenate([v.ravel() for v in all_values])
if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(all_concat))
    vmin = -vmax
else:
    vmin = np.nanmin(all_concat)
    vmax = np.nanmax(all_concat)

# determine sweep direction from Vtop sequence
Vseq = np.array([r["Vtop_mean"] for r in records], dtype=float)

directions = []
for idx, V in enumerate(Vseq):
    if idx == 0 or not np.isfinite(Vseq[idx-1]) or not np.isfinite(V):
        directions.append("start")
    else:
        dV = V - Vseq[idx-1]
        if dV > 1e-8:
            directions.append("positive sweep")
        elif dV < -1e-8:
            directions.append("negative sweep")
        else:
            directions.append("same V")

filtered_records = []
filtered_directions = []

for rec, d in zip(records, directions):
    if match(rec, d):
        filtered_records.append(rec)
        filtered_directions.append(d)

records = filtered_records
directions = filtered_directions

# figure size
n = len(records)
print(f"Drawing {n} plots after filtering.")
fig_height = max(2.0 * n, 4.0)
fig, axes = plt.subplots(
    nrows=n,
    ncols=1,
    figsize=(7.5, fig_height),
    sharex=True,
    constrained_layout=True
)


if n == 1:
    axes = [axes]

last_im = None

for ax, rec, sweep_dir in zip(axes, records, directions):
    P_slice = rec["P_slice"]
    x_nm = rec["x_nm"]
    z_nm = rec["z_nm"]

    last_im = ax.pcolormesh(
        x_nm,
        z_nm,
        P_slice.T,
        shading="auto",
        cmap="RdBu_r",
        vmin=vmin,
        vmax=vmax
    )

    Vmean = rec["Vtop_mean"]
    Vmin = rec["Vtop_min"]
    Vmax = rec["Vtop_max"]

    if np.isfinite(Vmean):
        v_label = f"Vg = {Vmean:+.1f} V"
        # 若你想檢查 top x/y variation，也可以顯示 min/max
        # v_label += f" [{Vmin:+.3f}, {Vmax:+.3f}]"
    else:
        v_label = "Vtop unavailable"

    step_label = f"step={rec['step']}" if rec["step"] is not None else rec["name"]

    ax.set_ylabel("z (nm)")

    ax.set_title(
        f"after |"
        f"{v_label} | {sweep_dir} | "
        f"y center ≈ {rec['y_nm']:.2f} nm",
        fontsize=9
    )

axes[-1].set_xlabel("x (nm)")
axes[-1].tick_params(axis='x', labelbottom=True)
'''
for ax in axes:
    ax.set_xlabel("x (nm)")
    ax.tick_params(axis='x', labelbottom=True)
'''
cbar = fig.colorbar(last_im, ax=axes, shrink=0.8)
cbar.set_label(r"Pz (C/m$^2$)")

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=200)
    print(f"Saved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-06-21 16:19:00,121 Parameters: current_time              = 5.166640000004391e-08
# yt : [INFO     ] 2026-06-21 16:19:00,121 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,122 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,122 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,161 Parameters: current_time              = 5.1690000000044014e-08
# yt : [INFO     ] 2026-06-21 16:19:00,162 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,162 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,162 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,203 Parameters: current_time              = 5.1716800000044133e-08
# yt : [INFO     ] 2026-06-21 16:19:00,203 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,203 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,203 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,243 Parameters: current_time              = 5.174720000004427e-08
# yt : [INFO     ] 2026-06-21 16:19:00,243 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,243 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,243 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,283 Parameters: current_time              = 5.1782800000044427e-08
# yt : [INFO     ] 2026-06-21 16:19:00,284 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,284 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,284 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Plotfiles to draw:
#   plt00129166
#   plt00129225
#   plt00129292
#   plt00129368
#   plt00129457
#   plt00129564
#   plt00129697
#   plt00129870
#   plt00130104
#   plt00201021
#   plt00201232
#   plt00201441
#   plt00201658
#   plt00201918
#   plt00202440
#   plt00202822
#   plt00202890
#   plt00202950
#   plt00203004
#   plt00203063
#   plt00203130
#   plt00203206
#   plt00203295
#   plt00203402
#   plt00203535
#   plt00203708
#   plt00203942
#   plt00264712
#   plt00264923
#   plt00265132
#   plt00265349
#   plt00265609
#   plt00266131
#   plt00266513
#   plt00266581
#   plt00266641
#   plt00266695
# 37 number of plotfiles will be drawn after filtering.
# yt : [INFO     ] 2026-06-21 16:19:00,324 Parameters: current_time              = 5.1825600000044617e-08
# yt : [INFO     ] 2026-06-21 16:19:00,324 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,324 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,324 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,363 Parameters: current_time              = 5.187880000004485e-08
# yt : [INFO     ] 2026-06-21 16:19:00,363 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,364 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,364 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,404 Parameters: current_time              = 5.194800000004516e-08
# yt : [INFO     ] 2026-06-21 16:19:00,404 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,404 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,404 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,443 Parameters: current_time              = 5.2041600000045576e-08
# yt : [INFO     ] 2026-06-21 16:19:00,443 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,443 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,444 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,484 Parameters: current_time              = 8.040839999982743e-08
# yt : [INFO     ] 2026-06-21 16:19:00,484 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,484 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,484 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,524 Parameters: current_time              = 8.04927999998264e-08
# yt : [INFO     ] 2026-06-21 16:19:00,524 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,524 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,524 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,564 Parameters: current_time              = 8.05763999998254e-08
# yt : [INFO     ] 2026-06-21 16:19:00,564 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,564 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,564 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,604 Parameters: current_time              = 8.066319999982434e-08
# yt : [INFO     ] 2026-06-21 16:19:00,604 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,604 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,604 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,643 Parameters: current_time              = 8.076719999982308e-08
# yt : [INFO     ] 2026-06-21 16:19:00,643 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,644 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,644 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:00,684 Parameters: current_time              = 8.097599999982056e-08
# yt : [INFO     ] 2026-06-21 16:19:00,684 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:00,684 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:00,684 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,005 Parameters: current_time              = 8.112879999981871e-08
# yt : [INFO     ] 2026-06-21 16:19:01,005 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,006 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,006 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,046 Parameters: current_time              = 8.115599999981838e-08
# yt : [INFO     ] 2026-06-21 16:19:01,046 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,046 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,046 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,087 Parameters: current_time              = 8.117999999981809e-08
# yt : [INFO     ] 2026-06-21 16:19:01,087 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,087 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,087 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,126 Parameters: current_time              = 8.120159999981783e-08
# yt : [INFO     ] 2026-06-21 16:19:01,127 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,127 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,127 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,167 Parameters: current_time              = 8.122519999981754e-08
# yt : [INFO     ] 2026-06-21 16:19:01,167 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,167 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,167 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,207 Parameters: current_time              = 8.125199999981722e-08
# yt : [INFO     ] 2026-06-21 16:19:01,207 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,208 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,208 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,247 Parameters: current_time              = 8.128239999981685e-08
# yt : [INFO     ] 2026-06-21 16:19:01,247 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,247 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,247 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,287 Parameters: current_time              = 8.131799999981642e-08
# yt : [INFO     ] 2026-06-21 16:19:01,287 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,287 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,287 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,326 Parameters: current_time              = 8.13607999998159e-08
# yt : [INFO     ] 2026-06-21 16:19:01,327 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,327 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,327 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,367 Parameters: current_time              = 8.141399999981526e-08
# yt : [INFO     ] 2026-06-21 16:19:01,367 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,368 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,368 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,408 Parameters: current_time              = 8.148319999981442e-08
# yt : [INFO     ] 2026-06-21 16:19:01,408 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,408 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,408 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,447 Parameters: current_time              = 8.157679999981329e-08
# yt : [INFO     ] 2026-06-21 16:19:01,448 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,448 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,448 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,488 Parameters: current_time              = 1.0588479999951914e-07
# yt : [INFO     ] 2026-06-21 16:19:01,488 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,489 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,489 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,528 Parameters: current_time              = 1.0596919999951812e-07
# yt : [INFO     ] 2026-06-21 16:19:01,528 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,528 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,528 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,569 Parameters: current_time              = 1.060527999995171e-07
# yt : [INFO     ] 2026-06-21 16:19:01,569 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,569 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,570 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,610 Parameters: current_time              = 1.0613959999951605e-07
# yt : [INFO     ] 2026-06-21 16:19:01,610 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,610 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,610 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,649 Parameters: current_time              = 1.062435999995148e-07
# yt : [INFO     ] 2026-06-21 16:19:01,649 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,650 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,650 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,690 Parameters: current_time              = 1.0645239999951227e-07
# yt : [INFO     ] 2026-06-21 16:19:01,690 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,690 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,691 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,730 Parameters: current_time              = 1.0660519999951042e-07
# yt : [INFO     ] 2026-06-21 16:19:01,730 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,730 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,730 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,771 Parameters: current_time              = 1.0663239999951009e-07
# yt : [INFO     ] 2026-06-21 16:19:01,771 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,771 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,771 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,811 Parameters: current_time              = 1.066563999995098e-07
# yt : [INFO     ] 2026-06-21 16:19:01,811 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,811 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,812 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-21 16:19:01,851 Parameters: current_time              = 1.0667799999950954e-07
# yt : [INFO     ] 2026-06-21 16:19:01,851 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-21 16:19:01,851 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-21 16:19:01,851 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Drawing 2 plots after filtering.

# %% [markdown]
# ## 3D Scatter plot (all voltage in same graph)

# %% [markdown]
# * trash

# %%
from pathlib import Path
import re

import yt
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec")

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 若 FE 只在部分 x/y 範圍，打開這裡
USE_FE_X_RANGE = False

USE_FE_Y_RANGE = False




# 用 top Phi 平均值四捨五入到整數電壓來分類
V_ROUND_DECIMALS = 0

# 3D 點太多會慢，STRIDE=2 表示 x/y/z 每 2 點取 1 點
# 若想更細可設 1；若很慢可設 3 或 4
STRIDE = 2

# 顏色是否以 0 對稱，畫 Pz 建議 True
SYMMETRIC_COLOR_SCALE = True

# 3D 視角
ELEV = 22
AZIM = -55

# 點大小
POINT_SIZE = 2

# 跳過 initial plt00000000
SKIP_INITIAL = True

# 若你已經有 plot_names，就保留 AUTO_FIND_PLOTS=False
# plot_names = [...]
AUTO_FIND_PLOTS = False

SAVE_FIG = True
OUT_FIG = PLOT_DIR/"Pz_FE_3D_2x11_sweep.png"


# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


def read_one_plot_3d(plotfile):
    ds = yt.load(str(plotfile))
    #g = ds.index.grids[0]

    P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

    if PHI_FIELD in ds.field_list:
        Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
    else:
        Phi = None

    Nx, Ny, Nz = P.shape

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    # FE selection
    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    if USE_FE_Y_RANGE:
        y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
    else:
        y_sel = np.ones_like(y_nm, dtype=bool)

    # Apply selection
    P_fe = P[np.ix_(x_sel, y_sel, z_sel)]

    x_fe = x_nm[x_sel]
    y_fe = y_nm[y_sel]
    z_fe = z_nm[z_sel]

    # Downsample for 3D plotting
    P_ds = P_fe[::STRIDE, ::STRIDE, ::STRIDE]
    x_ds = x_fe[::STRIDE]
    y_ds = y_fe[::STRIDE]
    z_ds = z_fe[::STRIDE]

    X, Y, Z = np.meshgrid(x_ds, y_ds, z_ds, indexing="ij")

    # Estimate top voltage from top cell Phi
    if Phi is not None:
        top_phi = Phi[:, :, -1]
        Vtop_mean = float(np.mean(top_phi))
        Vtop_min = float(np.min(top_phi))
        Vtop_max = float(np.max(top_phi))
    else:
        Vtop_mean = np.nan
        Vtop_min = np.nan
        Vtop_max = np.nan

    return {
        "P": P_ds,
        "X": X,
        "Y": Y,
        "Z": Z,
        "x_range": (float(np.min(x_fe)), float(np.max(x_fe))),
        "y_range": (float(np.min(y_fe)), float(np.max(y_fe))),
        "z_range": (float(np.min(z_fe)), float(np.max(z_fe))),
        "Vtop_mean": Vtop_mean,
        "Vtop_min": Vtop_min,
        "Vtop_max": Vtop_max,
        "shape_full": P.shape,
        "shape_fe": P_fe.shape,
        "shape_plot": P_ds.shape,
    }


def classify_sweep(records):
    """
    根據 records 原本的時間順序，用 Vtop 的變化判斷正掃/負掃。
    第一個點歸到 positive，因為通常是正掃起點。
    turning point 會同時加入 positive 與 negative，讓上下排都有 +5。
    """
    pos = []
    neg = []

    V = np.array([r["Vtop_mean"] for r in records], dtype=float)

    if len(records) == 0:
        return pos, neg

    pos.append(records[0])

    for i in range(1, len(records)):
        dV = V[i] - V[i - 1]

        if dV > 1e-8:
            pos.append(records[i])
        elif dV < -1e-8:
            # 如果剛從正掃轉負掃，把上一個 turning point 也放進 neg
            if len(neg) == 0:
                neg.append(records[i - 1])
            neg.append(records[i])
        else:
            # 同電壓重複時，不確定歸類；先放到目前方向
            if len(neg) == 0:
                pos.append(records[i])
            else:
                neg.append(records[i])

    return pos, neg


def pick_record_by_voltage(records, target_v):
    """
    從一組 records 中挑最接近 target_v 的那筆。
    """
    if len(records) == 0:
        return None

    V = np.array([r["Vround"] for r in records], dtype=float)
    idx = int(np.argmin(np.abs(V - target_v)))

    if np.abs(V[idx] - target_v) > 0.25:
        return None

    return records[idx]


def draw_3d_fe(ax, rec, norm, cmap):
    P = rec["P"]
    X = rec["X"]
    Y = rec["Y"]
    Z = rec["Z"]

    ax.scatter(
        X.ravel(),
        Y.ravel(),
        Z.ravel(),
        c=P.ravel(),
        cmap=cmap,
        norm=norm,
        s=POINT_SIZE,
        marker="s",
        linewidths=0,
        alpha=0.95,
    )

    ax.set_xlim(rec["x_range"])
    ax.set_ylim(rec["y_range"])
    ax.set_zlim(rec["z_range"])

    ax.view_init(elev=ELEV, azim=AZIM)

    # 22 張小圖，不要塞太多刻度
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_zticks([])

    ax.set_box_aspect((
        rec["x_range"][1] - rec["x_range"][0],
        rec["y_range"][1] - rec["y_range"][0],
        rec["z_range"][1] - rec["z_range"][0],
    ))


# ==========================
# Main
# ==========================

if AUTO_FIND_PLOTS:
    plot_names_use = find_plot_names(PLOT_DIR)
else:
    plot_names_use = list(plot_names)

plot_names_use = sorted(
    plot_names_use,
    key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99
)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

print("Plotfiles to read:")
for n in plot_names_use:
    print(" ", n)

records = []

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    info = read_one_plot_3d(plotfile)

    Vround = np.round(info["Vtop_mean"], V_ROUND_DECIMALS)

    rec = {
        "name": name,
        "step": get_step_from_name(name),
        "Vround": float(Vround),
        **info,
    }

    records.append(rec)

print("\nRead records:")
for r in records:
    print(
        f"{r['name']}  step={r['step']}  "
        f"Vtop={r['Vtop_mean']:+.4f} V  Vround={r['Vround']:+.0f}  "
        f"shape_fe={r['shape_fe']}  shape_plot={r['shape_plot']}"
    )

# classify positive / negative sweep from time ordering
pos_records, neg_records = classify_sweep(records)

print("\nPositive sweep records:")
for r in pos_records:
    print(f"  V={r['Vround']:+.0f}  {r['name']}")

print("\nNegative sweep records:")
for r in neg_records:
    print(f"  V={r['Vround']:+.0f}  {r['name']}")

# Arrange columns left-to-right by increasing voltage: -5, -4, ..., 5
pos_grid = [pick_record_by_voltage(pos_records, v) for v in VOLTAGES]
neg_grid = [pick_record_by_voltage(neg_records, v) for v in VOLTAGES]

# shared color scale from all selected records
selected_records = [r for r in pos_grid + neg_grid if r is not None]
if len(selected_records) == 0:
    raise RuntimeError("No records selected. Check plot_names or voltage classification.")

all_p = np.concatenate([r["P"].ravel() for r in selected_records])

if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(all_p))
    vmin = -vmax
else:
    vmin = np.nanmin(all_p)
    vmax = np.nanmax(all_p)

cmap = "RdBu"
norm = Normalize(vmin=vmin, vmax=vmax)

# 2 x 11 figure
fig = plt.figure(figsize=(22, 6.2))

axes = np.empty((2, len(VOLTAGES)), dtype=object)

for row in range(2):
    for col in range(len(VOLTAGES)):
        axes[row, col] = fig.add_subplot(
            2,
            len(VOLTAGES),
            row * len(VOLTAGES) + col + 1,
            projection="3d"
        )

for col, Vtarget in enumerate(VOLTAGES):
    rec = pos_grid[col]
    ax = axes[0, col]

    if rec is not None:
        draw_3d_fe(ax, rec, norm, cmap)
        ax.set_title(f"{Vtarget:+.0f} V\npos sweep", fontsize=9)
    else:
        ax.set_title(f"{Vtarget:+.0f} V\nmissing", fontsize=9)
        ax.axis("off")

for col, Vtarget in enumerate(VOLTAGES):
    rec = neg_grid[col]
    ax = axes[1, col]

    if rec is not None:
        draw_3d_fe(ax, rec, norm, cmap)
        ax.set_title(f"{Vtarget:+.0f} V\nneg sweep", fontsize=9)
    else:
        ax.set_title(f"{Vtarget:+.0f} V\nmissing", fontsize=9)
        ax.axis("off")

# row labels
fig.text(0.01, 0.72, "Positive sweep\n(-5 → +5)", va="center", ha="left", fontsize=12)
fig.text(0.01, 0.28, "Negative sweep\n(+5 → -5)\nshown as -5 → +5", va="center", ha="left", fontsize=12)

# shared colorbar
sm = ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])

cbar = fig.colorbar(
    sm,
    ax=axes.ravel().tolist(),
    shrink=0.75,
    pad=0.01,
    location="right"
)
cbar.set_label(r"Pz (C/m$^2$)")

fig.suptitle(
    "3D FE-layer Pz colormap | columns ordered by increasing applied voltage",
    fontsize=14
)

plt.tight_layout(rect=[0.04, 0.03, 0.94, 0.93])

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=200)
    print(f"\nSaved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-06-02 14:39:32,644 Parameters: current_time              = 1.52e-11
# yt : [INFO     ] 2026-06-02 14:39:32,645 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:32,645 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:32,646 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:32,753 Parameters: current_time              = 2.4799999999999998e-11
# yt : [INFO     ] 2026-06-02 14:39:32,754 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:32,755 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:32,755 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Plotfiles to read:
#   plt00000076
#   plt00000124
#   plt00000178
#   plt00000238
#   plt00000307
#   plt00000389
#   plt00000493
#   plt00000639
#   plt00000911
#   plt00001160
#   plt00001330
#   plt00001378
#   plt00001431
#   plt00001491
#   plt00001560
#   plt00001641
#   plt00001743
#   plt00001886
#   plt00002150
#   plt00002398
#   plt00002575
# yt : [INFO     ] 2026-06-02 14:39:32,860 Parameters: current_time              = 3.56000000000001e-11
# yt : [INFO     ] 2026-06-02 14:39:32,860 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:32,861 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:32,861 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:32,974 Parameters: current_time              = 4.760000000000029e-11
# yt : [INFO     ] 2026-06-02 14:39:32,975 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:32,976 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:32,976 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:33,317 Parameters: current_time              = 6.140000000000042e-11
# yt : [INFO     ] 2026-06-02 14:39:33,318 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:33,319 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:33,320 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:33,423 Parameters: current_time              = 7.780000000000015e-11
# yt : [INFO     ] 2026-06-02 14:39:33,423 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:33,424 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:33,424 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:33,531 Parameters: current_time              = 9.859999999999981e-11
# yt : [INFO     ] 2026-06-02 14:39:33,532 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:33,533 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:33,533 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:33,644 Parameters: current_time              = 1.2780000000000007e-10
# yt : [INFO     ] 2026-06-02 14:39:33,645 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:33,646 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:33,647 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:33,756 Parameters: current_time              = 1.822000000000027e-10
# yt : [INFO     ] 2026-06-02 14:39:33,756 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:33,757 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:33,757 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:33,862 Parameters: current_time              = 2.320000000000051e-10
# yt : [INFO     ] 2026-06-02 14:39:33,863 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:33,864 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:33,864 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:33,972 Parameters: current_time              = 2.6600000000000673e-10
# yt : [INFO     ] 2026-06-02 14:39:33,973 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:33,974 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:33,974 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:34,077 Parameters: current_time              = 2.756000000000072e-10
# yt : [INFO     ] 2026-06-02 14:39:34,078 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:34,078 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:34,079 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:34,184 Parameters: current_time              = 2.862000000000077e-10
# yt : [INFO     ] 2026-06-02 14:39:34,185 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:34,185 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:34,186 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:34,292 Parameters: current_time              = 2.982000000000083e-10
# yt : [INFO     ] 2026-06-02 14:39:34,292 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:34,293 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:34,294 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:34,399 Parameters: current_time              = 3.1200000000000895e-10
# yt : [INFO     ] 2026-06-02 14:39:34,400 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:34,400 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:34,401 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:34,506 Parameters: current_time              = 3.2820000000000973e-10
# yt : [INFO     ] 2026-06-02 14:39:34,506 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:34,507 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:34,507 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:34,611 Parameters: current_time              = 3.486000000000107e-10
# yt : [INFO     ] 2026-06-02 14:39:34,611 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:34,612 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:34,612 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:34,716 Parameters: current_time              = 3.772000000000121e-10
# yt : [INFO     ] 2026-06-02 14:39:34,716 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:34,717 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:34,718 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:35,054 Parameters: current_time              = 4.3000000000001465e-10
# yt : [INFO     ] 2026-06-02 14:39:35,055 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:35,055 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:35,056 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:35,162 Parameters: current_time              = 4.796000000000134e-10
# yt : [INFO     ] 2026-06-02 14:39:35,163 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:35,163 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:35,164 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# yt : [INFO     ] 2026-06-02 14:39:35,270 Parameters: current_time              = 5.15000000000006e-10
# yt : [INFO     ] 2026-06-02 14:39:35,270 Parameters: domain_dimensions         = [64 64 59]
# yt : [INFO     ] 2026-06-02 14:39:35,271 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-02 14:39:35,271 Parameters: domain_right_edge         = [1.60e-08 1.60e-08 2.95e-08]
# Read records:
# plt00000076  step=76  Vtop=-5.0820 V  Vround=-5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000124  step=124  Vtop=-4.0882 V  Vround=-4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000178  step=178  Vtop=-3.0936 V  Vround=-3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000238  step=238  Vtop=-2.0981 V  Vround=-2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000307  step=307  Vtop=-1.1012 V  Vround=-1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000389  step=389  Vtop=-0.1026 V  Vround=-0  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000493  step=493  Vtop=+0.8985 V  Vround=+1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000639  step=639  Vtop=+1.9041 V  Vround=+2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00000911  step=911  Vtop=+2.9208 V  Vround=+3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001160  step=1160  Vtop=+3.9405 V  Vround=+4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001330  step=1330  Vtop=+5.1121 V  Vround=+5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001378  step=1378  Vtop=+4.1184 V  Vround=+4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001431  step=1431  Vtop=+3.1240 V  Vround=+3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001491  step=1491  Vtop=+2.1286 V  Vround=+2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001560  step=1560  Vtop=+1.1320 V  Vround=+1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001641  step=1641  Vtop=+0.1336 V  Vround=+0  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001743  step=1743  Vtop=-0.8673 V  Vround=-1  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00001886  step=1886  Vtop=-1.8726 V  Vround=-2  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00002150  step=2150  Vtop=-2.8887 V  Vround=-3  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00002398  step=2398  Vtop=-3.9092 V  Vround=-4  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
# plt00002575  step=2575  Vtop=-5.0820 V  Vround=-5  shape_fe=(64, 64, 16)  shape_plot=(32, 32, 8)
#
# Positive sweep records:
#   V=-5  plt00000076
#   V=-4  plt00000124
#   V=-3  plt00000178
#   V=-2  plt00000238
#   V=-1  plt00000307
#   V=-0  plt00000389
#   V=+1  plt00000493
#   V=+2  plt00000639
#   V=+3  plt00000911
#   V=+4  plt00001160
#   V=+5  plt00001330
#
# Negative sweep records:
#   V=+5  plt00001330
#   V=+4  plt00001378
#   V=+3  plt00001431
#   V=+2  plt00001491
#   V=+1  plt00001560
#   V=+0  plt00001641
#   V=-1  plt00001743
#   V=-2  plt00001886
#   V=-3  plt00002150
#   V=-4  plt00002398
#   V=-5  plt00002575
# /tmp/ipykernel_751268/2315896281.py:387: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0.04, 0.03, 0.94, 0.93])
# Saved figure: /home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_11_plt/Pz_FE_3D_2x11_sweep.png

# %% [markdown]
# ## 3D Contour plot

# %% [markdown]
# * 畫出長方體三個面
# * 選擇要畫的三個面C1,C2,C3
# * 選擇視角

# %%
from pathlib import Path

import yt
import numpy as np
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_plt")
   # 改成你要畫的 plotfile

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 如果 FE 只想取部分 x/y 範圍
USE_FE_X_RANGE = False


USE_FE_Y_RANGE = False


# contour levels
N_LEVELS = 21

# 視角
ELEV = 35
AZIM = 245

# 色階是否對稱於 0
SYMMETRIC_COLOR_SCALE = True

SAVE_FIG= True
OUT_FIG = PLOT_DIR/"Pz_FE_3D_contour_p+1.5.png"

# ==========================
# Helper
# ==========================

def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


# ==========================
# Load data
# ==========================
specify_plotfile = "plt00052034"

if specify_plotfile is not None:
    plotfile = PLOT_DIR / specify_plotfile
    if not plotfile.is_dir():
        raise FileNotFoundError(f"Specified plotfile not found: {plotfile}")
else:
    plotfile = PLOT_DIR / PLOTFILE_NAME
    
ds = yt.load(str(plotfile))
g = ds.index.grids[0]

P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

if PHI_FIELD in ds.field_list:
    Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
else:
    Phi = None

Nx, Ny, Nz = P.shape

lo = ds.domain_left_edge.to_value()
hi = ds.domain_right_edge.to_value()
dx = (hi - lo) / np.array([Nx, Ny, Nz])

x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9


# ==========================
# Select FE layer
# ==========================

z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

if USE_FE_X_RANGE:
    x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
else:
    x_sel = np.ones_like(x_nm, dtype=bool)

if USE_FE_Y_RANGE:
    y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
else:
    y_sel = np.ones_like(y_nm, dtype=bool)

P_fe = P[np.ix_(x_sel, y_sel, z_sel)]

x_fe = x_nm[x_sel]
y_fe = y_nm[y_sel]
z_fe = z_nm[z_sel]

Nx_fe, Ny_fe, Nz_fe = P_fe.shape

# 選三個切面：
# xy plane at top FE surface
k_top = Nz_fe - 1

# xz plane at y min side
#j_mid = Ny_fe // 2

# yz plane at x max side
i_right = Nx_fe - 1

P_xy = P_fe[:, :, k_top]      # shape (Nx, Ny)
P_xz = P_fe[:, 0, :]      # shape (Nx, Nz)
P_yz = P_fe[0, :, :]    # shape (Ny, Nz)

# 建立 2D coordinates
X_xy, Y_xy = np.meshgrid(x_fe, y_fe, indexing="ij")
X_xz, Z_xz = np.meshgrid(x_fe, z_fe, indexing="ij")
Y_yz, Z_yz = np.meshgrid(y_fe, z_fe, indexing="ij")


# ==========================
# Voltage label
# ==========================

if Phi is not None:
    top_phi = Phi[:, :, -1]
    Vtop_mean = float(np.mean(top_phi))
else:
    Vtop_mean = np.nan


# ==========================
# Color scale
# ==========================

if SYMMETRIC_COLOR_SCALE:
    vmax = np.nanmax(np.abs(P_fe))
    vmin = -vmax
else:
    vmin = np.nanmin(P_fe)
    vmax = np.nanmax(P_fe)

levels = np.linspace(vmin, vmax, N_LEVELS)

kw = dict(
    levels=levels,
    vmin=vmin,
    vmax=vmax,
    cmap="RdBu_r",
)


# ==========================
# Plot 3D contour walls
# ==========================

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection="3d")

xmin, xmax = x_fe.min(), x_fe.max()
ymin, ymax = y_fe.min(), y_fe.max()
zmin, zmax = z_fe.min(), z_fe.max()

# 1. xy plane, placed at z = zmax
# contourf expects arrays with same shape.
# X_xy/Y_xy/P_xy are (Nx, Ny)
C1 = ax.contourf(
    X_xy,
    Y_xy,
    P_xy,
    zdir="z",
    offset=zmax,
    **kw
)

# 2. xz plane, placed at y = ymin
# Here x-axis is X_xz, vertical is Z_xz, color is P_xz
C2 = ax.contourf(
    X_xz,
    P_xz,
    Z_xz,
    zdir="y",
    offset=ymin,
    **kw
)

# 3. yz plane, placed at x = xmax
# Here horizontal axis is Y_yz, vertical is Z_yz, color is P_yz
C3 = ax.contourf(
    P_yz,
    Y_yz,
    Z_yz,
    zdir="x",
    offset=xmin,
    **kw
)

# Set axis limits
ax.set(
    xlim=[xmin, xmax],
    ylim=[ymin, ymax],
    zlim=[zmin, zmax],
)

# Draw box edges
edges_kw = dict(color="0.35", linewidth=1.0, zorder=1000)

# 只畫可見的外框邊，不畫背後被內容遮住的線
visible_edges = [
    # bottom/front-ish edges（左側變主視角）
    ([xmin, xmax], [ymin, ymin], [zmin, zmin]),
    ([xmin, xmin], [ymin, ymax], [zmin, zmin]),
    ([xmin, xmin], [ymin, ymin], [zmin, zmax]),

    # top/front-ish edges
    ([xmin, xmax], [ymin, ymin], [zmax, zmax]),
    ([xmin, xmin], [ymin, ymax], [zmax, zmax]),
    ([xmin, xmin], [ymin, ymin], [zmin, zmax]),
]

for xs, ys, zs in visible_edges:
    ax.plot(xs, ys, zs, **edges_kw)
ax.set_xlabel("x (nm)")
ax.set_ylabel("y (nm)")
ax.set_zlabel("z (nm)")

ax.view_init(ELEV, AZIM)
Z_VISUAL_SCALE = 2.5
ax.set_box_aspect((
    xmax - xmin,
    ymax - ymin,
    Z_VISUAL_SCALE * (zmax - zmin)
))

ax.set_title(
    
    rf"FE-layer Pz contour walls | positive sweep | $V_{{app}}$ = {Vtop_mean:+.1f} V"
)

cbar = fig.colorbar(C3, ax=ax, fraction=0.035, pad=0.12)
cbar.set_label(r"Pz (C/m$^2$)")

plt.tight_layout()

if SAVE_FIG:
    fig.savefig(OUT_FIG, dpi=300)
    print(f"\nSaved figure: {OUT_FIG}")

plt.show()
# Out:
# yt : [INFO     ] 2026-06-19 23:41:23,619 Parameters: current_time              = 2.0813599999981195e-08
# yt : [INFO     ] 2026-06-19 23:41:23,619 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-19 23:41:23,619 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-19 23:41:23,620 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Saved figure: /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_3D_1e-6/Pz_FE_3D_contour_p+1.5.png

# %% [markdown]
# ## 3D Contour plot(all)

# %% [markdown]
# * 畫出長方體三個面
# * 選擇要畫的三個面C1,C2,C3
# * 選擇視角

# %%
## 

from pathlib import Path

import yt
import numpy as np
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_plt")
   # 改成你要畫的 plotfile

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 如果 FE 只想取部分 x/y 範圍
USE_FE_X_RANGE = False


USE_FE_Y_RANGE = False


# contour levels
N_LEVELS = 21

# 視角
ELEV = 35
AZIM = 245

# 色階是否對稱於 0
SYMMETRIC_COLOR_SCALE = True

SAVE_FIG= False
OUT_FIG = PLOT_DIR/"Pz_FE_3D_contour_p+1.5.png"

# ==========================
# Helper
# ==========================

def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v


# ==========================
# Load data
# ==========================

all_plot_names = find_plot_names(PLOT_DIR)


# sort by step if names are plt########
all_plot_names = sorted(all_plot_names, key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99)
# skip initial plt(initial state)
all_plot_names = [
        n for n in all_plot_names
        if get_step_from_name(n) != 0
    ]

sel_plot_names = all_plot_names[:] #chose postive/negative sweep by voltage 

print("Selected plotfiles to draw:")
for n in sel_plot_names:
    print(" ", n)

for index, plt_name in enumerate(sel_plot_names):
    plotfile = PLOT_DIR / plt_name
        
    ds = yt.load(str(plotfile))
    g = ds.index.grids[0]

    P = read_full_field_from_grids(ds, P_FIELD) # 讀取整個 domain 的 Pz 資料，會自動合併多個 grid

    if PHI_FIELD in ds.field_list:
        Phi = read_full_field_from_grids(ds, PHI_FIELD) # 讀取整個 domain 的 Phi 資料，會自動合併多個 grid
    else:
        Phi = None

    Nx, Ny, Nz = P.shape

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9


    # ==========================
    # Select FE layer
    # ==========================

    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    if USE_FE_Y_RANGE:
        y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
    else:
        y_sel = np.ones_like(y_nm, dtype=bool)

    P_fe = P[np.ix_(x_sel, y_sel, z_sel)]

    x_fe = x_nm[x_sel]
    y_fe = y_nm[y_sel]
    z_fe = z_nm[z_sel]

    Nx_fe, Ny_fe, Nz_fe = P_fe.shape

    # 選三個切面：
    # xy plane at top FE surface
    k_top = Nz_fe - 1

    # xz plane at y min side
    #j_mid = Ny_fe // 2

    # yz plane at x max side
    i_right = Nx_fe - 1

    P_xy = P_fe[:, :, k_top]      # shape (Nx, Ny)
    P_xz = P_fe[:, 0, :]      # shape (Nx, Nz)
    P_yz = P_fe[0, :, :]    # shape (Ny, Nz)

    # 建立 2D coordinates
    X_xy, Y_xy = np.meshgrid(x_fe, y_fe, indexing="ij")
    X_xz, Z_xz = np.meshgrid(x_fe, z_fe, indexing="ij")
    Y_yz, Z_yz = np.meshgrid(y_fe, z_fe, indexing="ij")


    # ==========================
    # Voltage label
    # ==========================

    if Phi is not None:
        top_phi = Phi[:, :, -1]
        Vtop_mean = float(np.mean(top_phi))
    else:
        Vtop_mean = np.nan


    # ==========================
    # Color scale
    # ==========================

    if SYMMETRIC_COLOR_SCALE:
        vmax = np.nanmax(np.abs(P_fe))
        vmin = -vmax
    else:
        vmin = np.nanmin(P_fe)
        vmax = np.nanmax(P_fe)

    levels = np.linspace(vmin, vmax, N_LEVELS)

    kw = dict(
        levels=levels,
        vmin=vmin,
        vmax=vmax,
        cmap="RdBu_r",
    )


    # ==========================
    # Plot 3D contour walls
    # ==========================

    fig = plt.figure(figsize=(10, 6))
    ax = fig.add_subplot(111, projection="3d")

    xmin, xmax = x_fe.min(), x_fe.max()
    ymin, ymax = y_fe.min(), y_fe.max()
    zmin, zmax = z_fe.min(), z_fe.max()

    # 1. xy plane, placed at z = zmax
    # contourf expects arrays with same shape.
    # X_xy/Y_xy/P_xy are (Nx, Ny)
    C1 = ax.contourf(
        X_xy,
        Y_xy,
        P_xy,
        zdir="z",
        offset=zmax,
        **kw
    )

    # 2. xz plane, placed at y = ymin
    # Here x-axis is X_xz, vertical is Z_xz, color is P_xz
    C2 = ax.contourf(
        X_xz,
        P_xz,
        Z_xz,
        zdir="y",
        offset=ymin,
        **kw
    )

    # 3. yz plane, placed at x = xmax
    # Here horizontal axis is Y_yz, vertical is Z_yz, color is P_yz
    C3 = ax.contourf(
        P_yz,
        Y_yz,
        Z_yz,
        zdir="x",
        offset=xmin,
        **kw
    )

    # Set axis limits
    ax.set(
        xlim=[xmin, xmax],
        ylim=[ymin, ymax],
        zlim=[zmin, zmax],
    )

    # Draw box edges
    edges_kw = dict(color="0.35", linewidth=1.0, zorder=1000)

    # 只畫可見的外框邊，不畫背後被內容遮住的線
    visible_edges = [
        # bottom/front-ish edges（左側變主視角）
        ([xmin, xmax], [ymin, ymin], [zmin, zmin]),
        ([xmin, xmin], [ymin, ymax], [zmin, zmin]),
        ([xmin, xmin], [ymin, ymin], [zmin, zmax]),

        # top/front-ish edges
        ([xmin, xmax], [ymin, ymin], [zmax, zmax]),
        ([xmin, xmin], [ymin, ymax], [zmax, zmax]),
        ([xmin, xmin], [ymin, ymin], [zmin, zmax]),
    ]

    for xs, ys, zs in visible_edges:
        ax.plot(xs, ys, zs, **edges_kw)
    ax.set_xlabel("x (nm)")
    ax.set_ylabel("y (nm)")
    ax.set_zlabel("z (nm)")

    ax.view_init(ELEV, AZIM)
    Z_VISUAL_SCALE = 2.5
    ax.set_box_aspect((
        xmax - xmin,
        ymax - ymin,
        Z_VISUAL_SCALE * (zmax - zmin)
    ))
    if index <= int(VOLTAGES.shape[0])-1:
        ax.set_title(
            
            rf"FE-layer Pz contour walls | positive sweep | $V_{{app}}$ = {Vtop_mean:+.1f} V"
        )
    else:
        ax.set_title(
            
            rf"FE-layer Pz contour walls | negative sweep | $V_{{app}}$ = {Vtop_mean:+.1f} V"
        )

    cbar = fig.colorbar(C3, ax=ax, fraction=0.035, pad=0.12)
    cbar.set_label(r"Pz (C/m$^2$)")

    plt.tight_layout()

    if SAVE_FIG:
        fig.savefig(OUT_FIG, dpi=300)
        print(f"\nSaved figure: {OUT_FIG}")

    plt.show()
# Out:
# yt : [INFO     ] 2026-06-20 00:16:09,842 Parameters: current_time              = 3.28e-11
# yt : [INFO     ] 2026-06-20 00:16:09,843 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:09,843 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:09,843 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Selected plotfiles to draw:
#   plt00000082
#   plt00000130
#   plt00000183
#   plt00000243
#   plt00000314
#   plt00000399
#   plt00000505
#   plt00000644
#   plt00000838
#   plt00025875
#   plt00032405
#   plt00039094
#   plt00052034
#   plt00076659
#   plt00139169
#   plt00139618
#   plt00140872
#   plt00140920
#   plt00140963
#   plt00141010
#   plt00141063
#   plt00141123
#   plt00141194
#   plt00141279
#   plt00141385
#   plt00141524
#   plt00141714
#   plt00144420
#   plt00144625
#   plt00144814
#   plt00144999
#   plt00145199
#   plt00145496
#   plt00145889
#   plt00145944
#   plt00145992
#   plt00146035
# yt : [INFO     ] 2026-06-20 00:16:09,962 Parameters: current_time              = 5.1999999999999995e-11
# yt : [INFO     ] 2026-06-20 00:16:09,962 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:09,962 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:09,963 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:10,077 Parameters: current_time              = 7.320000000000024e-11
# yt : [INFO     ] 2026-06-20 00:16:10,078 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:10,078 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:10,078 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:10,193 Parameters: current_time              = 9.720000000000062e-11
# yt : [INFO     ] 2026-06-20 00:16:10,193 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:10,193 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:10,193 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:10,313 Parameters: current_time              = 1.2560000000000079e-10
# yt : [INFO     ] 2026-06-20 00:16:10,313 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:10,313 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:10,313 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:10,431 Parameters: current_time              = 1.5960000000000023e-10
# yt : [INFO     ] 2026-06-20 00:16:10,431 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:10,431 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:10,431 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:10,547 Parameters: current_time              = 2.0199999999999954e-10
# yt : [INFO     ] 2026-06-20 00:16:10,547 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:10,547 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:10,547 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:10,930 Parameters: current_time              = 2.5760000000000023e-10
# yt : [INFO     ] 2026-06-20 00:16:10,930 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:10,931 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:10,931 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:11,046 Parameters: current_time              = 3.3520000000000397e-10
# yt : [INFO     ] 2026-06-20 00:16:11,047 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:11,047 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:11,047 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:11,164 Parameters: current_time              = 1.035000000000244e-08
# yt : [INFO     ] 2026-06-20 00:16:11,164 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:11,164 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:11,164 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:11,292 Parameters: current_time              = 1.2962000000003241e-08
# yt : [INFO     ] 2026-06-20 00:16:11,293 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:11,293 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:11,293 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:11,417 Parameters: current_time              = 1.5637600000001015e-08
# yt : [INFO     ] 2026-06-20 00:16:11,417 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:11,417 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:11,417 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:11,543 Parameters: current_time              = 2.0813599999981195e-08
# yt : [INFO     ] 2026-06-20 00:16:11,543 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:11,543 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:11,544 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:11,666 Parameters: current_time              = 3.06635999999506e-08
# yt : [INFO     ] 2026-06-20 00:16:11,666 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:11,666 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:11,666 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:11,788 Parameters: current_time              = 5.5667600000061685e-08
# yt : [INFO     ] 2026-06-20 00:16:11,788 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:11,788 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:11,789 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:11,909 Parameters: current_time              = 5.584720000006248e-08
# yt : [INFO     ] 2026-06-20 00:16:11,910 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:11,910 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:11,910 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:12,033 Parameters: current_time              = 5.634880000006471e-08
# yt : [INFO     ] 2026-06-20 00:16:12,033 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:12,033 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:12,033 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:12,149 Parameters: current_time              = 5.63680000000648e-08
# yt : [INFO     ] 2026-06-20 00:16:12,149 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:12,149 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:12,150 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:12,533 Parameters: current_time              = 5.6385200000064873e-08
# yt : [INFO     ] 2026-06-20 00:16:12,533 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:12,533 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:12,533 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:12,651 Parameters: current_time              = 5.640400000006496e-08
# yt : [INFO     ] 2026-06-20 00:16:12,651 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:12,651 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:12,651 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:12,766 Parameters: current_time              = 5.642520000006505e-08
# yt : [INFO     ] 2026-06-20 00:16:12,766 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:12,767 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:12,767 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:12,881 Parameters: current_time              = 5.644920000006516e-08
# yt : [INFO     ] 2026-06-20 00:16:12,881 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:12,882 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:12,882 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:12,997 Parameters: current_time              = 5.6477600000065284e-08
# yt : [INFO     ] 2026-06-20 00:16:12,997 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:12,997 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:12,997 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:13,112 Parameters: current_time              = 5.6511600000065435e-08
# yt : [INFO     ] 2026-06-20 00:16:13,112 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:13,112 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:13,112 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:13,229 Parameters: current_time              = 5.655400000006562e-08
# yt : [INFO     ] 2026-06-20 00:16:13,229 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:13,229 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:13,230 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:13,348 Parameters: current_time              = 5.660960000006587e-08
# yt : [INFO     ] 2026-06-20 00:16:13,348 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:13,348 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:13,349 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:13,469 Parameters: current_time              = 5.668560000006621e-08
# yt : [INFO     ] 2026-06-20 00:16:13,469 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:13,470 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:13,470 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:13,585 Parameters: current_time              = 5.7768000000071017e-08
# yt : [INFO     ] 2026-06-20 00:16:13,585 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:13,586 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:13,586 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:13,969 Parameters: current_time              = 5.785000000007138e-08
# yt : [INFO     ] 2026-06-20 00:16:13,970 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:13,970 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:13,970 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:14,091 Parameters: current_time              = 5.792560000007172e-08
# yt : [INFO     ] 2026-06-20 00:16:14,091 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:14,092 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:14,092 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:14,214 Parameters: current_time              = 5.7999600000072046e-08
# yt : [INFO     ] 2026-06-20 00:16:14,215 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:14,215 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:14,215 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:14,341 Parameters: current_time              = 5.80796000000724e-08
# yt : [INFO     ] 2026-06-20 00:16:14,341 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:14,342 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:14,342 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:14,463 Parameters: current_time              = 5.819840000007293e-08
# yt : [INFO     ] 2026-06-20 00:16:14,463 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:14,464 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:14,464 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:14,585 Parameters: current_time              = 5.835560000007363e-08
# yt : [INFO     ] 2026-06-20 00:16:14,585 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:14,585 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:14,586 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:14,700 Parameters: current_time              = 5.8377600000073725e-08
# yt : [INFO     ] 2026-06-20 00:16:14,701 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:14,701 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:14,701 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:14,816 Parameters: current_time              = 5.839680000007381e-08
# yt : [INFO     ] 2026-06-20 00:16:14,816 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:14,816 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:14,816 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-20 00:16:14,930 Parameters: current_time              = 5.8414000000073887e-08
# yt : [INFO     ] 2026-06-20 00:16:14,930 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-20 00:16:14,930 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-20 00:16:14,931 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]

# %% [markdown]
# ## PV

# %% [markdown]
# ### User Settings

# %%
from pathlib import Path
import re

import yt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# ==========================
# User settings
# ==========================

#PLOT_DIR = Path("/home/kaiwi/FAM/FerroX/Exec/MFIS_t_8_1_plt")

P_FIELD = ("boxlib", "Pz")
PHI_FIELD = ("boxlib", "Phi")


# 如果 FE 是全幅 MFIS，通常不用限制 x/y
USE_FE_X_RANGE = False


USE_FE_Y_RANGE = False
# 若你已經有 steady-state plot_names，就用 AUTO_FIND_PLOTS=False
# plot_names = [...]
AUTO_FIND_PLOTS = True

# 如果沒有 plot_names，可以自動找所有 plt########
# 但建議最好只用 steady-state plotfiles
SKIP_INITIAL = True

OUT_CSV = PLOT_DIR/"MFIM_PV_curve_add_f.csv"
OUT_FIG = PLOT_DIR/"MFIM_PV_curve_3comp.png"

# %% [markdown]
# ### Utils

# %%
# ==========================
# Helper functions
# ==========================

def get_step_from_name(name):
    m = re.fullmatch(r"plt(\d+)", str(name))
    return int(m.group(1)) if m else None


def find_plot_names(plot_dir):
    names = []
    for p in plot_dir.iterdir():
        if p.is_dir() and re.fullmatch(r"plt\d+", p.name):
            names.append(p.name)
    names.sort(key=lambda n: get_step_from_name(n))
    return names


def to_numpy(field_data):
    try:
        return field_data.to_ndarray()
    except AttributeError:
        return field_data.v

def read_full_field_from_grids(ds, field):
    """
    Read a cell-centered AMReX field from all yt grids
    and stitch them into one full-domain numpy array.

    Return:
        full: numpy array with shape ds.domain_dimensions
    """
    dims = np.array(ds.domain_dimensions, dtype=int)
    full = np.empty(tuple(dims), dtype=float)

    domain_lo = ds.domain_left_edge.to_value()
    domain_hi = ds.domain_right_edge.to_value()
    dx = (domain_hi - domain_lo) / dims

    for grid in ds.index.grids:
        arr = to_numpy(grid[field])

        left = grid.LeftEdge.to_value()

        # grid start index in global domain
        start = np.rint((left - domain_lo) / dx).astype(int)

        nx, ny, nz = arr.shape
        i0, j0, k0 = start
        i1, j1, k1 = i0 + nx, j0 + ny, k0 + nz

        full[i0:i1, j0:j1, k0:k1] = arr

    return full

def read_pv_from_plot(plotfile):
    ds = yt.load(str(plotfile))
    Pz = read_full_field_from_grids(ds, P_FIELD)
    Phi = read_full_field_from_grids(ds, PHI_FIELD)

    Nx, Ny, Nz = Pz.shape
    print(f"Read Pz with shape {Pz.shape} from {plotfile}")

    lo = ds.domain_left_edge.to_value()
    hi = ds.domain_right_edge.to_value()
    print(f"Domain: x [{lo[0]:.3e}, {hi[0]:.3e}] m, "
          f"y [{lo[1]:.3e}, {hi[1]:.3e}] m, "
          f"z [{lo[2]:.3e}, {hi[2]:.3e}] m")
    dx = (hi - lo) / np.array([Nx, Ny, Nz])

    x_nm = (lo[0] + (np.arange(Nx) + 0.5) * dx[0]) * 1e9
    y_nm = (lo[1] + (np.arange(Ny) + 0.5) * dx[1]) * 1e9
    z_nm = (lo[2] + (np.arange(Nz) + 0.5) * dx[2]) * 1e9

    z_sel = (z_nm >= FE_Z_LO_NM) & (z_nm <= FE_Z_HI_NM)

    if USE_FE_X_RANGE:
        x_sel = (x_nm >= FE_X_LO_NM) & (x_nm <= FE_X_HI_NM)
    else:
        x_sel = np.ones_like(x_nm, dtype=bool)

    if USE_FE_Y_RANGE:
        y_sel = (y_nm >= FE_Y_LO_NM) & (y_nm <= FE_Y_HI_NM)
    else:
        y_sel = np.ones_like(y_nm, dtype=bool)

    Pz_FE = Pz[np.ix_(x_sel, y_sel, z_sel)]

    P_mean = float(np.mean(Pz_FE))
    P_min = float(np.min(Pz_FE))
    P_max = float(np.max(Pz_FE))
    P_std = float(np.std(Pz_FE))

    # 用最上層 cell 的 Phi 平均值估 top electrode potential
    # 注意：這是 top cell center，不是真正 ghost boundary
    top_phi = Phi[:, :, -1]
    Vg_mean = float(np.mean(top_phi))
    Vg_min = float(np.min(top_phi))
    Vg_max = float(np.max(top_phi))
    Vg_std = float(np.std(top_phi))

    return {
        "P_mean": P_mean,
        "P_min": P_min,
        "P_max": P_max,
        "P_std": P_std,
        "Vg_mean": Vg_mean,
        "Vg_min": Vg_min,
        "Vg_max": Vg_max,
        "Vg_std": Vg_std,
        "Nx": Nx,
        "Ny": Ny,
        "Nz": Nz,
        "num_FE_cells": int(Pz_FE.size),
    }

# %% [markdown]
# ### Data Preparation

# %%
# ==========================
# Main
# ==========================


plot_names_use = list(plot_names)

plot_names_use = sorted(
    plot_names_use,
    key=lambda n: get_step_from_name(n) if get_step_from_name(n) is not None else 10**99
)

if SKIP_INITIAL:
    plot_names_use = [
        n for n in plot_names_use
        if get_step_from_name(n) != 0
    ]

plot_names_use = plot_names_use[9:]  # skip first 9 plotfiles
rows = []

print(plot_names_use)

for name in plot_names_use:
    plotfile = PLOT_DIR / name
    step = get_step_from_name(name)

    info = read_pv_from_plot(plotfile)

    rows.append({
        "plotfile": name,
        "step": step,
        **info,
    })

    print(
        f"{name} | step={step} | "
        f"Vg={info['Vg_mean']:+.4f} V | "
        f"<Pz>_FE={info['P_mean']:+.6e}"
    )

df = pd.DataFrame(rows)
df.to_csv(OUT_CSV, index=False)
print(f"Saved CSV: {OUT_CSV}")


# ==========================
# Determine sweep direction
# ==========================

V = df["Vg_mean"].to_numpy()
P = df["P_mean"].to_numpy()


direction = np.zeros_like(V)

for i in range(1, len(V)):
    dV = V[i] - V[i - 1]
    if dV > 1e-8:
        direction[i] = 1   # positive sweep
    elif dV < -1e-8:
        direction[i] = -1  # negative sweep
    else:
        direction[i] = direction[i - 1]

#np.append(direction, direction[-1])  # 複製第一筆到最後

df["sweep_direction"] = direction
df.to_csv(OUT_CSV, index=False)
# Out:
# yt : [INFO     ] 2026-06-25 19:39:54,957 Parameters: current_time              = 5.166640000004391e-08
# yt : [INFO     ] 2026-06-25 19:39:54,957 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:54,957 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:54,958 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:54,998 Parameters: current_time              = 5.1690000000044014e-08
# yt : [INFO     ] 2026-06-25 19:39:54,998 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:54,999 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:54,999 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,040 Parameters: current_time              = 5.1716800000044133e-08
# yt : [INFO     ] 2026-06-25 19:39:55,040 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,040 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,040 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,080 Parameters: current_time              = 5.174720000004427e-08
# yt : [INFO     ] 2026-06-25 19:39:55,080 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,080 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,081 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,121 Parameters: current_time              = 5.1782800000044427e-08
# yt : [INFO     ] 2026-06-25 19:39:55,122 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,122 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,122 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# ['plt00129166', 'plt00129225', 'plt00129292', 'plt00129368', 'plt00129457', 'plt00129564', 'plt00129697', 'plt00129870', 'plt00130104', 'plt00201021', 'plt00201232', 'plt00201441', 'plt00201658', 'plt00201918', 'plt00202440', 'plt00202822', 'plt00202890', 'plt00202950', 'plt00203004', 'plt00203063', 'plt00203130', 'plt00203206', 'plt00203295', 'plt00203402', 'plt00203535', 'plt00203708', 'plt00203942', 'plt00264712', 'plt00264923', 'plt00265132', 'plt00265349', 'plt00265609', 'plt00266131', 'plt00266513', 'plt00266581', 'plt00266641', 'plt00266695']
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00129166
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00129166 | step=129166 | Vg=-4.5483 V | <Pz>_FE=+1.261182e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00129225
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00129225 | step=129225 | Vg=-4.0479 V | <Pz>_FE=+1.186562e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00129292
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00129292 | step=129292 | Vg=-3.5469 V | <Pz>_FE=+1.104641e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00129368
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00129368 | step=129368 | Vg=-3.0451 V | <Pz>_FE=+1.013572e-01
# yt : [INFO     ] 2026-06-25 19:39:55,162 Parameters: current_time              = 5.1825600000044617e-08
# yt : [INFO     ] 2026-06-25 19:39:55,162 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,162 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,162 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,203 Parameters: current_time              = 5.187880000004485e-08
# yt : [INFO     ] 2026-06-25 19:39:55,203 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,203 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,204 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,244 Parameters: current_time              = 5.194800000004516e-08
# yt : [INFO     ] 2026-06-25 19:39:55,244 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,245 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,245 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,284 Parameters: current_time              = 5.2041600000045576e-08
# yt : [INFO     ] 2026-06-25 19:39:55,284 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,285 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,285 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,325 Parameters: current_time              = 8.040839999982743e-08
# yt : [INFO     ] 2026-06-25 19:39:55,326 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,326 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,326 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00129457
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00129457 | step=129457 | Vg=-2.5423 V | <Pz>_FE=+9.106982e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00129564
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00129564 | step=129564 | Vg=-2.0383 V | <Pz>_FE=+7.920400e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00129697
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00129697 | step=129697 | Vg=-1.5326 V | <Pz>_FE=+6.513957e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00129870
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00129870 | step=129870 | Vg=-1.0247 V | <Pz>_FE=+4.790203e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00130104
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00130104 | step=130104 | Vg=-0.5138 V | <Pz>_FE=+2.620102e-02
# yt : [INFO     ] 2026-06-25 19:39:55,366 Parameters: current_time              = 8.04927999998264e-08
# yt : [INFO     ] 2026-06-25 19:39:55,366 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,366 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,366 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,407 Parameters: current_time              = 8.05763999998254e-08
# yt : [INFO     ] 2026-06-25 19:39:55,407 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,408 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,408 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,448 Parameters: current_time              = 8.066319999982434e-08
# yt : [INFO     ] 2026-06-25 19:39:55,448 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,448 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,448 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,487 Parameters: current_time              = 8.076719999982308e-08
# yt : [INFO     ] 2026-06-25 19:39:55,488 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,488 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,488 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,528 Parameters: current_time              = 8.097599999982056e-08
# yt : [INFO     ] 2026-06-25 19:39:55,528 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,529 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,529 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00201021
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00201021 | step=201021 | Vg=-0.0000 V | <Pz>_FE=+2.914335e-17
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00201232
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00201232 | step=201232 | Vg=+0.5029 V | <Pz>_FE=-1.239804e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00201441
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00201441 | step=201441 | Vg=+1.0059 V | <Pz>_FE=-2.486753e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00201658
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00201658 | step=201658 | Vg=+1.5090 V | <Pz>_FE=-3.754992e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00201918
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00201918 | step=201918 | Vg=+2.0125 V | <Pz>_FE=-5.088062e-02
# yt : [INFO     ] 2026-06-25 19:39:55,569 Parameters: current_time              = 8.112879999981871e-08
# yt : [INFO     ] 2026-06-25 19:39:55,569 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,569 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,569 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,610 Parameters: current_time              = 8.115599999981838e-08
# yt : [INFO     ] 2026-06-25 19:39:55,610 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,610 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,610 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,651 Parameters: current_time              = 8.117999999981809e-08
# yt : [INFO     ] 2026-06-25 19:39:55,651 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,651 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,651 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,691 Parameters: current_time              = 8.120159999981783e-08
# yt : [INFO     ] 2026-06-25 19:39:55,691 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,691 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,691 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,731 Parameters: current_time              = 8.122519999981754e-08
# yt : [INFO     ] 2026-06-25 19:39:55,732 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,732 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,732 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00202440
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00202440 | step=202440 | Vg=+2.5181 V | <Pz>_FE=-6.685452e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00202822
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00202822 | step=202822 | Vg=+3.0451 V | <Pz>_FE=-1.013571e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00202890
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00202890 | step=202890 | Vg=+3.5469 V | <Pz>_FE=-1.104638e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00202950
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00202950 | step=202950 | Vg=+4.0479 V | <Pz>_FE=-1.186560e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00203004
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00203004 | step=203004 | Vg=+4.5483 V | <Pz>_FE=-1.261182e-01
# yt : [INFO     ] 2026-06-25 19:39:55,772 Parameters: current_time              = 8.125199999981722e-08
# yt : [INFO     ] 2026-06-25 19:39:55,772 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,772 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,772 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,813 Parameters: current_time              = 8.128239999981685e-08
# yt : [INFO     ] 2026-06-25 19:39:55,813 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,814 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,814 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:55,856 Parameters: current_time              = 8.131799999981642e-08
# yt : [INFO     ] 2026-06-25 19:39:55,856 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:55,856 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:55,856 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00203063
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00203063 | step=203063 | Vg=+4.0479 V | <Pz>_FE=-1.186562e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00203130
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00203130 | step=203130 | Vg=+3.5469 V | <Pz>_FE=-1.104641e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00203206
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00203206 | step=203206 | Vg=+3.0451 V | <Pz>_FE=-1.013572e-01
# yt : [INFO     ] 2026-06-25 19:39:56,011 Parameters: current_time              = 8.13607999998159e-08
# yt : [INFO     ] 2026-06-25 19:39:56,011 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,011 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,011 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,052 Parameters: current_time              = 8.141399999981526e-08
# yt : [INFO     ] 2026-06-25 19:39:56,052 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,052 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,053 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,093 Parameters: current_time              = 8.148319999981442e-08
# yt : [INFO     ] 2026-06-25 19:39:56,093 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,093 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,093 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,134 Parameters: current_time              = 8.157679999981329e-08
# yt : [INFO     ] 2026-06-25 19:39:56,134 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,134 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,135 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,174 Parameters: current_time              = 1.0588479999951914e-07
# yt : [INFO     ] 2026-06-25 19:39:56,174 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,175 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,175 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00203295
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00203295 | step=203295 | Vg=+2.5423 V | <Pz>_FE=-9.106982e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00203402
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00203402 | step=203402 | Vg=+2.0383 V | <Pz>_FE=-7.920400e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00203535
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00203535 | step=203535 | Vg=+1.5326 V | <Pz>_FE=-6.513957e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00203708
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00203708 | step=203708 | Vg=+1.0247 V | <Pz>_FE=-4.790203e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00203942
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00203942 | step=203942 | Vg=+0.5138 V | <Pz>_FE=-2.620102e-02
# yt : [INFO     ] 2026-06-25 19:39:56,216 Parameters: current_time              = 1.0596919999951812e-07
# yt : [INFO     ] 2026-06-25 19:39:56,216 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,216 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,216 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,257 Parameters: current_time              = 1.060527999995171e-07
# yt : [INFO     ] 2026-06-25 19:39:56,257 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,257 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,257 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,297 Parameters: current_time              = 1.0613959999951605e-07
# yt : [INFO     ] 2026-06-25 19:39:56,298 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,298 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,298 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,339 Parameters: current_time              = 1.062435999995148e-07
# yt : [INFO     ] 2026-06-25 19:39:56,339 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,339 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,339 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,379 Parameters: current_time              = 1.0645239999951227e-07
# yt : [INFO     ] 2026-06-25 19:39:56,379 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,380 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,380 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00264712
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00264712 | step=264712 | Vg=+0.0000 V | <Pz>_FE=-6.245005e-17
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00264923
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00264923 | step=264923 | Vg=-0.5029 V | <Pz>_FE=+1.239804e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00265132
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00265132 | step=265132 | Vg=-1.0059 V | <Pz>_FE=+2.486753e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00265349
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00265349 | step=265349 | Vg=-1.5090 V | <Pz>_FE=+3.754992e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00265609
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00265609 | step=265609 | Vg=-2.0125 V | <Pz>_FE=+5.088062e-02
# yt : [INFO     ] 2026-06-25 19:39:56,421 Parameters: current_time              = 1.0660519999951042e-07
# yt : [INFO     ] 2026-06-25 19:39:56,421 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,421 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,421 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,462 Parameters: current_time              = 1.0663239999951009e-07
# yt : [INFO     ] 2026-06-25 19:39:56,462 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,462 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,463 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,503 Parameters: current_time              = 1.066563999995098e-07
# yt : [INFO     ] 2026-06-25 19:39:56,503 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,503 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,503 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# yt : [INFO     ] 2026-06-25 19:39:56,544 Parameters: current_time              = 1.0667799999950954e-07
# yt : [INFO     ] 2026-06-25 19:39:56,544 Parameters: domain_dimensions         = [64 64 18]
# yt : [INFO     ] 2026-06-25 19:39:56,545 Parameters: domain_left_edge          = [-1.6e-08 -1.6e-08  0.0e+00]
# yt : [INFO     ] 2026-06-25 19:39:56,545 Parameters: domain_right_edge         = [1.6e-08 1.6e-08 9.0e-09]
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00266131
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00266131 | step=266131 | Vg=-2.5181 V | <Pz>_FE=+6.685452e-02
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00266513
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00266513 | step=266513 | Vg=-3.0451 V | <Pz>_FE=+1.013571e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00266581
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00266581 | step=266581 | Vg=-3.5469 V | <Pz>_FE=+1.104638e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00266641
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00266641 | step=266641 | Vg=-4.0479 V | <Pz>_FE=+1.186560e-01
# Read Pz with shape (64, 64, 18) from /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/plt00266695
# Domain: x [-1.600e-08, 1.600e-08] m, y [-1.600e-08, 1.600e-08] m, z [0.000e+00, 9.000e-09] m
# plt00266695 | step=266695 | Vg=-4.5483 V | <Pz>_FE=+1.261182e-01
# Saved CSV: /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/MFIM_PV_curve_add_f.csv

# %% [markdown]
# ### Load paper 2D data

# %%
import pandas as pd

def load_pv_file(filepath):
    filepath = str(filepath)

    if filepath.endswith(".csv"):
        df = pd.read_csv(filepath, header=None)

    elif filepath.endswith(".xlsx"):
        df = pd.read_excel(filepath, header=None)

    else:
        raise ValueError("Only .csv or .xlsx supported")

    V = df.iloc[:, 0].to_numpy()
    P = df.iloc[:, 1].to_numpy()

    return V, P, df

# %%
Vp, Pp, dfp = load_pv_file("Paper_Dataset.xlsx")

# %%
print("Loaded PV data from Paper_Dataset.xlsx:")
dfp.head()
# Out:
# Loaded PV data from Paper_Dataset.xlsx:
#           0         1
# 0 -3.429463 -9.232048
# 1 -2.995951 -8.330400
# 2 -1.497976 -4.795635
# 3 -1.022267 -2.400194
# 4  0.000000  0.086957

# %%
#!pip install openpyxl

# %% [markdown]
# ### load no f data

# %%
import pandas as pd


filepath = "/home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7/MFIM_PV_curve.csv"

dfnf = pd.read_csv(filepath)

    
Vnf = dfnf["Vg_mean"].to_numpy()
Pnf = dfnf["P_mean"].to_numpy()

dfnf.head()
# Out:
#       plotfile  step    P_mean     P_min     P_max     P_std   Vg_mean  \
# 0  plt00000076    76  0.126118  0.073447  0.135848  0.018304 -4.548267
# 1  plt00000135   135  0.118656  0.067879  0.128379  0.017732 -4.047918
# 2  plt00000202   202  0.110464  0.061986  0.120115  0.017028 -3.546909
# 3  plt00000278   278  0.101357  0.055699  0.110841  0.016149 -3.045105
# 4  plt00000367   367  0.091070  0.048920  0.100241  0.015031 -2.542320
#
#      Vg_min    Vg_max        Vg_std  Nx  Ny  Nz  num_FE_cells  sweep_direction
# 0 -4.548267 -4.548266  1.221150e-07  64  64  18         40960              0.0
# 1 -4.047918 -4.047918  1.212080e-09  64  64  18         40960              1.0
# 2 -3.546909 -3.546909  2.249592e-11  64  64  18         40960              1.0
# 3 -3.045105 -3.045105  3.662867e-12  64  64  18         40960              1.0
# 4 -2.542320 -2.542320  2.954151e-12  64  64  18         40960              1.0

# %% [markdown]
# ### plot pv

# %%
print(len(P))
# Out:
# 37

# %%
def sci_tex(x, sig=2):
    """Return LaTeX like 1.23\\times10^{-4} (no 'e')."""
    if x == 0:
        return r"0"
    exp = int(np.floor(np.log10(abs(x))))
    mant = x / (10 ** exp)
    return rf"{mant:.{sig}f}\times 10^{{{exp}}}"

# ==========================
# Plot PV curve
# ==========================

plt.figure(figsize=(6, 5))

textstr = '\n'.join((
    r'In SI units:',
    rf'$\alpha={sci_tex(ALPHA, sig=2)}$',
    rf'$\beta={sci_tex(BETA, sig=2)}$',
    rf'$\gamma={sci_tex(SMALL_GAMMA, sig=2)}$',
    rf'$g_{{11}}={sci_tex(G11, sig=2)}$',
    rf'$g_{{44}}={sci_tex(G44, sig=2)}$',
    rf'$t_{{fe}}={sci_tex((FE_Z_HI_NM-FE_Z_LO_NM)*1e-9, sig=2)}$',
))

props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
plt.text(1, -1, textstr, fontsize=12,
        verticalalignment='top', bbox=props)

# time-order full loop
plt.plot(V, -P*100, "-o", markersize=4, linewidth=1.2, label="after")
# paper data
plt.plot(Vp, Pp, "-o", markersize=4, linewidth=1.2, label="paper")
# no f data
plt.plot(Vnf, -Pnf*100, "-o", markersize=4, linewidth=1.2, label="before")
# optional: highlight positive / negative sweep
pos = df["sweep_direction"].to_numpy() >= 0
neg = df["sweep_direction"].to_numpy() < 0
'''
if np.any(pos):
    plt.plot(V[pos], -P[pos]*100, "o", markersize=5, label="positive sweep")

if np.any(neg):
    plt.plot(V[neg], -P[neg]*100, "s", markersize=5, label="negative sweep")
'''

plt.axhline(0, linewidth=0.8)
plt.axvline(0, linewidth=0.8)

plt.xlabel(r"$V_g$ (V)")
plt.ylabel(r"$\langle P_z \rangle_\mathrm{FE}$ (uC/cm$^2$)")
plt.title("MFIM P-V Curve")
plt.grid(True, alpha=0.3)
plt.legend()
plt.tight_layout()

plt.savefig(OUT_FIG, dpi=200)
print(f"Saved figure: {OUT_FIG}")

plt.show()
# Out:
# Saved figure: /home/gkaiwi58/FAM/FerroX/Exec/MFIM_mod_1_2D_1e-7_add_f/MFIM_PV_curve_3comp.png
